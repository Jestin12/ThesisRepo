# %% [markdown]
# # 1D CNN — Two-Hand Dynamic Gesture Recognition (multi-variant)
#
# Clean, single-path pipeline for training **several 1D-CNN architecture variants** on the glove data and exporting a comparison PDF.
#
# **Pipeline stages**
# 1. Configuration (data paths, sensor selection, preprocessing, augmentation, training)
# 2. Sensor column selection
# 3. Load CSVs from `DynamicTrainingData/TwoSec`
# 4. Preprocess: resample to fixed length + Butterworth low-pass filter
# 5. Train/test split (hold-out)
# 6. Cross-validation with augmentation **inside** each fold (so the validation set is never augmented)
# 7. Final retrain on the full training pool and evaluation on hold-out
# 8. Batch test on `TestData/Jestin/TwoHandDynamic` using per-subfolder labels
# 9. Save model + log experiment row
#
# Only the CNN-on-sequences path is supported here. Engineered-feature/MLP variants have been removed to keep the notebook readable.

# %% [markdown]
# ## 1. Imports

# %%
import os
import re
import glob
import json
import hashlib
import warnings
from pathlib import Path
from datetime import datetime
from collections import Counter

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy import signal as scipy_signal
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout

warnings.filterwarnings('ignore')
np.random.seed(42)
pd.set_option('display.max_columns', 20)
print('Imports OK.')
# Out:
# Imports OK.

# %% [markdown]
# ## 2. Configuration
#
# All knobs in one place. Edit only this cell to run different experiments.

# %%
from tensorflow.keras.layers import (
    BatchNormalization, GlobalAveragePooling1D, Activation, Input,
    LSTM, Bidirectional,
)
from tensorflow.keras.models import Sequential


def build_baseline(seq_len, n_chan, n_classes):
    """Original architecture from the notebook."""
    m = Sequential([
        Input(shape=(seq_len, n_chan)),
        Conv1D(32, 4, activation='relu'),
        MaxPooling1D(2),
        Conv1D(64, 4, activation='relu'),
        MaxPooling1D(2),
        Flatten(),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(n_classes, activation='softmax'),
    ], name='Baseline')
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return m


def build_shallow(seq_len, n_chan, n_classes):
    """Single Conv block — fewer params, faster to train."""
    m = Sequential([
        Input(shape=(seq_len, n_chan)),
        Conv1D(32, 5, activation='relu'),
        MaxPooling1D(2),
        Flatten(),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(n_classes, activation='softmax'),
    ], name='Shallow')
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return m


def build_deep(seq_len, n_chan, n_classes):
    """Three Conv blocks — more representational depth."""
    m = Sequential([
        Input(shape=(seq_len, n_chan)),
        Conv1D(32, 4, activation='relu'),
        MaxPooling1D(2),
        Conv1D(64, 4, activation='relu'),
        MaxPooling1D(2),
        Conv1D(128, 3, activation='relu'),
        MaxPooling1D(2),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.4),
        Dense(n_classes, activation='softmax'),
    ], name='Deep')
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return m


def build_bn_gap(seq_len, n_chan, n_classes):
    """BatchNorm + GlobalAveragePooling — typically better generalisation, fewer params."""
    m = Sequential([
        Input(shape=(seq_len, n_chan)),
        Conv1D(32, 4, padding='same'),
        BatchNormalization(), Activation('relu'),
        MaxPooling1D(2),
        Conv1D(64, 4, padding='same'),
        BatchNormalization(), Activation('relu'),
        MaxPooling1D(2),
        Conv1D(128, 3, padding='same'),
        BatchNormalization(), Activation('relu'),
        GlobalAveragePooling1D(),
        Dropout(0.3),
        Dense(n_classes, activation='softmax'),
    ], name='BN_GAP')
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return m


def build_wide_kernel(seq_len, n_chan, n_classes):
    """Wider kernels — larger temporal receptive field per layer."""
    m = Sequential([
        Input(shape=(seq_len, n_chan)),
        Conv1D(32, 8, activation='relu'),
        MaxPooling1D(2),
        Conv1D(64, 8, activation='relu'),
        MaxPooling1D(2),
        Flatten(),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(n_classes, activation='softmax'),
    ], name='WideKernel')
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return m


def build_cnn_lstm(seq_len, n_chan, n_classes):
    """CNN feature extractor → LSTM temporal model.

    Two Conv1D blocks pull out local temporal features, then a single LSTM
    consumes the resulting (T', F) sequence and a final Dense head classifies.
    Conv layers use padding='same' so MaxPooling controls the temporal
    downsampling explicitly.
    """
    m = Sequential([
        Input(shape=(seq_len, n_chan)),
        Conv1D(32, 4, padding='same', activation='relu'),
        MaxPooling1D(2),
        Conv1D(64, 4, padding='same', activation='relu'),
        MaxPooling1D(2),
        Dropout(0.3),
        LSTM(64, return_sequences=False),
        Dropout(0.3),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(n_classes, activation='softmax'),
    ], name='CNN_LSTM')
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return m


def build_cnn_bilstm(seq_len, n_chan, n_classes):
    """CNN feature extractor → Bidirectional LSTM temporal model.

    Same Conv front-end as CNN_LSTM but the recurrent stage is bidirectional,
    so each timestep's representation sees both past and future context within
    the trial — useful for gestures where the discriminative motion can sit
    anywhere along the trial.
    """
    m = Sequential([
        Input(shape=(seq_len, n_chan)),
        Conv1D(32, 4, padding='same', activation='relu'),
        MaxPooling1D(2),
        Conv1D(64, 4, padding='same', activation='relu'),
        MaxPooling1D(2),
        Dropout(0.3),
        Bidirectional(LSTM(64, return_sequences=False)),
        Dropout(0.3),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(n_classes, activation='softmax'),
    ], name='CNN_BiLSTM')
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return m

# %%
BATCH_TEST_ROOT = '/home/jestin/ThesisRepo/ML/NewTestData/15_Tash/Dynamic'

# %%
# ── Data locations ───────────────────────────────────────────────────────────
# You can include data from MULTIPLE users / source folders.
#
# Each entry in DATA_PATHS is a folder that DIRECTLY contains gesture-label
# subfolders (e.g. .../Alan/Dynamic, .../Bridgette/Dynamic). All matching label
# folders across these paths are merged by label name, so e.g.
# Alan/Dynamic/Wave and Bridgette/Dynamic/Wave end up in the same "Wave" class.
#
# Tip: comment out a path to exclude that user from training without deleting it.
DATA_PATHS = [
    # '/home/jestin/ThesisRepo/ML/NewTrainingData/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/1_Alan/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/2_Alex/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/3_Anghad/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/4_Daniel/Dynamic',
    # '/home/jestin/ThesisRepo/ML/NewTestData/5_Georgia/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/6_Harry/Dynamic',
    # '/home/jestin/ThesisRepo/ML/NewTestData/7_Henry/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/8_Jestin/Dynamic',
    # '/home/jestin/ThesisRepo/ML/NewTestData/9_Joselyn/Dynamic',
    # '/home/jestin/ThesisRepo/ML/NewTestData/10_Josh/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/11_Mansh/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/12_Marcus/Dynamic',
    # '/home/jestin/ThesisRepo/ML/NewTestData/13_Nat/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/14_StephenV2/Dynamic',
    # '/home/jestin/ThesisRepo/ML/NewTestData/15_Tash/Dynamic',
    # '/home/jestin/ThesisRepo/ML/NewTestData/16_Bella/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/17_Raquel/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/18_Bridgette/Dynamic'

]


# Backwards-compat shortcut: set DATA_ROOT to a string and leave DATA_PATHS = None
# (or empty) to use the old single-folder workflow.
DATA_ROOT = None

# INCLUDE_LABELS  = None   # None = use every label subfolder found

INCLUDE_LABELS = [
    'Double_Lower',
    # 'Double_Nothing',
    'Double_Pistol_Recoil',
    'Double_Raise',
    'Double_Wiggle',
    'Double_cmere',
    'Drum_Roll',
]


# ── Sensor selection ─────────────────────────────────────────────────────────
USE_LEFT_HAND  = True
USE_RIGHT_HAND = True

USE_YPR        = True   # yaw / pitch / roll (or heading/pitch/roll for wrist)
USE_QUAT       = False   # quaternion w/x/y/z
USE_ACCEL      = True   # ax / ay / az
USE_FLEX       = True   # mcp_flex / pip_flex (fingers only)

# Segments to include
USE_WRIST  = True
USE_PALM   = True
USE_THUMB  = True
USE_INDEX  = True
USE_MIDDLE = True
USE_RING   = True
USE_PINKY  = True

# ── Preprocessing ────────────────────────────────────────────────────────────
RESAMPLE_TO_N_STEPS    = 90
APPLY_BUTTERWORTH      = True
BUTTERWORTH_CUTOFF_HZ  = 10.0
BUTTERWORTH_ORDER      = 4
SAMPLING_RATE_HZ       = 30.0
NORMALISATION          = 'standard'   
                                                                  # 'standard' | 'minmax' | None

# ── Train/test split ─────────────────────────────────────────────────────────
TEST_SIZE             = 0.10
RANDOM_STATE          = 42
STRATIFY_SPLIT        = True

# ── Cross-validation ─────────────────────────────────────────────────────────
RUN_CROSS_VALIDATION  = True
CV_FOLDS              = 7
CV_SHUFFLE            = True

# ── Augmentation (training only, inside each CV fold) ────────────────────────
AUGMENT_TRAINING_DATA          = True
AUGMENTATION_COPIES_PER_SAMPLE = 2
AUGMENTATION_RANDOM_SEED       = 42
AUGMENT_CONFIG = {
    'time_shift':      {'enabled': False,  'apply_prob': 0.7, 'max_shift_steps': 3, 'fill_mode': 'edge'},
    'time_warp':       {'enabled': False,  'apply_prob': 0.5, 'speed_range': (0.90, 1.10)},
    'time_mask':       {'enabled': False,  'apply_prob': 0.5, 'max_masks': 2, 'max_mask_size': 3, 'fill_mode': 'zero'},
    'gaussian_noise':  {'enabled': False,  'apply_prob': 1.0, 'std_ratio': 0.02},
    'amplitude_scale': {'enabled': True,  'apply_prob': 1.0, 'scale_range': (0.9, 1.1)},
    'baseline_offset': {'enabled': True,  'apply_prob': 1.0, 'offset_std_ratio': 0.02},
    'channel_dropout': {'enabled': False,  'apply_prob': 0.3, 'drop_fraction': 0.03, 'fill_mode': 'zero'},
    # Only enable left/right swap if the class label is symmetric under that swap
    'left_right_swap': {'enabled': False, 'apply_prob': 0.5},
}

# ── Training hyperparameters ─────────────────────────────────────────────────
TRAIN_EPOCHS           = 60     # max epochs; EarlyStopping decides when to stop
TRAIN_BATCH_SIZE       = 16
TRAIN_VALIDATION_SPLIT = 0.2    # only used by the final retrain (not by CV)
TRAIN_VERBOSE          = 1

# ── Early stopping ───────────────────────────────────────────────────────────
EARLY_STOPPING_ENABLED          = True
EARLY_STOPPING_MONITOR          = 'val_loss'   # 'val_loss' (min) or 'val_accuracy' (max)
EARLY_STOPPING_PATIENCE         = 5            # epochs with no improvement before stopping
EARLY_STOPPING_MIN_DELTA        = 0.0          # min change to count as improvement
EARLY_STOPPING_RESTORE_BEST     = True         # roll weights back to best-monitor epoch
EARLY_STOPPING_VERBOSE          = 1

# ── Output paths ─────────────────────────────────────────────────────────────
MODEL_OUTPUT_DIR     = Path('/home/jestin/ThesisRepo/ML/NewReports/DynamicReports')
EXPERIMENT_LOG_PATH  = MODEL_OUTPUT_DIR / 'experiment_results.csv'
MODEL_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Resolve active data paths (supports both DATA_PATHS list and legacy DATA_ROOT)
ACTIVE_DATA_PATHS = []
if DATA_PATHS:
    ACTIVE_DATA_PATHS = [p for p in DATA_PATHS if p and not p.strip().startswith('#')]
if not ACTIVE_DATA_PATHS and DATA_ROOT:
    ACTIVE_DATA_PATHS = [DATA_ROOT]

print('Configuration loaded.')
print(f'  Data paths ({len(ACTIVE_DATA_PATHS)}):')
for p in ACTIVE_DATA_PATHS:
    print(f'    - {p}')
# Out:
# Configuration loaded.
#   Data paths (11):
#     - /home/jestin/ThesisRepo/ML/NewTestData/1_Alan/Dynamic
#     - /home/jestin/ThesisRepo/ML/NewTestData/2_Alex/Dynamic
#     - /home/jestin/ThesisRepo/ML/NewTestData/3_Anghad/Dynamic
#     - /home/jestin/ThesisRepo/ML/NewTestData/4_Daniel/Dynamic
#     - /home/jestin/ThesisRepo/ML/NewTestData/6_Harry/Dynamic
#     - /home/jestin/ThesisRepo/ML/NewTestData/8_Jestin/Dynamic
#     - /home/jestin/ThesisRepo/ML/NewTestData/11_Mansh/Dynamic
#     - /home/jestin/ThesisRepo/ML/NewTestData/12_Marcus/Dynamic
#     - /home/jestin/ThesisRepo/ML/NewTestData/14_StephenV2/Dynamic
#     - /home/jestin/ThesisRepo/ML/NewTestData/17_Raquel/Dynamic
#     - /home/jestin/ThesisRepo/ML/NewTestData/18_Bridgette/Dynamic

# %%
VARIANTS = [
    # ('Baseline',   'Conv1D(32,k=4)→Pool→Conv1D(64,k=4)→Pool→Flatten→Dense(64)→Dropout(0.3)→Softmax', build_baseline),
    # ('Shallow',    'Single Conv block: Conv1D(32,k=5)→Pool→Flatten→Dense(32)→Dropout(0.3)→Softmax',           build_shallow),
    ('Deep',       'Three Conv blocks: Conv1D(32,4)→Conv1D(64,4)→Conv1D(128,3)→Flatten→Dense(128)→Dropout(0.4)→Softmax', build_deep),
    ('BN_GAP',     'Conv+BN+ReLU ×3 with GlobalAveragePooling1D head — fewer params, less overfit',                build_bn_gap),
    # ('WideKernel', 'Conv1D(32,k=8)→Pool→Conv1D(64,k=8)→Pool→Flatten→Dense(64)→Dropout(0.3)→Softmax', build_wide_kernel),
    # ('CNN_LSTM',   'Conv1D(32,4)→Pool→Conv1D(64,4)→Pool→Dropout→LSTM(64)→Dense(64)→Dropout→Softmax',           build_cnn_lstm),
    # ('CNN_BiLSTM', 'Conv1D(32,4)→Pool→Conv1D(64,4)→Pool→Dropout→BiLSTM(64)→Dense(64)→Dropout→Softmax',         build_cnn_bilstm),
]

# Container populated by the CV / retrain / hold-out / batch-test cells below.
# Each entry: dict with name, description, n_params, cv_results, cv_mean, cv_std,
# history, test_accuracy, test_loss, classification_report, y_pred, batch_df,
# batch_correct, batch_total, batch_accuracy, model, model_path, scaler.
variant_results = []
print(f'Configured {len(VARIANTS)} variants:')
for n, d, _ in VARIANTS:
    print(f'  - {n}: {d}')
# Out:
# Configured 4 variants:
#   - Baseline: Conv1D(32,k=4)→Pool→Conv1D(64,k=4)→Pool→Flatten→Dense(64)→Dropout(0.3)→Softmax
#   - Deep: Three Conv blocks: Conv1D(32,4)→Conv1D(64,4)→Conv1D(128,3)→Flatten→Dense(128)→Dropout(0.4)→Softmax
#   - BN_GAP: Conv+BN+ReLU ×3 with GlobalAveragePooling1D head — fewer params, less overfit
#   - CNN_BiLSTM: Conv1D(32,4)→Pool→Conv1D(64,4)→Pool→Dropout→BiLSTM(64)→Dense(64)→Dropout→Softmax

# %% [markdown]
# ## 3. Sensor column selection
#
# Build the list of channel names that match the configuration toggles. The CSVs share a known column schema, so we generate names directly rather than parsing every header.

# %%
SEGMENTS_WITH_FLEX = ['thumb', 'index', 'middle', 'ring', 'pinky']  # palm has no flex


def build_sensor_columns(hands, segments, use_ypr, use_quat, use_accel, use_flex):
    cols = []
    for hand in hands:
        for seg in segments:
            if seg == 'wrist':
                # wrist has a single IMU; YPR fields are heading/pitch/roll
                p = f'{hand}_wrist'
                if use_ypr:   cols += [f'{p}_heading', f'{p}_pitch', f'{p}_roll']
                if use_quat:  cols += [f'{p}_quat_w', f'{p}_quat_x', f'{p}_quat_y', f'{p}_quat_z']
                if use_accel: cols += [f'{p}_ax', f'{p}_ay', f'{p}_az']
                # no flex on wrist
            else:
                for loc in ['mid', 'prox']:
                    p = f'{hand}_{seg}_{loc}'
                    if use_ypr:   cols += [f'{p}_yaw', f'{p}_pitch', f'{p}_roll']
                    if use_quat:  cols += [f'{p}_quat_w', f'{p}_quat_x', f'{p}_quat_y', f'{p}_quat_z']
                    if use_accel: cols += [f'{p}_ax', f'{p}_ay', f'{p}_az']
                if use_flex and seg in SEGMENTS_WITH_FLEX:
                    cols += [f'{hand}_{seg}_mcp_flex', f'{hand}_{seg}_pip_flex']
    return cols


resolved_hands = [h for h, on in [('left', USE_LEFT_HAND), ('right', USE_RIGHT_HAND)] if on]
resolved_segs = [s for s, on in [
    ('wrist', USE_WRIST), ('palm', USE_PALM), ('thumb', USE_THUMB),
    ('index', USE_INDEX), ('middle', USE_MIDDLE), ('ring', USE_RING), ('pinky', USE_PINKY)
] if on]

SENSOR_COLS = build_sensor_columns(
    hands=resolved_hands, segments=resolved_segs,
    use_ypr=USE_YPR, use_quat=USE_QUAT, use_accel=USE_ACCEL, use_flex=USE_FLEX,
)

print(f'Selected {len(SENSOR_COLS)} sensor columns.')
print('First 6:', SENSOR_COLS[:6])
print('Last  6:', SENSOR_COLS[-6:])
# Out:
# Selected 176 sensor columns.
# First 6: ['left_wrist_heading', 'left_wrist_pitch', 'left_wrist_roll', 'left_wrist_ax', 'left_wrist_ay', 'left_wrist_az']
# Last  6: ['right_pinky_prox_roll', 'right_pinky_prox_ax', 'right_pinky_prox_ay', 'right_pinky_prox_az', 'right_pinky_mcp_flex', 'right_pinky_pip_flex']

# %% [markdown]
# ## 4. Load training data
#
# Walk the label subfolders under `DATA_ROOT` and read each CSV as a `(T, C)` array of the selected sensor channels.

# %%
def load_dataset(data_paths, include_labels, sensor_cols):
    """
    Load all CSVs from gesture-label subfolders found inside each path in
    `data_paths`. Trials from the same label across different source folders
    are merged into a single class.

    Returns:
        trials      : list of np.ndarray (per-trial sensor matrices)
        labels      : list of class label strings
        class_names : sorted list of unique class labels
        source_info : list of source label-folder paths per trial (parallel to trials)
    """
    if isinstance(data_paths, str):
        data_paths = [data_paths]
    if not data_paths:
        raise ValueError('No data paths provided. Set DATA_PATHS or DATA_ROOT.')

    resolved_paths = []
    for p in data_paths:
        p_exp = os.path.expanduser(p)
        if not os.path.isdir(p_exp):
            raise FileNotFoundError(
                f"Data path not found: {p_exp!r}\n"
                "Update DATA_PATHS in the Configuration cell."
            )
        resolved_paths.append(p_exp)

    SKIP = {'PDF', 'sdb', 'idk'}
    label_to_folders = {}   # label -> list of full folder paths
    for root in resolved_paths:
        for d in sorted(os.listdir(root)):
            full = os.path.join(root, d)
            if not os.path.isdir(full) or d in SKIP:
                continue
            label_to_folders.setdefault(d, []).append(full)

    if include_labels is not None:
        label_to_folders = {k: v for k, v in label_to_folders.items()
                            if k in include_labels}
    if not label_to_folders:
        raise ValueError('No label folders found. Check DATA_PATHS and INCLUDE_LABELS.')

    label_names = sorted(label_to_folders.keys())
    print(f'Found {len(label_names)} gesture classes across {len(resolved_paths)} source folder(s):')

    trials, labels, source_info = [], [], []
    for label in label_names:
        folders = label_to_folders[label]
        per_source_counts = []
        for folder in folders:
            csv_files = sorted(glob.glob(os.path.join(folder, '*.csv')))
            per_source_counts.append((folder, len(csv_files)))
            for fpath in csv_files:
                try:
                    df = pd.read_csv(fpath)
                    available = [c for c in sensor_cols if c in df.columns]
                    if not available:
                        print(f'    WARNING: no matching sensor columns in {os.path.basename(fpath)}')
                        continue
                    trials.append(df[available].values.astype(np.float32))
                    labels.append(label)
                    source_info.append(folder)
                except Exception as e:
                    print(f'    ERROR loading {os.path.basename(fpath)}: {e}')
        total = sum(c for _, c in per_source_counts)
        extra = ''
        if len(per_source_counts) > 1:
            extra = ' from ' + ', '.join(
                f"{os.path.basename(os.path.dirname(fp))}({n})"
                for fp, n in per_source_counts
            )
        print(f'  [{label}]  →  {total} files{extra}')

    print(f'\nTotal trials loaded: {len(trials)}')
    return trials, labels, label_names, source_info


trials_raw, labels_raw, class_names, source_info = load_dataset(
    ACTIVE_DATA_PATHS, INCLUDE_LABELS, SENSOR_COLS
)

print('\nClass distribution:')
for cls, cnt in sorted(Counter(labels_raw).items()):
    print(f'  {cls}: {cnt} trials')

# Per-source-folder distribution
print('\nTrials per source folder:')
for src, cnt in sorted(Counter(source_info).items()):
    tag = os.sep.join(src.split(os.sep)[-3:])
    print(f'  {tag}: {cnt} trials')
# Out:
# Found 6 gesture classes across 11 source folder(s):
#   [Double_Lower]  →  55 files from Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5)
#   [Double_Pistol_Recoil]  →  55 files from Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5)
#   [Double_Raise]  →  55 files from Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5)
#   [Double_Wiggle]  →  54 files from Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(4), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5)
#   [Double_cmere]  →  56 files from Dynamic(5), Dynamic(5), Dynamic(6), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5)
#   [Drum_Roll]  →  50 files from Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(0), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5)
#
# Total trials loaded: 325
#
# Class distribution:
#   Double_Lower: 55 trials
#   Double_Pistol_Recoil: 55 trials
#   Double_Raise: 55 trials
#   Double_Wiggle: 54 trials
#   Double_cmere: 56 trials
#   Drum_Roll: 50 trials
#
# Trials per source folder:
#   11_Mansh/Dynamic/Double_Lower: 5 trials
#   11_Mansh/Dynamic/Double_Pistol_Recoil: 5 trials
#   11_Mansh/Dynamic/Double_Raise: 5 trials
#   11_Mansh/Dynamic/Double_Wiggle: 5 trials
#   11_Mansh/Dynamic/Double_cmere: 5 trials
#   11_Mansh/Dynamic/Drum_Roll: 5 trials
#   12_Marcus/Dynamic/Double_Lower: 5 trials
#   12_Marcus/Dynamic/Double_Pistol_Recoil: 5 trials
#   12_Marcus/Dynamic/Double_Raise: 5 trials
#   12_Marcus/Dynamic/Double_Wiggle: 5 trials
#   12_Marcus/Dynamic/Double_cmere: 5 trials
#   12_Marcus/Dynamic/Drum_Roll: 5 trials
#   14_StephenV2/Dynamic/Double_Lower: 5 trials
#   14_StephenV2/Dynamic/Double_Pistol_Recoil: 5 trials
#   14_StephenV2/Dynamic/Double_Raise: 5 trials
#   14_StephenV2/Dynamic/Double_Wiggle: 5 trials
#   14_StephenV2/Dynamic/Double_cmere: 5 trials
#   14_StephenV2/Dynamic/Drum_Roll: 5 trials
#   17_Raquel/Dynamic/Double_Lower: 5 trials
#   17_Raquel/Dynamic/Double_Pistol_Recoil: 5 trials
#   17_Raquel/Dynamic/Double_Raise: 5 trials
#   17_Raquel/Dynamic/Double_Wiggle: 5 trials
#   17_Raquel/Dynamic/Double_cmere: 5 trials
#   17_Raquel/Dynamic/Drum_Roll: 5 trials
#   18_Bridgette/Dynamic/Double_Lower: 5 trials
#   18_Bridgette/Dynamic/Double_Pistol_Recoil: 5 trials
#   18_Bridgette/Dynamic/Double_Raise: 5 trials
#   18_Bridgette/Dynamic/Double_Wiggle: 5 trials
#   18_Bridgette/Dynamic/Double_cmere: 5 trials
#   18_Bridgette/Dynamic/Drum_Roll: 5 trials
#   1_Alan/Dynamic/Double_Lower: 5 trials
#   1_Alan/Dynamic/Double_Pistol_Recoil: 5 trials
#   1_Alan/Dynamic/Double_Raise: 5 trials
#   1_Alan/Dynamic/Double_Wiggle: 5 trials
#   1_Alan/Dynamic/Double_cmere: 5 trials
#   1_Alan/Dynamic/Drum_Roll: 5 trials
#   2_Alex/Dynamic/Double_Lower: 5 trials
#   2_Alex/Dynamic/Double_Pistol_Recoil: 5 trials
#   2_Alex/Dynamic/Double_Raise: 5 trials
#   2_Alex/Dynamic/Double_Wiggle: 5 trials
#   2_Alex/Dynamic/Double_cmere: 5 trials
#   2_Alex/Dynamic/Drum_Roll: 5 trials
#   3_Anghad/Dynamic/Double_Lower: 5 trials
#   3_Anghad/Dynamic/Double_Pistol_Recoil: 5 trials
#   3_Anghad/Dynamic/Double_Raise: 5 trials
#   3_Anghad/Dynamic/Double_Wiggle: 5 trials
#   3_Anghad/Dynamic/Double_cmere: 6 trials
#   3_Anghad/Dynamic/Drum_Roll: 5 trials
#   4_Daniel/Dynamic/Double_Lower: 5 trials
#   4_Daniel/Dynamic/Double_Pistol_Recoil: 5 trials
#   4_Daniel/Dynamic/Double_Raise: 5 trials
#   4_Daniel/Dynamic/Double_Wiggle: 5 trials
#   4_Daniel/Dynamic/Double_cmere: 5 trials
#   4_Daniel/Dynamic/Drum_Roll: 5 trials
#   6_Harry/Dynamic/Double_Lower: 5 trials
#   6_Harry/Dynamic/Double_Pistol_Recoil: 5 trials
#   6_Harry/Dynamic/Double_Raise: 5 trials
#   6_Harry/Dynamic/Double_Wiggle: 5 trials
#   6_Harry/Dynamic/Double_cmere: 5 trials
#   6_Harry/Dynamic/Drum_Roll: 5 trials
#   8_Jestin/Dynamic/Double_Lower: 5 trials
#   8_Jestin/Dynamic/Double_Pistol_Recoil: 5 trials
#   8_Jestin/Dynamic/Double_Raise: 5 trials
#   8_Jestin/Dynamic/Double_Wiggle: 4 trials
#   8_Jestin/Dynamic/Double_cmere: 5 trials

# %% [markdown]
# ## 5. Preprocessing
#
# 1. Resample every trial to a fixed length so the CNN gets a constant input shape.
# 2. Optional zero-phase Butterworth low-pass filter to smooth high-frequency noise.

# %%
def resample_trial(trial, n_steps):
    """Linear resample (T, C) → (n_steps, C)."""
    T, C = trial.shape
    if T == n_steps:
        return trial.astype(np.float32, copy=False)
    old_idx = np.linspace(0, 1, T)
    new_idx = np.linspace(0, 1, n_steps)
    out = np.zeros((n_steps, C), dtype=np.float32)
    for c in range(C):
        out[:, c] = np.interp(new_idx, old_idx, trial[:, c])
    return out


def apply_butterworth(trials, cutoff, order, fs):
    """Zero-phase low-pass filter applied per channel."""
    nyq = fs / 2.0
    norm_cutoff = cutoff / nyq
    if norm_cutoff >= 1.0:
        print(f'  WARNING: cutoff {cutoff} Hz >= Nyquist {nyq} Hz — skipping filter.')
        return trials
    b, a = scipy_signal.butter(order, norm_cutoff, btype='low', analog=False)
    return [scipy_signal.filtfilt(b, a, t, axis=0).astype(np.float32) for t in trials]


# Resample
if RESAMPLE_TO_N_STEPS is not None:
    trials_resampled = [resample_trial(t, RESAMPLE_TO_N_STEPS) for t in trials_raw]
    print(f'Resampled all trials to {RESAMPLE_TO_N_STEPS} time steps.')
else:
    trials_resampled = trials_raw

# Filter
if APPLY_BUTTERWORTH:
    trials_filtered = apply_butterworth(trials_resampled, BUTTERWORTH_CUTOFF_HZ,
                                        BUTTERWORTH_ORDER, SAMPLING_RATE_HZ)
    print(f'Butterworth low-pass: cutoff={BUTTERWORTH_CUTOFF_HZ} Hz, order={BUTTERWORTH_ORDER}.')
else:
    trials_filtered = trials_resampled
    print('Butterworth filter skipped.')

sequence_length, n_channels = trials_filtered[0].shape
print(f'Trial shape: ({sequence_length}, {n_channels})  (time_steps × channels)')
# Out:
# Resampled all trials to 90 time steps.
# Butterworth low-pass: cutoff=10.0 Hz, order=4.
# Trial shape: (90, 176)  (time_steps × channels)

# %% [markdown]
# ## 6. Build X, y and the train/test split
#
# We stack all trials into a single `(N, T, C)` tensor, encode labels, then carve off a stratified hold-out test set. The hold-out set is **never** seen during training, augmentation, or scaler fitting.

# %%
X = np.stack(trials_filtered, axis=0).astype(np.float32)
X = np.nan_to_num(X, nan=0.0, posinf=0.0, neginf=0.0)

le = LabelEncoder()
y = le.fit_transform(labels_raw)
n_classes = len(le.classes_)
print(f'X shape: {X.shape}    y shape: {y.shape}    n_classes: {n_classes}')
print('Label mapping:', dict(zip(le.classes_, range(n_classes))))

X_train_pool, X_test, y_train_pool, y_test = train_test_split(
    X, y,
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE,
    stratify=y if STRATIFY_SPLIT and n_classes > 1 else None,
)
print(f'Train pool: {X_train_pool.shape}    Hold-out test: {X_test.shape}')
# Out:
# X shape: (325, 90, 176)    y shape: (325,)    n_classes: 6
# Label mapping: {np.str_('Double_Lower'): 0, np.str_('Double_Pistol_Recoil'): 1, np.str_('Double_Raise'): 2, np.str_('Double_Wiggle'): 3, np.str_('Double_cmere'): 4, np.str_('Drum_Roll'): 5}
# Train pool: (292, 90, 176)    Hold-out test: (33, 90, 176)

# %% [markdown]
# ## 7. Augmentation helpers
#
# Each augmentation operates on a single `(T, C)` trial and is applied probabilistically per `AUGMENT_CONFIG`. `augment_training_set` produces `copies_per_sample` augmented variants per original trial and concatenates them with the originals.
#
# Augmentation is applied **inside** each CV fold's training split — the fold's validation split is left untouched, just like the hold-out test set.

# %%
def _resize_linear(trial, target_steps):
    T, C = trial.shape
    if T == target_steps:
        return trial.astype(np.float32, copy=False)
    old_idx = np.linspace(0, 1, T)
    new_idx = np.linspace(0, 1, target_steps)
    out = np.zeros((target_steps, C), dtype=np.float32)
    for c in range(C):
        out[:, c] = np.interp(new_idx, old_idx, trial[:, c])
    return out


def aug_time_shift(trial, max_shift_steps=3, fill_mode='edge', rng=None):
    rng = rng or np.random.default_rng()
    if max_shift_steps <= 0:
        return trial.copy()
    shift = int(rng.integers(-max_shift_steps, max_shift_steps + 1))
    if shift == 0:
        return trial.copy()
    out = np.empty_like(trial)
    out[:] = 0.0 if fill_mode == 'zero' else (trial[0] if shift > 0 else trial[-1])
    if shift > 0:
        out[shift:] = trial[:-shift]
    else:
        out[:shift] = trial[-shift:]
    return out


def aug_time_warp(trial, speed_range=(0.9, 1.1), rng=None):
    rng = rng or np.random.default_rng()
    factor = float(rng.uniform(*speed_range))
    T = trial.shape[0]
    warped_steps = max(4, int(round(T * factor)))
    return _resize_linear(_resize_linear(trial, warped_steps), T)


def aug_time_mask(trial, max_masks=2, max_mask_size=3, fill_mode='zero', rng=None):
    rng = rng or np.random.default_rng()
    out = trial.copy()
    T, C = out.shape
    n_masks = int(rng.integers(1, max_masks + 1)) if max_masks > 0 else 0
    for _ in range(n_masks):
        size = int(rng.integers(1, max_mask_size + 1))
        start = int(rng.integers(0, max(1, T - size + 1)))
        if fill_mode == 'mean':
            out[start:start+size] = out.mean(axis=0, keepdims=True)
        elif fill_mode == 'noise':
            ch_std = np.std(out, axis=0, keepdims=True)
            out[start:start+size] = rng.normal(0.0, np.maximum(ch_std, 1e-6), size=(size, C))
        else:
            out[start:start+size] = 0.0
    return out


def aug_gaussian_noise(trial, std_ratio=0.02, rng=None):
    rng = rng or np.random.default_rng()
    ch_std = np.std(trial, axis=0, keepdims=True)
    noise_std = np.maximum(ch_std * std_ratio, 1e-6)
    return (trial + rng.normal(0.0, noise_std, size=trial.shape)).astype(np.float32)


def aug_amplitude_scale(trial, scale_range=(0.95, 1.05), rng=None):
    rng = rng or np.random.default_rng()
    scale = rng.uniform(scale_range[0], scale_range[1], size=(1, trial.shape[1]))
    return (trial * scale).astype(np.float32)


def aug_baseline_offset(trial, offset_std_ratio=0.02, rng=None):
    rng = rng or np.random.default_rng()
    ch_std = np.std(trial, axis=0, keepdims=True)
    offset_std = np.maximum(ch_std * offset_std_ratio, 1e-6)
    offset = rng.normal(0.0, offset_std, size=(1, trial.shape[1]))
    return (trial + offset).astype(np.float32)


def aug_channel_dropout(trial, drop_fraction=0.03, fill_mode='zero', rng=None):
    rng = rng or np.random.default_rng()
    out = trial.copy()
    C = out.shape[1]
    n_drop = max(1, int(round(C * drop_fraction))) if drop_fraction > 0 else 0
    if n_drop == 0:
        return out
    idx = rng.choice(C, size=min(n_drop, C), replace=False)
    if fill_mode == 'mean':
        out[:, idx] = out.mean(axis=0, keepdims=True)[:, idx]
    else:
        out[:, idx] = 0.0
    return out


def aug_left_right_swap(trial, sensor_cols, rng=None):
    out = trial.copy()
    name_to_idx = {col: i for i, col in enumerate(sensor_cols)}
    for col in sensor_cols:
        if col.startswith('left'):
            partner = 'right' + col[4:]
            if partner in name_to_idx:
                i, j = name_to_idx[col], name_to_idx[partner]
                out[:, i], out[:, j] = trial[:, j], trial[:, i]
    return out


def apply_augmentations(trial, sensor_cols, config, rng):
    """Apply each augmentation independently with its own probability."""
    out = trial.astype(np.float32, copy=True)

    def _drop_meta(cfg):
        return {k: v for k, v in cfg.items() if k not in ('enabled', 'apply_prob')}

    def _maybe(name, fn, **extra):
        cfg = config.get(name, {})
        if cfg.get('enabled', False) and rng.random() < cfg.get('apply_prob', 1.0):
            return fn(out, **_drop_meta(cfg), **extra, rng=rng)
        return out

    out = _maybe('time_shift',      aug_time_shift)
    out = _maybe('time_warp',       aug_time_warp)
    out = _maybe('time_mask',       aug_time_mask)
    out = _maybe('gaussian_noise',  aug_gaussian_noise)
    out = _maybe('amplitude_scale', aug_amplitude_scale)
    out = _maybe('baseline_offset', aug_baseline_offset)
    out = _maybe('channel_dropout', aug_channel_dropout)
    if config.get('left_right_swap', {}).get('enabled', False) \
            and rng.random() < config['left_right_swap'].get('apply_prob', 1.0):
        out = aug_left_right_swap(out, sensor_cols=sensor_cols, rng=rng)

    return np.nan_to_num(out, nan=0.0, posinf=0.0, neginf=0.0).astype(np.float32)


def augment_training_set(X_tr, y_tr, sensor_cols, config, copies_per_sample=1, random_state=42):
    if copies_per_sample <= 0 or len(X_tr) == 0:
        return X_tr, y_tr
    rng = np.random.default_rng(random_state)
    X_aug, y_aug = [], []
    for trial, label in zip(X_tr, y_tr):
        for _ in range(copies_per_sample):
            X_aug.append(apply_augmentations(trial, sensor_cols, config, rng))
            y_aug.append(label)
    X_combined = np.concatenate([X_tr, np.stack(X_aug, axis=0)], axis=0)
    y_combined = np.concatenate([y_tr, np.array(y_aug, dtype=y_tr.dtype)], axis=0)
    return X_combined, y_combined

# %% [markdown]
# ## 8. CNN model and scaler helper
#
# `scale_train_val_test` fits the scaler on the training fold only, then applies it to validation and to a copy of the hold-out test set so we always have a correctly-scaled view of the test set per fold.

# %%
def build_cnn_model(sequence_length, n_channels, n_classes):
    model = Sequential([
        Conv1D(32, kernel_size=4, activation='relu', input_shape=(sequence_length, n_channels)),
        MaxPooling1D(pool_size=2),
        Conv1D(64, kernel_size=4, activation='relu'),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(n_classes, activation='softmax'),
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model


def make_scaler(kind):
    if kind == 'standard':
        return StandardScaler()
    if kind == 'minmax':
        return MinMaxScaler()
    return None


def scale_sets(X_train, X_val, X_test, kind):
    """Fit on train only; transform val and test."""
    scaler = make_scaler(kind)
    if scaler is None:
        return X_train, X_val, X_test, None
    Nt, T, C = X_train.shape
    Xt = scaler.fit_transform(X_train.reshape(Nt, T * C)).reshape(Nt, T, C).astype(np.float32)
    Xv = scaler.transform(X_val.reshape(X_val.shape[0], T * C)).reshape(X_val.shape[0], T, C).astype(np.float32) \
         if len(X_val) else X_val
    Xs = scaler.transform(X_test.reshape(X_test.shape[0], T * C)).reshape(X_test.shape[0], T, C).astype(np.float32) \
         if len(X_test) else X_test
    return Xt, Xv, Xs, scaler

# %% [markdown]
# ## 8b. CNN architecture variants
#
# We compare several 1D-CNN architectures using the same data, splits, CV folds, augmentation, scaler, and training loop. Each entry in `VARIANTS` is `(name, description, builder)` and the rest of the notebook iterates over it.
#
# Variants:
#
# - **Baseline** — the original 2-block CNN.
# - **Shallow** — single Conv block, fewer params.
# - **Deep** — three Conv blocks for more depth.
# - **BN_GAP** — BatchNorm + GlobalAveragePooling head, typically generalises better.
# - **WideKernel** — larger Conv kernels for a bigger temporal receptive field.
# - **CNN_LSTM** — Conv1D front-end feeding an LSTM that models temporal dynamics across the gesture.
# - **CNN_BiLSTM** — same Conv front-end, but a Bidirectional LSTM so each step sees both past and future context within the trial.

# %% [markdown]
# ## 9. Cross-validation (augmentation inside each fold)
#
# For every fold:
# 1. Split `X_train_pool` into fold train / fold val.
# 2. Augment **only** fold train.
# 3. Fit scaler on fold train; transform fold val and the (separate) hold-out test.
# 4. Train a fresh CNN; record validation accuracy.
#
# We keep the best-fold model as a starting point, but the final reported test accuracy comes from a clean retrain on the full training pool (next cell).

# %%
# Per-variant cross-validation. Reuses augment_training_set / scale_sets / build_*
# from the helper cells above. The familiar legacy variables (cv_histories,
# cv_fold_results, cv_mean_accuracy, cv_std_accuracy, best_cv_fold_index) end up
# pointing at the LAST variant trained, so existing downstream cells still run.
import tensorflow as tf

variant_results = []  # reset on re-run

for v_name, v_desc, v_builder in VARIANTS:
    print(f'\n{"="*72}\n  Variant: {v_name}\n{"="*72}')
    cv_histories = []
    cv_fold_results = []
    cv_mean_accuracy = None
    cv_std_accuracy = None
    best_cv_fold_index = None

    if RUN_CROSS_VALIDATION and CV_FOLDS > 1:
        skf = StratifiedKFold(n_splits=CV_FOLDS, shuffle=CV_SHUFFLE,
                              random_state=RANDOM_STATE if CV_SHUFFLE else None)
        for fold_idx, (tr_idx, va_idx) in enumerate(skf.split(X_train_pool, y_train_pool), start=1):
            X_tr, y_tr = X_train_pool[tr_idx].copy(), y_train_pool[tr_idx].copy()
            X_va, y_va = X_train_pool[va_idx].copy(), y_train_pool[va_idx].copy()

            if AUGMENT_TRAINING_DATA:
                X_tr, y_tr = augment_training_set(
                    X_tr, y_tr,
                    sensor_cols=SENSOR_COLS,
                    config=AUGMENT_CONFIG,
                    copies_per_sample=AUGMENTATION_COPIES_PER_SAMPLE,
                    random_state=AUGMENTATION_RANDOM_SEED + fold_idx,
                )

            X_tr_s, X_va_s, _, _ = scale_sets(X_tr, X_va, X_test, NORMALISATION)

            tf.keras.backend.clear_session()
            tf.random.set_seed(RANDOM_STATE + fold_idx)
            fold_model = v_builder(sequence_length, n_channels, n_classes)
            _cbs = []
            if EARLY_STOPPING_ENABLED:
                _cbs.append(tf.keras.callbacks.EarlyStopping(
                    monitor=EARLY_STOPPING_MONITOR,
                    patience=EARLY_STOPPING_PATIENCE,
                    min_delta=EARLY_STOPPING_MIN_DELTA,
                    mode=('max' if EARLY_STOPPING_MONITOR.endswith('accuracy') else 'min'),
                    restore_best_weights=EARLY_STOPPING_RESTORE_BEST,
                    verbose=EARLY_STOPPING_VERBOSE,
                ))
            history = fold_model.fit(
                X_tr_s, y_tr,
                epochs=TRAIN_EPOCHS, batch_size=TRAIN_BATCH_SIZE,
                validation_data=(X_va_s, y_va), verbose=TRAIN_VERBOSE,
                callbacks=_cbs,
            )
            val_pred = np.argmax(fold_model.predict(X_va_s, verbose=0), axis=1)
            val_acc = float(accuracy_score(y_va, val_pred))

            _epochs_run = len(history.history.get('loss', []))
            _best_epoch = (int(np.argmin(history.history['val_loss'])) + 1
                            if 'val_loss' in history.history else _epochs_run)
            cv_histories.append(history.history)
            cv_fold_results.append({
                'fold': fold_idx,
                'train_after_aug': int(X_tr.shape[0]),
                'val_samples': int(len(va_idx)),
                'val_accuracy': val_acc,
                'best_val_accuracy': float(max(history.history.get('val_accuracy', [val_acc]))),
                'final_val_accuracy': float(history.history.get('val_accuracy', [val_acc])[-1]),
                'epochs_run': _epochs_run,
                'best_epoch': _best_epoch,
            })
            print(f'  Fold {fold_idx}/{CV_FOLDS}: val_acc={val_acc:.4f}  (epochs_run={_epochs_run}, best_epoch={_best_epoch})')

        val_accs = [r['val_accuracy'] for r in cv_fold_results]
        cv_mean_accuracy = float(np.mean(val_accs))
        cv_std_accuracy  = float(np.std(val_accs))
        best_cv_fold_index = int(np.argmax(val_accs)) + 1
        print(f'  CV mean: {cv_mean_accuracy:.4f} ± {cv_std_accuracy:.4f}, best fold {best_cv_fold_index}')

    variant_results.append({
        'name': v_name,
        'description': v_desc,
        'builder': v_builder,
        'cv_histories': cv_histories,
        'cv_fold_results': cv_fold_results,
        'cv_mean': cv_mean_accuracy,
        'cv_std':  cv_std_accuracy,
        'best_cv_fold_index': best_cv_fold_index,
    })
# Out:
# ========================================================================
#   Variant: Baseline
# ========================================================================
# Epoch 1/60
# I0000 00:00:1778763378.540482 1788373 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1617738__.31
# 37/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2458 - loss: 1.7070
# I0000 00:00:1778763379.812809 1788380 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1617738__.31
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.3493 - loss: 1.4599 - val_accuracy: 0.5714 - val_loss: 1.0212
# Epoch 2/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6013 - loss: 0.9411 - val_accuracy: 0.6429 - val_loss: 0.7829
# Epoch 3/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6893 - loss: 0.6600 - val_accuracy: 0.8333 - val_loss: 0.4259
# Epoch 4/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8040 - loss: 0.4769 - val_accuracy: 0.7619 - val_loss: 0.4948
# Epoch 5/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8440 - loss: 0.4064 - val_accuracy: 1.0000 - val_loss: 0.1926
# Epoch 6/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9267 - loss: 0.2428 - val_accuracy: 0.9524 - val_loss: 0.1643
# Epoch 7/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9613 - loss: 0.1538 - val_accuracy: 0.9762 - val_loss: 0.0745
# Epoch 8/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9760 - loss: 0.1021 - val_accuracy: 0.9762 - val_loss: 0.0719
# Epoch 9/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9613 - loss: 0.1352 - val_accuracy: 0.9762 - val_loss: 0.0795
# Epoch 10/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9827 - loss: 0.0645 - val_accuracy: 1.0000 - val_loss: 0.0091
# Epoch 11/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9933 - loss: 0.0361 - val_accuracy: 1.0000 - val_loss: 0.0165
# Epoch 12/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9907 - loss: 0.0411 - val_accuracy: 1.0000 - val_loss: 0.0144
# Epoch 13/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9867 - loss: 0.0402 - val_accuracy: 1.0000 - val_loss: 0.0111
# Epoch 14/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9787 - loss: 0.0841 - val_accuracy: 0.8810 - val_loss: 0.4442
# Epoch 15/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9773 - loss: 0.0866 - val_accuracy: 1.0000 - val_loss: 0.0272
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 10.
#   Fold 1/7: val_acc=1.0000  (epochs_run=15, best_epoch=10)
# Epoch 1/60
# I0000 00:00:1778763389.891239 1788378 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1623579__.31
# 44/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3443 - loss: 1.5417
# I0000 00:00:1778763391.152156 1788380 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1623579__.31
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 0.4773 - loss: 1.2247 - val_accuracy: 0.5000 - val_loss: 1.0876
# Epoch 2/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6547 - loss: 0.7877 - val_accuracy: 0.6429 - val_loss: 0.6032
# Epoch 3/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7373 - loss: 0.6010 - val_accuracy: 0.7857 - val_loss: 0.4382
# Epoch 4/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7640 - loss: 0.5214 - val_accuracy: 0.7857 - val_loss: 0.3662
# Epoch 5/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8373 - loss: 0.3769 - val_accuracy: 0.8095 - val_loss: 0.3171
# Epoch 6/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8427 - loss: 0.3637 - val_accuracy: 0.9524 - val_loss: 0.1920
# Epoch 7/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8920 - loss: 0.2518 - val_accuracy: 0.9048 - val_loss: 0.1742
# Epoch 8/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9253 - loss: 0.2133 - val_accuracy: 0.9048 - val_loss: 0.1660
# Epoch 9/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9707 - loss: 0.1335 - val_accuracy: 1.0000 - val_loss: 0.0570
# Epoch 10/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9707 - loss: 0.1176 - val_accuracy: 0.9048 - val_loss: 0.1615
# Epoch 11/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9787 - loss: 0.1002 - val_accuracy: 0.9048 - val_loss: 0.1229
# Epoch 12/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9493 - loss: 0.1557 - val_accuracy: 1.0000 - val_loss: 0.0231
# Epoch 13/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9787 - loss: 0.0694 - val_accuracy: 1.0000 - val_loss: 0.0409
# Epoch 14/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9853 - loss: 0.0529 - val_accuracy: 1.0000 - val_loss: 0.0096
# Epoch 15/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9973 - loss: 0.0292 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 16/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9747 - loss: 0.0994 - val_accuracy: 1.0000 - val_loss: 0.0230
# Epoch 17/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9920 - loss: 0.0307 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 18/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9947 - loss: 0.0214 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 19/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9973 - loss: 0.0135 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 20/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9960 - loss: 0.0160 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 21/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9960 - loss: 0.0129 - val_accuracy: 1.0000 - val_loss: 3.7586e-04
# Epoch 22/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9813 - loss: 0.0714 - val_accuracy: 0.9524 - val_loss: 0.0931
# Epoch 23/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9920 - loss: 0.0297 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 24/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9893 - loss: 0.0503 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 25/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 26/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0096 - val_accuracy: 1.0000 - val_loss: 5.9345e-04
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 21.
#   Fold 2/7: val_acc=1.0000  (epochs_run=26, best_epoch=21)
# Epoch 1/60
# I0000 00:00:1778763404.996543 1788373 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1632029__.31
# 36/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3139 - loss: 1.6015
# I0000 00:00:1778763406.359309 1788373 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1632029__.31
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.4453 - loss: 1.3038 - val_accuracy: 0.4762 - val_loss: 1.0089
# Epoch 2/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6120 - loss: 0.7981 - val_accuracy: 0.6905 - val_loss: 0.7363
# Epoch 3/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7080 - loss: 0.5811 - val_accuracy: 0.7381 - val_loss: 0.6303
# Epoch 4/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7413 - loss: 0.5127 - val_accuracy: 0.7381 - val_loss: 0.5417
# Epoch 5/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8053 - loss: 0.3778 - val_accuracy: 0.7619 - val_loss: 0.6237
# Epoch 6/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8053 - loss: 0.3426 - val_accuracy: 0.7857 - val_loss: 0.5092
# Epoch 7/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8333 - loss: 0.2660 - val_accuracy: 0.7857 - val_loss: 0.5679
# Epoch 8/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8627 - loss: 0.2591 - val_accuracy: 0.8095 - val_loss: 0.4946
# Epoch 9/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8547 - loss: 0.2664 - val_accuracy: 0.8095 - val_loss: 0.5187
# Epoch 10/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8800 - loss: 0.2443 - val_accuracy: 0.9048 - val_loss: 0.4460
# Epoch 11/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8587 - loss: 0.2818 - val_accuracy: 0.7857 - val_loss: 0.5123
# Epoch 12/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8840 - loss: 0.2284 - val_accuracy: 0.9286 - val_loss: 0.3725
# Epoch 13/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9360 - loss: 0.1799 - val_accuracy: 0.9762 - val_loss: 0.3772
# Epoch 14/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9373 - loss: 0.1905 - val_accuracy: 0.9286 - val_loss: 0.4221
# Epoch 15/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9440 - loss: 0.1462 - val_accuracy: 0.8333 - val_loss: 0.4392
# Epoch 16/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9693 - loss: 0.1018 - val_accuracy: 0.9524 - val_loss: 0.4102
# Epoch 17/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9800 - loss: 0.0627 - val_accuracy: 0.9524 - val_loss: 0.4726
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 12.
#   Fold 3/7: val_acc=0.9286  (epochs_run=17, best_epoch=12)
# Epoch 1/60
# I0000 00:00:1778763417.409786 1788374 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1638324__.31
# 35/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2721 - loss: 1.6682
# I0000 00:00:1778763418.563254 1788373 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1638324__.31
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.4013 - loss: 1.3362 - val_accuracy: 0.6905 - val_loss: 0.7587
# Epoch 2/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6813 - loss: 0.7347 - val_accuracy: 0.6429 - val_loss: 0.6477
# Epoch 3/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7000 - loss: 0.6673 - val_accuracy: 0.7381 - val_loss: 0.5061
# Epoch 4/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7493 - loss: 0.5279 - val_accuracy: 0.8810 - val_loss: 0.3550
# Epoch 5/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8560 - loss: 0.3797 - val_accuracy: 0.8333 - val_loss: 0.3132
# Epoch 6/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9053 - loss: 0.2767 - val_accuracy: 0.9286 - val_loss: 0.1933
# Epoch 7/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9267 - loss: 0.2212 - val_accuracy: 0.9762 - val_loss: 0.1079
# Epoch 8/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9493 - loss: 0.1732 - val_accuracy: 0.9762 - val_loss: 0.0998
# Epoch 9/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9587 - loss: 0.1400 - val_accuracy: 0.9524 - val_loss: 0.1593
# Epoch 10/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9520 - loss: 0.1422 - val_accuracy: 1.0000 - val_loss: 0.0422
# Epoch 11/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9827 - loss: 0.0794 - val_accuracy: 1.0000 - val_loss: 0.0170
# Epoch 12/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9920 - loss: 0.0413 - val_accuracy: 1.0000 - val_loss: 0.0071
# Epoch 13/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9920 - loss: 0.0510 - val_accuracy: 1.0000 - val_loss: 0.0274
# Epoch 14/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9960 - loss: 0.0218 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 15/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9960 - loss: 0.0174 - val_accuracy: 1.0000 - val_loss: 0.0073
# Epoch 16/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9933 - loss: 0.0220 - val_accuracy: 1.0000 - val_loss: 0.0373
# Epoch 17/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9880 - loss: 0.0450 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 18/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9960 - loss: 0.0143 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 19/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9973 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 0.0220
# Epoch 20/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9947 - loss: 0.0166 - val_accuracy: 1.0000 - val_loss: 0.0200
# Epoch 21/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9973 - loss: 0.0107 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 22/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.8810 - val_loss: 0.5604
# Epoch 23/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9627 - loss: 0.1503 - val_accuracy: 1.0000 - val_loss: 0.0707
# Epoch 24/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9640 - loss: 0.1076 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 25/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9747 - loss: 0.0974 - val_accuracy: 0.9286 - val_loss: 0.1001
# Epoch 26/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9893 - loss: 0.0408 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 21.
#   Fold 4/7: val_acc=1.0000  (epochs_run=26, best_epoch=21)
# Epoch 1/60
# I0000 00:00:1778763431.632071 1788377 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1646774__.31
# 36/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2977 - loss: 1.5756
# I0000 00:00:1778763432.699788 1788373 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1646774__.31
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 0.4187 - loss: 1.2765 - val_accuracy: 0.5238 - val_loss: 0.8333
# Epoch 2/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5693 - loss: 0.8720 - val_accuracy: 0.6905 - val_loss: 0.6591
# Epoch 3/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6867 - loss: 0.6913 - val_accuracy: 0.8333 - val_loss: 0.5187
# Epoch 4/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7920 - loss: 0.5226 - val_accuracy: 0.8095 - val_loss: 0.4291
# Epoch 5/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8907 - loss: 0.3363 - val_accuracy: 0.9286 - val_loss: 0.2518
# Epoch 6/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9320 - loss: 0.2471 - val_accuracy: 0.9048 - val_loss: 0.1818
# Epoch 7/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9493 - loss: 0.1769 - val_accuracy: 0.8810 - val_loss: 0.3001
# Epoch 8/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9600 - loss: 0.1487 - val_accuracy: 0.9762 - val_loss: 0.0814
# Epoch 9/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9547 - loss: 0.1401 - val_accuracy: 0.9762 - val_loss: 0.1334
# Epoch 10/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9680 - loss: 0.1098 - val_accuracy: 1.0000 - val_loss: 0.0357
# Epoch 11/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9893 - loss: 0.0447 - val_accuracy: 0.9762 - val_loss: 0.0546
# Epoch 12/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9813 - loss: 0.0676 - val_accuracy: 1.0000 - val_loss: 0.0325
# Epoch 13/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9920 - loss: 0.0455 - val_accuracy: 0.9762 - val_loss: 0.0418
# Epoch 14/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9760 - loss: 0.0934 - val_accuracy: 0.9762 - val_loss: 0.0453
# Epoch 15/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9947 - loss: 0.0417 - val_accuracy: 0.9762 - val_loss: 0.0377
# Epoch 16/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9947 - loss: 0.0284 - val_accuracy: 1.0000 - val_loss: 0.0193
# Epoch 17/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9693 - loss: 0.0967 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 18/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9960 - loss: 0.0226 - val_accuracy: 1.0000 - val_loss: 0.0107
# Epoch 19/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9813 - loss: 0.0567 - val_accuracy: 1.0000 - val_loss: 0.0145
# Epoch 20/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9947 - loss: 0.0228 - val_accuracy: 0.9762 - val_loss: 0.0629
# Epoch 21/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9960 - loss: 0.0158 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 22/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9973 - loss: 0.0099 - val_accuracy: 0.9762 - val_loss: 0.0388
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 17.
#   Fold 5/7: val_acc=1.0000  (epochs_run=22, best_epoch=17)
# Epoch 1/60
# I0000 00:00:1778763444.906325 1788377 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1654252__.31
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.4050 - loss: 1.4059 - val_accuracy: 0.5610 - val_loss: 0.8873
# Epoch 2/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6441 - loss: 0.8399 - val_accuracy: 0.8293 - val_loss: 0.5911
# Epoch 3/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7278 - loss: 0.6257 - val_accuracy: 0.8293 - val_loss: 0.5210
# Epoch 4/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7676 - loss: 0.5532 - val_accuracy: 0.8293 - val_loss: 0.5348
# Epoch 5/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8167 - loss: 0.4462 - val_accuracy: 0.8780 - val_loss: 0.3475
# Epoch 6/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8446 - loss: 0.4275 - val_accuracy: 0.9268 - val_loss: 0.3210
# Epoch 7/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9070 - loss: 0.2687 - val_accuracy: 1.0000 - val_loss: 0.1443
# Epoch 8/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8725 - loss: 0.3536 - val_accuracy: 0.8537 - val_loss: 0.3553
# Epoch 9/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9256 - loss: 0.2423 - val_accuracy: 0.9024 - val_loss: 0.2441
# Epoch 10/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8938 - loss: 0.2687 - val_accuracy: 0.9756 - val_loss: 0.2536
# Epoch 11/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9588 - loss: 0.1358 - val_accuracy: 0.9756 - val_loss: 0.0437
# Epoch 12/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9854 - loss: 0.0761 - val_accuracy: 0.9756 - val_loss: 0.0671
# Epoch 13/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9668 - loss: 0.1011 - val_accuracy: 1.0000 - val_loss: 0.0357
# Epoch 14/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9867 - loss: 0.0537 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 15/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9920 - loss: 0.0391 - val_accuracy: 1.0000 - val_loss: 0.0133
# Epoch 16/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9960 - loss: 0.0254 - val_accuracy: 1.0000 - val_loss: 0.0091
# Epoch 17/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9947 - loss: 0.0259 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 18/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9934 - loss: 0.0277 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 19/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9907 - loss: 0.0264 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 20/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9960 - loss: 0.0271 - val_accuracy: 1.0000 - val_loss: 0.0104
# Epoch 21/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9655 - loss: 0.1171 - val_accuracy: 0.6341 - val_loss: 1.6647
# Epoch 22/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9256 - loss: 0.2112 - val_accuracy: 1.0000 - val_loss: 0.0113
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 17.
#   Fold 6/7: val_acc=1.0000  (epochs_run=22, best_epoch=17)
# Epoch 1/60
# I0000 00:00:1778763460.415464 1788377 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1661802__.31
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.4489 - loss: 1.2841 - val_accuracy: 0.5854 - val_loss: 0.8532
# Epoch 2/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6268 - loss: 0.8496 - val_accuracy: 0.6829 - val_loss: 0.6001
# Epoch 3/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7012 - loss: 0.6224 - val_accuracy: 0.8780 - val_loss: 0.4559
# Epoch 4/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7649 - loss: 0.5282 - val_accuracy: 0.8780 - val_loss: 0.4124
# Epoch 5/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8579 - loss: 0.3706 - val_accuracy: 0.9512 - val_loss: 0.2625
# Epoch 6/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9110 - loss: 0.2766 - val_accuracy: 0.9268 - val_loss: 0.1670
# Epoch 7/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9535 - loss: 0.1720 - val_accuracy: 0.9756 - val_loss: 0.0926
# Epoch 8/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9602 - loss: 0.1428 - val_accuracy: 0.9756 - val_loss: 0.1135
# Epoch 9/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9788 - loss: 0.0923 - val_accuracy: 0.9268 - val_loss: 0.1066
# Epoch 10/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9867 - loss: 0.0539 - val_accuracy: 0.9756 - val_loss: 0.0409
# Epoch 11/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9934 - loss: 0.0469 - val_accuracy: 0.9756 - val_loss: 0.0277
# Epoch 12/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9947 - loss: 0.0367 - val_accuracy: 0.9756 - val_loss: 0.0352
# Epoch 13/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9867 - loss: 0.0539 - val_accuracy: 0.8780 - val_loss: 0.2171
# Epoch 14/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9894 - loss: 0.0474 - val_accuracy: 1.0000 - val_loss: 0.0113
# Epoch 15/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9934 - loss: 0.0316 - val_accuracy: 0.9756 - val_loss: 0.0238
# Epoch 16/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9827 - loss: 0.0631 - val_accuracy: 1.0000 - val_loss: 0.0128
# Epoch 17/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9774 - loss: 0.0925 - val_accuracy: 0.9512 - val_loss: 0.1502
# Epoch 18/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9841 - loss: 0.0484 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 19/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9947 - loss: 0.0190 - val_accuracy: 1.0000 - val_loss: 0.0116
# Epoch 20/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9920 - loss: 0.0302 - val_accuracy: 1.0000 - val_loss: 0.0216
# Epoch 21/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9920 - loss: 0.0250 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 22/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9509 - loss: 0.1838 - val_accuracy: 0.9756 - val_loss: 0.0451
# Epoch 23/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9934 - loss: 0.0412 - val_accuracy: 1.0000 - val_loss: 0.0084
# Epoch 24/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9960 - loss: 0.0217 - val_accuracy: 1.0000 - val_loss: 0.0167
# Epoch 25/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9973 - loss: 0.0115 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 26/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9973 - loss: 0.0181 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 27/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9960 - loss: 0.0151 - val_accuracy: 1.0000 - val_loss: 0.0249
# Epoch 28/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9947 - loss: 0.0157 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 29/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9973 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 30/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9973 - loss: 0.0087 - val_accuracy: 0.9756 - val_loss: 0.0291
# Epoch 31/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9987 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 5.5227e-04
# Epoch 32/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0133
# Epoch 33/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9973 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 0.0219
# Epoch 34/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9987 - loss: 0.0125 - val_accuracy: 0.9756 - val_loss: 0.0286
# Epoch 35/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9987 - loss: 0.0085 - val_accuracy: 0.9756 - val_loss: 0.0776
# Epoch 36/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9004 - loss: 0.3439 - val_accuracy: 0.8049 - val_loss: 0.3353
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 31.
#   Fold 7/7: val_acc=1.0000  (epochs_run=36, best_epoch=31)
#   CV mean: 0.9898 ± 0.0250, best fold 1
#
# ========================================================================
#   Variant: Deep
# ========================================================================
# Epoch 1/60
# I0000 00:00:1778763478.268419 1788380 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1673036__.40
# 46/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3769 - loss: 1.4572
# I0000 00:00:1778763479.591714 1788377 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1673036__.40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.4693 - loss: 1.2212 - val_accuracy: 0.6905 - val_loss: 0.8725
# Epoch 2/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6627 - loss: 0.7735 - val_accuracy: 0.6667 - val_loss: 0.6029
# Epoch 3/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7067 - loss: 0.6163 - val_accuracy: 0.7619 - val_loss: 0.4712
# Epoch 4/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7587 - loss: 0.5322 - val_accuracy: 0.8095 - val_loss: 0.3482
# Epoch 5/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8413 - loss: 0.3627 - val_accuracy: 0.8810 - val_loss: 0.2827
# Epoch 6/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9333 - loss: 0.2045 - val_accuracy: 0.9524 - val_loss: 0.1144
# Epoch 7/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9333 - loss: 0.2010 - val_accuracy: 0.9762 - val_loss: 0.0846
# Epoch 8/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9600 - loss: 0.1613 - val_accuracy: 0.9524 - val_loss: 0.1731
# Epoch 9/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9840 - loss: 0.0694 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 10/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9907 - loss: 0.0339 - val_accuracy: 0.9286 - val_loss: 0.2814
# Epoch 11/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9867 - loss: 0.0345 - val_accuracy: 0.9762 - val_loss: 0.0795
# Epoch 12/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9960 - loss: 0.0220 - val_accuracy: 1.0000 - val_loss: 8.8969e-04
# Epoch 13/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9933 - loss: 0.0338 - val_accuracy: 1.0000 - val_loss: 0.0192
# Epoch 14/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9893 - loss: 0.0256 - val_accuracy: 1.0000 - val_loss: 8.9464e-04
# Epoch 15/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9760 - loss: 0.0907 - val_accuracy: 0.9762 - val_loss: 0.0300
# Epoch 16/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9693 - loss: 0.0831 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 17/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9680 - loss: 0.1118 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 12.
#   Fold 1/7: val_acc=1.0000  (epochs_run=17, best_epoch=12)
# Epoch 1/60
# I0000 00:00:1778763491.328792 1788377 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1679824__.40
# 42/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2926 - loss: 1.6643
# I0000 00:00:1778763492.738833 1788377 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1679824__.40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.3853 - loss: 1.3750 - val_accuracy: 0.4286 - val_loss: 1.1142
# Epoch 2/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5773 - loss: 0.8290 - val_accuracy: 0.7143 - val_loss: 0.5968
# Epoch 3/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6627 - loss: 0.6618 - val_accuracy: 0.7381 - val_loss: 0.4770
# Epoch 4/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7067 - loss: 0.6091 - val_accuracy: 0.7857 - val_loss: 0.4268
# Epoch 5/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7867 - loss: 0.4746 - val_accuracy: 0.8095 - val_loss: 0.4274
# Epoch 6/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8000 - loss: 0.4269 - val_accuracy: 0.9762 - val_loss: 0.2061
# Epoch 7/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9093 - loss: 0.2743 - val_accuracy: 0.9524 - val_loss: 0.1129
# Epoch 8/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9293 - loss: 0.2409 - val_accuracy: 0.9524 - val_loss: 0.2136
# Epoch 9/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9627 - loss: 0.1195 - val_accuracy: 0.9762 - val_loss: 0.0542
# Epoch 10/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9653 - loss: 0.1099 - val_accuracy: 1.0000 - val_loss: 0.0226
# Epoch 11/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9960 - loss: 0.0359 - val_accuracy: 1.0000 - val_loss: 0.0110
# Epoch 12/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9867 - loss: 0.0795 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 13/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9933 - loss: 0.0331 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 14/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9920 - loss: 0.0291 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 15/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9733 - loss: 0.0995 - val_accuracy: 0.8571 - val_loss: 0.3561
# Epoch 16/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9840 - loss: 0.0612 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 17/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9947 - loss: 0.0339 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 18/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9960 - loss: 0.0201 - val_accuracy: 1.0000 - val_loss: 9.3741e-04
# Epoch 19/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9960 - loss: 0.0225 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 20/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9973 - loss: 0.0138 - val_accuracy: 1.0000 - val_loss: 2.2586e-04
# Epoch 21/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9973 - loss: 0.0143 - val_accuracy: 1.0000 - val_loss: 3.5538e-04
# Epoch 22/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9973 - loss: 0.0148 - val_accuracy: 1.0000 - val_loss: 2.6984e-04
# Epoch 23/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9947 - loss: 0.0232 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 24/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9973 - loss: 0.0102 - val_accuracy: 1.0000 - val_loss: 2.5358e-04
# Epoch 25/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9973 - loss: 0.0091 - val_accuracy: 1.0000 - val_loss: 8.8374e-05
# Epoch 26/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9960 - loss: 0.0098 - val_accuracy: 1.0000 - val_loss: 4.1306e-05
# Epoch 27/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 9.3562e-05
# Epoch 28/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 9.8405e-05
# Epoch 29/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 1.3600e-05
# Epoch 30/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 9.7203e-06
# Epoch 31/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9213 - loss: 0.3408 - val_accuracy: 0.8095 - val_loss: 0.8076
# Epoch 32/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9493 - loss: 0.1844 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 33/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 8.8585e-04
# Epoch 34/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 3.1557e-04
# Epoch 35/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 8.3824e-04 - val_accuracy: 1.0000 - val_loss: 2.0233e-04
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 30.
#   Fold 2/7: val_acc=1.0000  (epochs_run=35, best_epoch=30)
# Epoch 1/60
# I0000 00:00:1778763510.227705 1788373 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1690898__.40
# 42/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3032 - loss: 1.5611
# I0000 00:00:1778763511.800792 1788374 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1690898__.40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.4360 - loss: 1.2234 - val_accuracy: 0.6429 - val_loss: 0.7740
# Epoch 2/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6747 - loss: 0.7219 - val_accuracy: 0.7381 - val_loss: 0.6467
# Epoch 3/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7133 - loss: 0.6159 - val_accuracy: 0.8095 - val_loss: 0.6239
# Epoch 4/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8187 - loss: 0.4172 - val_accuracy: 0.8095 - val_loss: 0.4898
# Epoch 5/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9027 - loss: 0.2709 - val_accuracy: 0.9524 - val_loss: 0.3934
# Epoch 6/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9560 - loss: 0.1232 - val_accuracy: 0.9286 - val_loss: 0.3500
# Epoch 7/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9800 - loss: 0.0672 - val_accuracy: 0.9524 - val_loss: 0.3805
# Epoch 8/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9987 - loss: 0.0124 - val_accuracy: 0.9524 - val_loss: 0.3821
# Epoch 9/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9960 - loss: 0.0151 - val_accuracy: 0.9524 - val_loss: 0.4361
# Epoch 10/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9973 - loss: 0.0144 - val_accuracy: 0.9524 - val_loss: 0.3522
# Epoch 11/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0072 - val_accuracy: 0.9524 - val_loss: 0.4812
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.
#   Fold 3/7: val_acc=0.9286  (epochs_run=11, best_epoch=6)
# Epoch 1/60
# I0000 00:00:1778763521.504886 1788377 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1696264__.40
# 41/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2543 - loss: 1.5824
# I0000 00:00:1778763522.893599 1788377 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1696264__.40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.4293 - loss: 1.2514 - val_accuracy: 0.4762 - val_loss: 1.1104
# Epoch 2/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6267 - loss: 0.7697 - val_accuracy: 0.7143 - val_loss: 0.6450
# Epoch 3/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7227 - loss: 0.5711 - val_accuracy: 0.7619 - val_loss: 0.4526
# Epoch 4/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7973 - loss: 0.4125 - val_accuracy: 0.7381 - val_loss: 0.5128
# Epoch 5/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8080 - loss: 0.4047 - val_accuracy: 0.7857 - val_loss: 0.4441
# Epoch 6/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8307 - loss: 0.3754 - val_accuracy: 0.6905 - val_loss: 0.7755
# Epoch 7/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7880 - loss: 0.4644 - val_accuracy: 0.8333 - val_loss: 0.2847
# Epoch 8/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8493 - loss: 0.2869 - val_accuracy: 0.9048 - val_loss: 0.2040
# Epoch 9/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8920 - loss: 0.2306 - val_accuracy: 0.9048 - val_loss: 0.1999
# Epoch 10/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8773 - loss: 0.3428 - val_accuracy: 0.9286 - val_loss: 0.1441
# Epoch 11/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8893 - loss: 0.2436 - val_accuracy: 1.0000 - val_loss: 0.1046
# Epoch 12/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9560 - loss: 0.1345 - val_accuracy: 1.0000 - val_loss: 0.0380
# Epoch 13/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9613 - loss: 0.1215 - val_accuracy: 1.0000 - val_loss: 0.0637
# Epoch 14/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9707 - loss: 0.0754 - val_accuracy: 1.0000 - val_loss: 0.0236
# Epoch 15/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9813 - loss: 0.0680 - val_accuracy: 0.9048 - val_loss: 0.1338
# Epoch 16/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9800 - loss: 0.0584 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 17/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9933 - loss: 0.0188 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 18/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9960 - loss: 0.0118 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 19/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9960 - loss: 0.0128 - val_accuracy: 1.0000 - val_loss: 7.8018e-04
# Epoch 20/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9960 - loss: 0.0102 - val_accuracy: 1.0000 - val_loss: 5.6726e-04
# Epoch 21/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 2.8380e-04
# Epoch 22/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 2.7636e-04
# Epoch 23/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 7.8850e-04
# Epoch 24/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9907 - loss: 0.0264 - val_accuracy: 0.8810 - val_loss: 0.6968
# Epoch 25/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9773 - loss: 0.0851 - val_accuracy: 1.0000 - val_loss: 0.0095
# Epoch 26/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 3.0628e-04
# Epoch 27/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 1.2342e-04
# Epoch 28/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9987 - loss: 0.0055 - val_accuracy: 0.9762 - val_loss: 0.0218
# Epoch 29/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9933 - loss: 0.0207 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 30/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9973 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 2.6401e-04
# Epoch 31/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9947 - loss: 0.0177 - val_accuracy: 1.0000 - val_loss: 0.0700
# Epoch 32/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9973 - loss: 0.0082 - val_accuracy: 1.0000 - val_loss: 3.3267e-04
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 27.
#   Fold 4/7: val_acc=1.0000  (epochs_run=32, best_epoch=27)
# Epoch 1/60
# I0000 00:00:1778763539.631978 1788380 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1706637__.40
# 45/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2923 - loss: 1.6173
# I0000 00:00:1778763540.979140 1788378 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1706637__.40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.3973 - loss: 1.3399 - val_accuracy: 0.6905 - val_loss: 0.8246
# Epoch 2/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5693 - loss: 0.8808 - val_accuracy: 0.7857 - val_loss: 0.6923
# Epoch 3/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6853 - loss: 0.6641 - val_accuracy: 0.7381 - val_loss: 0.5807
# Epoch 4/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8387 - loss: 0.4206 - val_accuracy: 0.8571 - val_loss: 0.3341
# Epoch 5/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9547 - loss: 0.1825 - val_accuracy: 0.9762 - val_loss: 0.1255
# Epoch 6/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9893 - loss: 0.0703 - val_accuracy: 0.9762 - val_loss: 0.1344
# Epoch 7/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9920 - loss: 0.0463 - val_accuracy: 0.9762 - val_loss: 0.1888
# Epoch 8/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9933 - loss: 0.0399 - val_accuracy: 0.9762 - val_loss: 0.0376
# Epoch 9/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9187 - loss: 0.2751 - val_accuracy: 0.9762 - val_loss: 0.1753
# Epoch 10/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9933 - loss: 0.0326 - val_accuracy: 0.9762 - val_loss: 0.0945
# Epoch 11/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9960 - loss: 0.0274 - val_accuracy: 0.9762 - val_loss: 0.1557
# Epoch 12/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9960 - loss: 0.0255 - val_accuracy: 0.9762 - val_loss: 0.1446
# Epoch 13/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9960 - loss: 0.0239 - val_accuracy: 0.9762 - val_loss: 0.2150
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 8.
#   Fold 5/7: val_acc=0.9762  (epochs_run=13, best_epoch=8)
# Epoch 1/60
# I0000 00:00:1778763551.030175 1788380 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1712457__.40
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 6s 90ms/step - accuracy: 0.4648 - loss: 1.2450 - val_accuracy: 0.5610 - val_loss: 0.9149
# Epoch 2/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6109 - loss: 0.8634 - val_accuracy: 0.6829 - val_loss: 0.5761
# Epoch 3/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6627 - loss: 0.7435 - val_accuracy: 0.6585 - val_loss: 0.6055
# Epoch 4/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7331 - loss: 0.5761 - val_accuracy: 0.7805 - val_loss: 0.4302
# Epoch 5/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7676 - loss: 0.5115 - val_accuracy: 0.7805 - val_loss: 0.3970
# Epoch 6/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8141 - loss: 0.4005 - val_accuracy: 0.8049 - val_loss: 0.3087
# Epoch 7/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8606 - loss: 0.3557 - val_accuracy: 0.9024 - val_loss: 0.2450
# Epoch 8/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8991 - loss: 0.2870 - val_accuracy: 1.0000 - val_loss: 0.0783
# Epoch 9/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9708 - loss: 0.1019 - val_accuracy: 0.9512 - val_loss: 0.0783
# Epoch 10/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9880 - loss: 0.0625 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 11/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9920 - loss: 0.0397 - val_accuracy: 1.0000 - val_loss: 0.0102
# Epoch 12/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9920 - loss: 0.0309 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 13/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9867 - loss: 0.0489 - val_accuracy: 0.7561 - val_loss: 0.5914
# Epoch 14/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9602 - loss: 0.1406 - val_accuracy: 0.9512 - val_loss: 0.0638
# Epoch 15/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9960 - loss: 0.0224 - val_accuracy: 1.0000 - val_loss: 3.7446e-04
# Epoch 16/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9987 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 4.7728e-04
# Epoch 17/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 9.5162e-05
# Epoch 18/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9987 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 4.9647e-05
# Epoch 19/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 7.4636e-05
# Epoch 20/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 3.7677e-05
# Epoch 21/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 1.4351e-05
# Epoch 22/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9721 - loss: 0.1117 - val_accuracy: 0.8780 - val_loss: 0.3726
# Epoch 23/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9163 - loss: 0.3147 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 24/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9947 - loss: 0.0218 - val_accuracy: 1.0000 - val_loss: 0.0083
# Epoch 25/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 8.3823e-04
# Epoch 26/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9960 - loss: 0.0166 - val_accuracy: 1.0000 - val_loss: 9.6041e-04
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 21.
#   Fold 6/7: val_acc=1.0000  (epochs_run=26, best_epoch=21)
# Epoch 1/60
# I0000 00:00:1778763573.770240 1788377 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1721512__.40
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.4316 - loss: 1.2708 - val_accuracy: 0.5366 - val_loss: 0.9092
# Epoch 2/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6308 - loss: 0.8046 - val_accuracy: 0.7073 - val_loss: 0.6539
# Epoch 3/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6799 - loss: 0.6773 - val_accuracy: 0.6585 - val_loss: 0.6809
# Epoch 4/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7065 - loss: 0.5889 - val_accuracy: 0.6585 - val_loss: 0.7401
# Epoch 5/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7822 - loss: 0.4654 - val_accuracy: 0.9756 - val_loss: 0.2949
# Epoch 6/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8127 - loss: 0.4406 - val_accuracy: 0.8049 - val_loss: 0.3548
# Epoch 7/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8818 - loss: 0.3048 - val_accuracy: 0.9756 - val_loss: 0.1688
# Epoch 8/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9456 - loss: 0.1570 - val_accuracy: 0.8293 - val_loss: 0.6537
# Epoch 9/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9296 - loss: 0.2244 - val_accuracy: 0.9268 - val_loss: 0.4702
# Epoch 10/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9389 - loss: 0.2075 - val_accuracy: 0.7805 - val_loss: 0.7247
# Epoch 11/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9894 - loss: 0.0567 - val_accuracy: 1.0000 - val_loss: 0.0111
# Epoch 12/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9947 - loss: 0.0300 - val_accuracy: 1.0000 - val_loss: 0.0115
# Epoch 13/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9947 - loss: 0.0225 - val_accuracy: 0.9756 - val_loss: 0.0432
# Epoch 14/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9947 - loss: 0.0194 - val_accuracy: 0.9756 - val_loss: 0.0320
# Epoch 15/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9960 - loss: 0.0182 - val_accuracy: 1.0000 - val_loss: 0.0107
# Epoch 16/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9827 - loss: 0.0688 - val_accuracy: 0.9756 - val_loss: 0.0815
# Epoch 17/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9934 - loss: 0.0328 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 18/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9947 - loss: 0.0231 - val_accuracy: 0.9024 - val_loss: 0.2728
# Epoch 19/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9880 - loss: 0.0463 - val_accuracy: 0.9756 - val_loss: 0.0293
# Epoch 20/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9947 - loss: 0.0168 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 21/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9960 - loss: 0.0169 - val_accuracy: 1.0000 - val_loss: 0.0070
# Epoch 22/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9987 - loss: 0.0079 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 23/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9920 - loss: 0.0167 - val_accuracy: 0.6341 - val_loss: 3.6925
# Epoch 24/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9429 - loss: 0.2761 - val_accuracy: 0.7561 - val_loss: 1.2183
# Epoch 25/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8911 - loss: 0.4783 - val_accuracy: 1.0000 - val_loss: 0.0324
# Epoch 26/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9774 - loss: 0.0758 - val_accuracy: 1.0000 - val_loss: 0.0261
# Epoch 27/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9960 - loss: 0.0194 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 22.
#   Fold 7/7: val_acc=1.0000  (epochs_run=27, best_epoch=22)
#   CV mean: 0.9864 ± 0.0250, best fold 1
#
# ========================================================================
#   Variant: BN_GAP
# ========================================================================
# Epoch 1/60
# I0000 00:00:1778763592.844297 1788377 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1731720__.48
# 45/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6120 - loss: 1.0649
# ...
# Epoch 17/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9453 - loss: 0.1586 - val_accuracy: 0.8571 - val_loss: 0.4253
# Epoch 18/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9133 - loss: 0.2512 - val_accuracy: 0.8333 - val_loss: 0.4229
# Epoch 19/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9747 - loss: 0.0945 - val_accuracy: 0.9524 - val_loss: 0.2684
# Epoch 20/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9893 - loss: 0.0422 - val_accuracy: 0.9762 - val_loss: 0.2240
# Epoch 21/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9960 - loss: 0.0278 - val_accuracy: 0.9524 - val_loss: 0.2672
# Epoch 22/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.9762 - val_loss: 0.2578
# Epoch 23/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.9762 - val_loss: 0.2224
# Epoch 24/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9040 - loss: 0.3120 - val_accuracy: 0.8095 - val_loss: 0.4029
# Epoch 25/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9613 - loss: 0.1399 - val_accuracy: 0.9762 - val_loss: 0.2282
# Epoch 26/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9853 - loss: 0.0447 - val_accuracy: 0.9524 - val_loss: 0.4240
# Epoch 27/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9907 - loss: 0.0443 - val_accuracy: 0.9762 - val_loss: 0.2380
# Epoch 28/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9762 - val_loss: 0.2956
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 23.
#   Fold 3/7: val_acc=0.9762  (epochs_run=28, best_epoch=23)
# Epoch 1/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.3360 - loss: 1.6312 - val_accuracy: 0.5238 - val_loss: 1.1207
# Epoch 2/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5387 - loss: 0.9775 - val_accuracy: 0.5714 - val_loss: 0.8433
# Epoch 3/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6333 - loss: 0.7808 - val_accuracy: 0.6667 - val_loss: 0.7639
# Epoch 4/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6933 - loss: 0.6614 - val_accuracy: 0.6429 - val_loss: 0.7525
# Epoch 5/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7213 - loss: 0.6156 - val_accuracy: 0.9286 - val_loss: 0.4714
# Epoch 6/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7640 - loss: 0.5607 - val_accuracy: 0.9286 - val_loss: 0.3425
# Epoch 7/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9173 - loss: 0.2742 - val_accuracy: 0.8095 - val_loss: 0.4839
# Epoch 8/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8800 - loss: 0.3645 - val_accuracy: 0.8333 - val_loss: 0.3767
# Epoch 9/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8973 - loss: 0.2802 - val_accuracy: 0.9524 - val_loss: 0.1050
# Epoch 10/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9440 - loss: 0.1915 - val_accuracy: 0.8333 - val_loss: 0.4088
# Epoch 11/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9200 - loss: 0.2390 - val_accuracy: 0.9762 - val_loss: 0.1064
# Epoch 12/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9880 - loss: 0.0700 - val_accuracy: 1.0000 - val_loss: 0.0099
# Epoch 13/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9547 - loss: 0.1552 - val_accuracy: 1.0000 - val_loss: 0.0268
# Epoch 14/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9813 - loss: 0.0832 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 15/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9747 - loss: 0.0917 - val_accuracy: 0.9524 - val_loss: 0.1399
# Epoch 16/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9720 - loss: 0.1003 - val_accuracy: 1.0000 - val_loss: 0.0103
# Epoch 17/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9760 - loss: 0.1051 - val_accuracy: 1.0000 - val_loss: 0.0076
# Epoch 18/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9880 - loss: 0.0445 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 19/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9907 - loss: 0.0378 - val_accuracy: 1.0000 - val_loss: 0.0110
# Epoch 20/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9960 - loss: 0.0200 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 21/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9947 - loss: 0.0279 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 22/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9933 - loss: 0.0253 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 23/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9960 - loss: 0.0175 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 24/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9960 - loss: 0.0112 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 25/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9960 - loss: 0.0183 - val_accuracy: 1.0000 - val_loss: 6.7014e-04
# Epoch 26/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9933 - loss: 0.0211 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 27/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9893 - loss: 0.0399 - val_accuracy: 0.9762 - val_loss: 0.0554
# Epoch 28/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9853 - loss: 0.0670 - val_accuracy: 0.8810 - val_loss: 0.6400
# Epoch 29/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9533 - loss: 0.1709 - val_accuracy: 1.0000 - val_loss: 0.0261
# Epoch 30/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9707 - loss: 0.1002 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 25.
#   Fold 4/7: val_acc=1.0000  (epochs_run=30, best_epoch=25)
# Epoch 1/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.3027 - loss: 1.6096 - val_accuracy: 0.4286 - val_loss: 1.1837
# Epoch 2/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4200 - loss: 1.2413 - val_accuracy: 0.4762 - val_loss: 1.0610
# Epoch 3/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5373 - loss: 0.9704 - val_accuracy: 0.6667 - val_loss: 0.7404
# Epoch 4/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6147 - loss: 0.8440 - val_accuracy: 0.3810 - val_loss: 1.4375
# Epoch 5/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4947 - loss: 1.1240 - val_accuracy: 0.6190 - val_loss: 0.7552
# Epoch 6/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6360 - loss: 0.7723 - val_accuracy: 0.6667 - val_loss: 0.7621
# Epoch 7/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6733 - loss: 0.6437 - val_accuracy: 0.6429 - val_loss: 0.5773
# Epoch 8/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7573 - loss: 0.5342 - val_accuracy: 0.7619 - val_loss: 0.5920
# Epoch 9/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6453 - loss: 0.7887 - val_accuracy: 0.7381 - val_loss: 0.5327
# Epoch 10/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7400 - loss: 0.5693 - val_accuracy: 0.8095 - val_loss: 0.5314
# Epoch 11/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7520 - loss: 0.5180 - val_accuracy: 0.6429 - val_loss: 0.7872
# Epoch 12/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7333 - loss: 0.6477 - val_accuracy: 0.8333 - val_loss: 0.5134
# Epoch 13/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8240 - loss: 0.4173 - val_accuracy: 0.8333 - val_loss: 0.3554
# Epoch 14/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8107 - loss: 0.4460 - val_accuracy: 0.7857 - val_loss: 0.3703
# Epoch 15/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8520 - loss: 0.3436 - val_accuracy: 0.8571 - val_loss: 0.3710
# Epoch 16/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8880 - loss: 0.2782 - val_accuracy: 0.9286 - val_loss: 0.2280
# Epoch 17/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7853 - loss: 0.5582 - val_accuracy: 0.7619 - val_loss: 0.4005
# Epoch 18/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8387 - loss: 0.3991 - val_accuracy: 0.9048 - val_loss: 0.2651
# Epoch 19/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9053 - loss: 0.2954 - val_accuracy: 0.9048 - val_loss: 0.2188
# Epoch 20/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9600 - loss: 0.1426 - val_accuracy: 0.9762 - val_loss: 0.0960
# Epoch 21/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8827 - loss: 0.3591 - val_accuracy: 0.8810 - val_loss: 0.5907
# Epoch 22/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9733 - loss: 0.1249 - val_accuracy: 0.9762 - val_loss: 0.0266
# Epoch 23/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9853 - loss: 0.0666 - val_accuracy: 0.9762 - val_loss: 0.0791
# Epoch 24/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9813 - loss: 0.0747 - val_accuracy: 0.9762 - val_loss: 0.0751
# Epoch 25/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9680 - loss: 0.1045 - val_accuracy: 0.9762 - val_loss: 0.0571
# Epoch 26/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9933 - loss: 0.0346 - val_accuracy: 0.9762 - val_loss: 0.0619
# Epoch 27/60
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9947 - loss: 0.0221 - val_accuracy: 0.9762 - val_loss: 0.0618
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 22.
#   Fold 5/7: val_acc=0.9762  (epochs_run=27, best_epoch=22)
# Epoch 1/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.3426 - loss: 1.4618 - val_accuracy: 0.4878 - val_loss: 0.9415
# Epoch 2/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5033 - loss: 1.0393 - val_accuracy: 0.6098 - val_loss: 0.8606
# Epoch 3/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5644 - loss: 0.8891 - val_accuracy: 0.6098 - val_loss: 0.7270
# Epoch 4/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6255 - loss: 0.7419 - val_accuracy: 0.6585 - val_loss: 0.5851
# Epoch 5/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6494 - loss: 0.7161 - val_accuracy: 0.4634 - val_loss: 0.8004
# Epoch 6/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5525 - loss: 0.9930 - val_accuracy: 0.5610 - val_loss: 0.8897
# Epoch 7/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6507 - loss: 0.6909 - val_accuracy: 0.7561 - val_loss: 0.5344
# Epoch 8/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7039 - loss: 0.5714 - val_accuracy: 0.7561 - val_loss: 0.4781
# Epoch 9/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6959 - loss: 0.6382 - val_accuracy: 0.7805 - val_loss: 0.5163
# Epoch 10/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7291 - loss: 0.5786 - val_accuracy: 0.7073 - val_loss: 0.5077
# Epoch 11/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7291 - loss: 0.6023 - val_accuracy: 0.8049 - val_loss: 0.4273
# Epoch 12/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7649 - loss: 0.4920 - val_accuracy: 0.7561 - val_loss: 0.5852
# Epoch 13/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8035 - loss: 0.4344 - val_accuracy: 0.7561 - val_loss: 0.5414
# Epoch 14/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8592 - loss: 0.3328 - val_accuracy: 0.7317 - val_loss: 0.8252
# Epoch 15/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8380 - loss: 0.3554 - val_accuracy: 0.9512 - val_loss: 0.1821
# Epoch 16/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8699 - loss: 0.2857 - val_accuracy: 0.9512 - val_loss: 0.2798
# Epoch 17/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9270 - loss: 0.2411 - val_accuracy: 0.8537 - val_loss: 0.3177
# Epoch 18/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8141 - loss: 0.3817 - val_accuracy: 0.8293 - val_loss: 0.2350
# Epoch 19/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9389 - loss: 0.1943 - val_accuracy: 0.8293 - val_loss: 0.3016
# Epoch 20/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8831 - loss: 0.2677 - val_accuracy: 0.6829 - val_loss: 1.0953
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 15.
#   Fold 6/7: val_acc=0.9512  (epochs_run=20, best_epoch=15)
# Epoch 1/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.3825 - loss: 1.4619 - val_accuracy: 0.6829 - val_loss: 0.8265
# Epoch 2/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6096 - loss: 0.9045 - val_accuracy: 0.6098 - val_loss: 0.7814
# Epoch 3/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6786 - loss: 0.7250 - val_accuracy: 0.7561 - val_loss: 0.7115
# Epoch 4/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6653 - loss: 0.7526 - val_accuracy: 0.7561 - val_loss: 0.6226
# Epoch 5/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7185 - loss: 0.5954 - val_accuracy: 0.7073 - val_loss: 0.6054
# Epoch 6/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6879 - loss: 0.7102 - val_accuracy: 0.6829 - val_loss: 0.6141
# Epoch 7/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7649 - loss: 0.5302 - val_accuracy: 0.7805 - val_loss: 0.5161
# Epoch 8/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8194 - loss: 0.4618 - val_accuracy: 0.9024 - val_loss: 0.3350
# Epoch 9/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8167 - loss: 0.4488 - val_accuracy: 0.8049 - val_loss: 0.3632
# Epoch 10/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8765 - loss: 0.3356 - val_accuracy: 0.7073 - val_loss: 0.8994
# Epoch 11/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8127 - loss: 0.5229 - val_accuracy: 0.7561 - val_loss: 0.6064
# Epoch 12/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8712 - loss: 0.4090 - val_accuracy: 0.9024 - val_loss: 0.2513
# Epoch 13/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8938 - loss: 0.2836 - val_accuracy: 0.9512 - val_loss: 0.1681
# Epoch 14/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9283 - loss: 0.2155 - val_accuracy: 0.9268 - val_loss: 0.1655
# Epoch 15/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9230 - loss: 0.2539 - val_accuracy: 0.8293 - val_loss: 0.5348
# Epoch 16/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9163 - loss: 0.2603 - val_accuracy: 0.8537 - val_loss: 0.4648
# Epoch 17/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9535 - loss: 0.1770 - val_accuracy: 0.9512 - val_loss: 0.0769
# Epoch 18/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9827 - loss: 0.0784 - val_accuracy: 1.0000 - val_loss: 0.0120
# Epoch 19/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9920 - loss: 0.0449 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 20/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9044 - loss: 0.2919 - val_accuracy: 0.8780 - val_loss: 0.3483
# Epoch 21/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9363 - loss: 0.2086 - val_accuracy: 1.0000 - val_loss: 0.0309
# Epoch 22/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9867 - loss: 0.0687 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 23/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9907 - loss: 0.0419 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 24/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9960 - loss: 0.0208 - val_accuracy: 0.9756 - val_loss: 0.0540
# Epoch 25/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9960 - loss: 0.0296 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 26/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9947 - loss: 0.0251 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 27/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9867 - loss: 0.0586 - val_accuracy: 0.9512 - val_loss: 0.0476
# Epoch 28/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9628 - loss: 0.1257 - val_accuracy: 0.7805 - val_loss: 0.8223
# Epoch 29/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9495 - loss: 0.1755 - val_accuracy: 0.9756 - val_loss: 0.0371
# Epoch 30/60
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9934 - loss: 0.0363 - val_accuracy: 1.0000 - val_loss: 0.0205
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 25.
#   Fold 7/7: val_acc=1.0000  (epochs_run=30, best_epoch=25)
#   CV mean: 0.9862 ± 0.0177, best fold 1

# %% [markdown]
# ## 10. Final retrain on the full training pool
#
# CV gave us an honest estimate of generalisation. Now we retrain on the whole training pool with augmentation, fit a fresh scaler, and evaluate on the hold-out test set. This `model` and `scaler` are what get used for batch testing.

# %%
# Final retrain on the full training pool — once per variant. The familiar
# `model`, `scaler`, `history`, `X_train_final`, `y_train_final`, `X_test_final`
# variables end up pointing at the LAST variant for compatibility with cells
# 23/25/27 if you ever decide to skip the variants loop and run a single one.
import tensorflow as tf

# Build the training set once (same data + augmentation seed for fair comparison)
if AUGMENT_TRAINING_DATA:
    X_tr_full, y_tr_full = augment_training_set(
        X_train_pool, y_train_pool,
        sensor_cols=SENSOR_COLS,
        config=AUGMENT_CONFIG,
        copies_per_sample=AUGMENTATION_COPIES_PER_SAMPLE,
        random_state=AUGMENTATION_RANDOM_SEED,
    )
else:
    X_tr_full, y_tr_full = X_train_pool.copy(), y_train_pool.copy()
print(f'Final training set size: {X_tr_full.shape[0]} (orig pool {X_train_pool.shape[0]})')

for entry in variant_results:
    print(f'\n── Final retrain: {entry["name"]} ──')

    # Fresh scaler per variant (fit on full augmented pool, applied to hold-out)
    X_tr_s, _, X_test_s, scaler_v = scale_sets(X_tr_full, X_tr_full[:0], X_test, NORMALISATION)

    tf.keras.backend.clear_session()
    tf.random.set_seed(RANDOM_STATE)
    model_v = entry['builder'](sequence_length, n_channels, n_classes)
    n_params = int(model_v.count_params())
    _cbs = []
    if EARLY_STOPPING_ENABLED:
        _cbs.append(tf.keras.callbacks.EarlyStopping(
            monitor=EARLY_STOPPING_MONITOR,
            patience=EARLY_STOPPING_PATIENCE,
            min_delta=EARLY_STOPPING_MIN_DELTA,
            mode=('max' if EARLY_STOPPING_MONITOR.endswith('accuracy') else 'min'),
            restore_best_weights=EARLY_STOPPING_RESTORE_BEST,
            verbose=EARLY_STOPPING_VERBOSE,
        ))
    history_v = model_v.fit(
        X_tr_s, y_tr_full,
        epochs=TRAIN_EPOCHS, batch_size=TRAIN_BATCH_SIZE,
        validation_split=TRAIN_VALIDATION_SPLIT, verbose=TRAIN_VERBOSE,
        callbacks=_cbs,
    )

    entry.update({
        'model':   model_v,
        'scaler':  scaler_v,
        'history': history_v.history,
        'n_params': n_params,
        'X_test_final': X_test_s,
    })
    print(f'  trainable params: {n_params:,}')

# Legacy aliases pointing at the last variant
_last = variant_results[-1]
model         = _last['model']
scaler        = _last['scaler']
history       = type('H', (), {'history': _last['history']})()
X_train_final = X_tr_s
y_train_final = y_tr_full
X_test_final  = _last['X_test_final']
# Out:
# Final training set size: 876 (orig pool 292)
#
# ── Final retrain: Baseline ──
# Epoch 1/60
# I0000 00:00:1778763969.657022 1788376 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1905761__.31
# 34/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2992 - loss: 1.6466
# I0000 00:00:1778763971.005689 1788377 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1905761__.31
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.4500 - loss: 1.3060 - val_accuracy: 0.6250 - val_loss: 0.7815
# Epoch 2/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6614 - loss: 0.7542 - val_accuracy: 0.6250 - val_loss: 0.7392
# Epoch 3/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7557 - loss: 0.5572 - val_accuracy: 0.6250 - val_loss: 0.7431
# Epoch 4/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7429 - loss: 0.6031 - val_accuracy: 0.8182 - val_loss: 0.5227
# Epoch 5/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8257 - loss: 0.4085 - val_accuracy: 0.7159 - val_loss: 0.5676
# Epoch 6/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9186 - loss: 0.2553 - val_accuracy: 0.9261 - val_loss: 0.1720
# Epoch 7/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9557 - loss: 0.1470 - val_accuracy: 0.9773 - val_loss: 0.1539
# Epoch 8/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9686 - loss: 0.1223 - val_accuracy: 0.9773 - val_loss: 0.0877
# Epoch 9/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9743 - loss: 0.1073 - val_accuracy: 0.9943 - val_loss: 0.0395
# Epoch 10/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9757 - loss: 0.0798 - val_accuracy: 0.9659 - val_loss: 0.0654
# Epoch 11/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9743 - loss: 0.0604 - val_accuracy: 0.9716 - val_loss: 0.0608
# Epoch 12/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9471 - loss: 0.1542 - val_accuracy: 0.9489 - val_loss: 0.1172
# Epoch 13/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9814 - loss: 0.0485 - val_accuracy: 0.9886 - val_loss: 0.0193
# Epoch 14/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9914 - loss: 0.0368 - val_accuracy: 0.9943 - val_loss: 0.0133
# Epoch 15/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9957 - loss: 0.0157 - val_accuracy: 0.9886 - val_loss: 0.0190
# Epoch 16/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9957 - loss: 0.0143 - val_accuracy: 0.9886 - val_loss: 0.0181
# Epoch 17/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9943 - loss: 0.0191 - val_accuracy: 0.9886 - val_loss: 0.0103
# Epoch 18/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9986 - loss: 0.0130 - val_accuracy: 0.9886 - val_loss: 0.0405
# Epoch 19/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9986 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 20/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9986 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 21/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9957 - loss: 0.0249 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 22/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9471 - loss: 0.1997 - val_accuracy: 0.9830 - val_loss: 0.0582
# Epoch 23/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9843 - loss: 0.0541 - val_accuracy: 1.0000 - val_loss: 0.0177
# Epoch 24/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9800 - loss: 0.0667 - val_accuracy: 0.9659 - val_loss: 0.0862
# Epoch 25/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9814 - loss: 0.0588 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 20.
#   trainable params: 113,190
#
# ── Final retrain: Deep ──
# Epoch 1/60
# I0000 00:00:1778763984.048036 1788376 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1914527__.40
# 35/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2447 - loss: 1.6813
# I0000 00:00:1778763985.494318 1788379 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1914527__.40
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 0.3814 - loss: 1.4154 - val_accuracy: 0.5398 - val_loss: 1.0153
# Epoch 2/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5943 - loss: 0.9093 - val_accuracy: 0.5341 - val_loss: 0.8712
# Epoch 3/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6457 - loss: 0.7967 - val_accuracy: 0.5511 - val_loss: 0.8822
# Epoch 4/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7343 - loss: 0.6040 - val_accuracy: 0.6420 - val_loss: 0.7774
# Epoch 5/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7214 - loss: 0.6365 - val_accuracy: 0.6989 - val_loss: 0.6276
# Epoch 6/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7900 - loss: 0.4456 - val_accuracy: 0.6307 - val_loss: 0.6771
# Epoch 7/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8186 - loss: 0.4303 - val_accuracy: 0.6989 - val_loss: 0.5568
# Epoch 8/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9014 - loss: 0.2773 - val_accuracy: 0.7500 - val_loss: 0.4663
# Epoch 9/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9600 - loss: 0.1638 - val_accuracy: 0.9318 - val_loss: 0.1692
# Epoch 10/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9757 - loss: 0.0995 - val_accuracy: 0.9545 - val_loss: 0.1029
# Epoch 11/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9743 - loss: 0.0922 - val_accuracy: 0.9886 - val_loss: 0.0635
# Epoch 12/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9843 - loss: 0.0577 - val_accuracy: 0.9830 - val_loss: 0.0419
# Epoch 13/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9857 - loss: 0.0464 - val_accuracy: 0.9886 - val_loss: 0.0254
# Epoch 14/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9614 - loss: 0.1264 - val_accuracy: 0.9830 - val_loss: 0.0410
# Epoch 15/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9914 - loss: 0.0451 - val_accuracy: 1.0000 - val_loss: 0.0136
# Epoch 16/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9957 - loss: 0.0216 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 17/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9957 - loss: 0.0236 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 18/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9943 - loss: 0.0287 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 19/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9929 - loss: 0.0217 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 20/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9957 - loss: 0.0158 - val_accuracy: 0.9716 - val_loss: 0.0968
# Epoch 21/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6857 - loss: 1.0733 - val_accuracy: 0.9432 - val_loss: 0.1974
# Epoch 22/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9171 - loss: 0.1916 - val_accuracy: 0.9773 - val_loss: 0.0679
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 17.
#   trainable params: 203,878
#
# ── Final retrain: BN_GAP ──
# Epoch 1/60
# I0000 00:00:1778763998.016249 1788379 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1923723__.48
# 41/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5302 - loss: 1.2823
# I0000 00:00:1778764000.177232 1788379 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1923723__.48
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - accuracy: 0.7700 - loss: 0.6879 - val_accuracy: 0.6250 - val_loss: 1.2829
# Epoch 2/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9814 - loss: 0.1237 - val_accuracy: 0.5170 - val_loss: 1.2803
# Epoch 3/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9943 - loss: 0.0605 - val_accuracy: 0.5739 - val_loss: 1.1411
# Epoch 4/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9943 - loss: 0.0400 - val_accuracy: 0.7557 - val_loss: 0.6261
# Epoch 5/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9986 - loss: 0.0211 - val_accuracy: 0.8182 - val_loss: 0.4590
# Epoch 6/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0145 - val_accuracy: 1.0000 - val_loss: 0.0375
# Epoch 7/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0112 - val_accuracy: 0.9943 - val_loss: 0.0289
# Epoch 8/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 9/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 10/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 11/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 0.0108
# Epoch 12/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 13/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 14/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 15/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 16/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 17/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 18/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 19/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 20/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 7.9159e-04
# Epoch 21/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 9.8089e-04
# Epoch 22/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 23/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 9.8491e-04
# Epoch 24/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 6.1462e-04
# Epoch 25/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 26/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 9.2183e-04
# Epoch 27/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 8.2630e-04
# Epoch 28/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 8.9529e-04
# Epoch 29/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 4.1240e-04
# Epoch 30/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 1.0000 - loss: 9.5483e-04 - val_accuracy: 1.0000 - val_loss: 3.8178e-04
# Epoch 31/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 9.0136e-04 - val_accuracy: 1.0000 - val_loss: 4.0314e-04
# Epoch 32/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 9.6931e-04 - val_accuracy: 1.0000 - val_loss: 3.6219e-04
# Epoch 33/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 8.3298e-04 - val_accuracy: 1.0000 - val_loss: 4.4283e-04
# Epoch 34/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 7.6832e-04 - val_accuracy: 1.0000 - val_loss: 3.7224e-04
# Epoch 35/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 7.1074e-04 - val_accuracy: 1.0000 - val_loss: 2.6703e-04
# Epoch 36/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 8.0157e-04 - val_accuracy: 1.0000 - val_loss: 2.8783e-04
# Epoch 37/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 6.5110e-04 - val_accuracy: 1.0000 - val_loss: 3.4319e-04
# Epoch 38/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 6.1536e-04 - val_accuracy: 1.0000 - val_loss: 2.9348e-04
# Epoch 39/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 7.2518e-04 - val_accuracy: 1.0000 - val_loss: 4.2435e-04
# Epoch 40/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 6.4775e-04 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 35.
#   trainable params: 57,190
#
# ── Final retrain: CNN_BiLSTM ──
# Epoch 1/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.3086 - loss: 1.5398 - val_accuracy: 0.5568 - val_loss: 1.0752
# Epoch 2/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5343 - loss: 0.9879 - val_accuracy: 0.6193 - val_loss: 0.8732
# Epoch 3/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6129 - loss: 0.8174 - val_accuracy: 0.6136 - val_loss: 0.8013
# Epoch 4/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7057 - loss: 0.6385 - val_accuracy: 0.6875 - val_loss: 0.6407
# Epoch 5/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6329 - loss: 0.8200 - val_accuracy: 0.6875 - val_loss: 0.5856
# Epoch 6/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.7614 - loss: 0.5118 - val_accuracy: 0.7898 - val_loss: 0.4310
# Epoch 7/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7886 - loss: 0.5156 - val_accuracy: 0.6591 - val_loss: 0.6766
# Epoch 8/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7371 - loss: 0.5455 - val_accuracy: 0.8466 - val_loss: 0.3745
# Epoch 9/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8100 - loss: 0.3986 - val_accuracy: 0.7443 - val_loss: 0.4193
# Epoch 10/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8571 - loss: 0.3427 - val_accuracy: 0.7386 - val_loss: 0.4758
# Epoch 11/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.7986 - loss: 0.4408 - val_accuracy: 0.8182 - val_loss: 0.3203
# Epoch 12/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8729 - loss: 0.2634 - val_accuracy: 0.9432 - val_loss: 0.2326
# Epoch 13/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9014 - loss: 0.2518 - val_accuracy: 0.9375 - val_loss: 0.2146
# Epoch 14/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9200 - loss: 0.2175 - val_accuracy: 0.9318 - val_loss: 0.1834
# Epoch 15/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9729 - loss: 0.1236 - val_accuracy: 0.7841 - val_loss: 0.6532
# Epoch 16/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8643 - loss: 0.3486 - val_accuracy: 0.9659 - val_loss: 0.1550
# Epoch 17/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9657 - loss: 0.1352 - val_accuracy: 0.9545 - val_loss: 0.1507
# Epoch 18/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9057 - loss: 0.2749 - val_accuracy: 0.8523 - val_loss: 0.2814
# Epoch 19/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9729 - loss: 0.1105 - val_accuracy: 0.9773 - val_loss: 0.0821
# Epoch 20/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9886 - loss: 0.0634 - val_accuracy: 0.9943 - val_loss: 0.0193
# Epoch 21/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9286 - loss: 0.2937 - val_accuracy: 0.8182 - val_loss: 0.4904
# Epoch 22/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8614 - loss: 0.4150 - val_accuracy: 0.9205 - val_loss: 0.3286
# Epoch 23/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9700 - loss: 0.1222 - val_accuracy: 0.9943 - val_loss: 0.0224
# Epoch 24/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9929 - loss: 0.0504 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 25/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9943 - loss: 0.0337 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 26/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9929 - loss: 0.0458 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 27/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9000 - loss: 0.3113 - val_accuracy: 0.7102 - val_loss: 0.6713
# Epoch 28/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8143 - loss: 0.4272 - val_accuracy: 0.9545 - val_loss: 0.2431
# Epoch 29/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9571 - loss: 0.1357 - val_accuracy: 0.9830 - val_loss: 0.0559
# Epoch 30/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9929 - loss: 0.0399 - val_accuracy: 0.9943 - val_loss: 0.0150
# Epoch 31/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9929 - loss: 0.0379 - val_accuracy: 0.9886 - val_loss: 0.0238
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 26.
#   trainable params: 105,510

# %% [markdown]
# ## 11. Training curves

# %%
# Overlay validation curves for all variants
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
for entry in variant_results:
    h = entry.get('history', {})
    if 'val_accuracy' in h:
        plt.plot(h['val_accuracy'], label=entry['name'])
plt.title('Validation accuracy (final retrain)')
plt.xlabel('Epoch'); plt.ylabel('Accuracy')
plt.legend(fontsize=8); plt.grid(alpha=0.3)

plt.subplot(1, 2, 2)
for entry in variant_results:
    h = entry.get('history', {})
    if 'val_loss' in h:
        plt.plot(h['val_loss'], label=entry['name'])
plt.title('Validation loss (final retrain)')
plt.xlabel('Epoch'); plt.ylabel('Loss')
plt.legend(fontsize=8); plt.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(MODEL_OUTPUT_DIR / 'training_curves.png', dpi=140, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 12. Hold-out test evaluation

# %%
# Hold-out evaluation per variant
for entry in variant_results:
    test_loss_v, test_accuracy_v = entry['model'].evaluate(
        entry['X_test_final'], y_test, verbose=0
    )
    y_pred_v = np.argmax(entry['model'].predict(entry['X_test_final'], verbose=0), axis=1)
    rep_v = classification_report(
        y_test, y_pred_v, target_names=le.classes_, output_dict=True, zero_division=0
    )
    entry.update({
        'test_loss': float(test_loss_v),
        'test_accuracy': float(test_accuracy_v),
        'y_pred': y_pred_v,
        'classification_report': rep_v,
    })
    print(f'{entry["name"]:<12} test_loss={test_loss_v:.4f}  test_acc={test_accuracy_v:.4f}')

print('\nConfusion matrix (last variant):')
print(confusion_matrix(y_test, variant_results[-1]['y_pred']))
print('\nClassification report (last variant):')
print(classification_report(
    y_test, variant_results[-1]['y_pred'], target_names=le.classes_, zero_division=0
))

# Legacy aliases for downstream cells
test_loss     = variant_results[-1]['test_loss']
test_accuracy = variant_results[-1]['test_accuracy']
y_pred        = variant_results[-1]['y_pred']
# Out:
# Baseline     test_loss=0.0008  test_acc=1.0000
# Deep         test_loss=0.0170  test_acc=1.0000
# BN_GAP       test_loss=0.0001  test_acc=1.0000
# CNN_BiLSTM   test_loss=0.0024  test_acc=1.0000
#
# Confusion matrix (last variant):
# [[5 0 0 0 0 0]
#  [0 6 0 0 0 0]
#  [0 0 6 0 0 0]
#  [0 0 0 5 0 0]
#  [0 0 0 0 6 0]
#  [0 0 0 0 0 5]]
#
# Classification report (last variant):
#                       precision    recall  f1-score   support
#
#         Double_Lower       1.00      1.00      1.00         5
# Double_Pistol_Recoil       1.00      1.00      1.00         6
#         Double_Raise       1.00      1.00      1.00         6
#        Double_Wiggle       1.00      1.00      1.00         5
#         Double_cmere       1.00      1.00      1.00         6
#            Drum_Roll       1.00      1.00      1.00         5
#
#             accuracy                           1.00        33
#            macro avg       1.00      1.00      1.00        33
#         weighted avg       1.00      1.00      1.00        33

# %% [markdown]
# ## 13. Batch test on TestData/Jestin/TwoHandDynamic
#
# The test folder contains one subfolder per gesture (matching the training class names, sometimes with case differences). We use **the subfolder name** as the ground-truth label — this is far more robust than parsing filenames. Class-name matching is case-insensitive so e.g. `TwoHandDynamic_L_Fist_R_LightBulb` (test) maps to `TwoHandDynamic_L_Fist_R_Lightbulb` (training).

# %%
def preprocess_csv_for_cnn(fpath, sensor_cols, resample_n, apply_butter, cutoff, order, fs, scaler,
                            seq_len, n_chan):
    """Read one CSV → (1, seq_len, n_chan) tensor ready for model.predict."""
    df = pd.read_csv(fpath)
    available = [c for c in sensor_cols if c in df.columns]
    if not available:
        raise ValueError('No matching sensor columns')
    if len(available) != len(sensor_cols):
        # Pad missing columns with zeros so the channel order matches training
        data = np.zeros((len(df), len(sensor_cols)), dtype=np.float32)
        idx_map = {c: i for i, c in enumerate(sensor_cols)}
        for c in available:
            data[:, idx_map[c]] = df[c].values.astype(np.float32)
    else:
        data = df[sensor_cols].values.astype(np.float32)

    if resample_n is not None:
        data = resample_trial(data, resample_n)
    if apply_butter:
        data = apply_butterworth([data], cutoff, order, fs)[0]
    data = np.nan_to_num(data, nan=0.0, posinf=0.0, neginf=0.0)

    if scaler is not None:
        data = scaler.transform(data.reshape(1, -1)).reshape(seq_len, n_chan).astype(np.float32)

    return data.reshape(1, seq_len, n_chan)


def build_test_label_map(class_names):
    """Case-insensitive map from test-folder class name → training class name."""
    m = {}
    for cls in class_names:
        m[cls.lower()] = cls
    return m


def run_batch_test(test_root, model, scaler, le, sensor_cols, class_names,
                   resample_n, apply_butter, cutoff, order, fs, seq_len, n_chan):
    test_root = os.path.expanduser(test_root)
    if not os.path.isdir(test_root):
        raise FileNotFoundError(f'BATCH_TEST_ROOT not found: {test_root!r}')

    label_map = build_test_label_map(class_names)
    sub_dirs = sorted(d for d in os.listdir(test_root)
                      if os.path.isdir(os.path.join(test_root, d)))
    if not sub_dirs:
        print(f'No subfolders found in {test_root}')
        return None

    correct, total, unrecognised = 0, 0, 0
    per_class = {}
    rows = []
    print(f'Batch testing files from {len(sub_dirs)} subfolders under {test_root}')
    print('-' * 100)

    for sub in sub_dirs:
        true_label = label_map.get(sub.lower())
        sub_path = os.path.join(test_root, sub)
        csv_files = sorted(f for f in glob.glob(os.path.join(sub_path, '*.csv'))
                           if not os.path.basename(f).startswith('_'))
        if true_label is None:
            print(f'  ? subfolder {sub!r} has no matching training class — skipping ({len(csv_files)} files)')
            unrecognised += len(csv_files)
            continue

        per_class.setdefault(true_label, {'correct': 0, 'total': 0})

        for fpath in csv_files:
            fname = os.path.basename(fpath)
            try:
                x = preprocess_csv_for_cnn(
                    fpath, sensor_cols,
                    resample_n, apply_butter, cutoff, order, fs,
                    scaler, seq_len, n_chan,
                )
                probs = model.predict(x, verbose=0)[0]
                pred_idx = int(np.argmax(probs))
                pred = le.inverse_transform([pred_idx])[0]
                conf = float(probs.max())
                ok = (pred == true_label)
                correct += int(ok); total += 1
                per_class[true_label]['correct'] += int(ok)
                per_class[true_label]['total']   += 1
                rows.append({'file': fname, 'true': true_label, 'pred': pred,
                             'confidence': conf, 'correct': ok})
                tag = '✓' if ok else '✗'
                t_short = true_label.replace('TwoHandDynamic_', '')
                p_short = pred.replace('TwoHandDynamic_', '')
                print(f'  {tag} {fname[:50]:<52}  true={t_short:<28}  pred={p_short:<28}  conf={conf:.3f}')
            except Exception as e:
                print(f'  ERROR {fname}: {e}')

    print('-' * 100)
    if total > 0:
        print(f'Overall batch accuracy: {correct/total:.4f}  ({correct}/{total})')
    if unrecognised:
        print(f'Files in unmatched subfolders: {unrecognised}')

    print('\nPer-class accuracy:')
    for cls, d in sorted(per_class.items()):
        if d['total']:
            print(f'  {cls:<55} {d["correct"]/d["total"]:.4f}  ({d["correct"]}/{d["total"]})')

    return pd.DataFrame(rows), correct, total

# %%
# Batch test per variant (reuses run_batch_test defined above)
for entry in variant_results:
    print(f'\n── Batch test: {entry["name"]} ──')
    res = run_batch_test(
        BATCH_TEST_ROOT, entry['model'], entry['scaler'], le,
        SENSOR_COLS, class_names,
        RESAMPLE_TO_N_STEPS, APPLY_BUTTERWORTH, BUTTERWORTH_CUTOFF_HZ, BUTTERWORTH_ORDER,
        SAMPLING_RATE_HZ, sequence_length, n_channels,
    )
    if res is not None:
        df_v, c_v, t_v = res
        entry['batch_df'] = df_v
        entry['batch_correct'] = int(c_v)
        entry['batch_total'] = int(t_v)
        entry['batch_accuracy'] = float(c_v / t_v) if t_v else None
    else:
        entry['batch_df'] = None
        entry['batch_correct'] = 0
        entry['batch_total'] = 0
        entry['batch_accuracy'] = None

print('\n=== Summary across variants ===')
print(f'{"Variant":<12}  {"params":>10}  {"CV":>16}  {"hold-out":>10}  {"batch":>10}')
for e in variant_results:
    cv = f'{e["cv_mean"]:.3f}±{e["cv_std"]:.3f}' if e["cv_mean"] is not None else '—'
    bt = f'{e["batch_accuracy"]:.3f}' if e["batch_accuracy"] is not None else '—'
    print(f'{e["name"]:<12}  {e["n_params"]:>10,}  {cv:>16}  {e["test_accuracy"]:>10.3f}  {bt:>10}')

# Legacy aliases
batch_df = variant_results[-1].get('batch_df')
batch_correct = variant_results[-1].get('batch_correct', 0)
batch_total = variant_results[-1].get('batch_total', 0)
batch_test_accuracy = variant_results[-1].get('batch_accuracy')
# Out:
# ── Batch test: Baseline ──
# Batch testing files from 7 subfolders under /home/jestin/ThesisRepo/ML/NewTestData/15_Tash/Dynamic
# ----------------------------------------------------------------------------------------------------
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_1_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_2_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_3_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_4_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.988
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_5_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.863
#   ? subfolder 'Double_Nothing' has no matching training class — skipping (5 files)
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_1_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_2_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_3_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_4_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_5_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_1_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.997
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_2_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.999
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_3_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.974
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_4_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.970
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_5_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.998
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_1_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.905
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_2_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.999
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_3_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.998
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_4_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.999
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_5_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.999
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_1_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.987
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_2_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.996
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_3_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=1.000
#   ✓ glove_data_L_Dynamic_Double_cmere_3s_4_2026-05-04_    true=Double_cmere                  pred=Double_cmere                  conf=0.999
#   ✓ glove_data_L_Dynamic_Double_cmere_3s_5_2026-05-04_    true=Double_cmere                  pred=Double_cmere                  conf=0.995
#   ✓ glove_data_L_Dynamic_Drum_Roll_3s_1_2026-05-04_08-    true=Drum_Roll                     pred=Drum_Roll                     conf=0.964
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_2_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.993
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_3_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.992
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_4_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.997
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_5_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.961
# ----------------------------------------------------------------------------------------------------
# Overall batch accuracy: 0.7667  (23/30)
# Files in unmatched subfolders: 5
#
# Per-class accuracy:
#   Double_Lower                                            1.0000  (5/5)
#   Double_Pistol_Recoil                                    1.0000  (5/5)
#   Double_Raise                                            1.0000  (5/5)
#   Double_Wiggle                                           1.0000  (5/5)
#   Double_cmere                                            0.4000  (2/5)
#   Drum_Roll                                               0.2000  (1/5)
#
# ── Batch test: Deep ──
# Batch testing files from 7 subfolders under /home/jestin/ThesisRepo/ML/NewTestData/15_Tash/Dynamic
# ----------------------------------------------------------------------------------------------------
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_1_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_2_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_3_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_4_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.999
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_5_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.833
#   ? subfolder 'Double_Nothing' has no matching training class — skipping (5 files)
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_1_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_2_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_3_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_4_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_5_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_1_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_2_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_3_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_4_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_5_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_1_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.994
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_2_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.998
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_3_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.999
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_4_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.999
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_5_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.999
#   ✓ glove_data_L_Dynamic_Double_cmere_3s_1_2026-05-04_    true=Double_cmere                  pred=Double_cmere                  conf=0.930
#   ✓ glove_data_L_Dynamic_Double_cmere_3s_2_2026-05-04_    true=Double_cmere                  pred=Double_cmere                  conf=0.564
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_3_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.991
#   ✓ glove_data_L_Dynamic_Double_cmere_3s_4_2026-05-04_    true=Double_cmere                  pred=Double_cmere                  conf=0.819
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_5_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.941
#   ✓ glove_data_L_Dynamic_Drum_Roll_3s_1_2026-05-04_08-    true=Drum_Roll                     pred=Drum_Roll                     conf=1.000
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_2_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.851
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_3_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.886
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_4_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.977
#   ✓ glove_data_L_Dynamic_Drum_Roll_3s_5_2026-05-04_08-    true=Drum_Roll                     pred=Drum_Roll                     conf=0.667
# ----------------------------------------------------------------------------------------------------
# Overall batch accuracy: 0.8333  (25/30)
# Files in unmatched subfolders: 5
#
# Per-class accuracy:
#   Double_Lower                                            1.0000  (5/5)
#   Double_Pistol_Recoil                                    1.0000  (5/5)
#   Double_Raise                                            1.0000  (5/5)
#   Double_Wiggle                                           1.0000  (5/5)
#   Double_cmere                                            0.6000  (3/5)
#   Drum_Roll                                               0.4000  (2/5)
#
# ── Batch test: BN_GAP ──
# Batch testing files from 7 subfolders under /home/jestin/ThesisRepo/ML/NewTestData/15_Tash/Dynamic
# ----------------------------------------------------------------------------------------------------
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_1_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.998
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_2_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.946
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_3_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.992
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_4_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.956
#   ✗ glove_data_L_Dynamic_Double_Lower_3s_5_2026-05-04_    true=Double_Lower                  pred=Double_Wiggle                 conf=0.695
#   ? subfolder 'Double_Nothing' has no matching training class — skipping (5 files)
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_1_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_2_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_3_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_4_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_5_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_1_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.982
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_2_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.998
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_3_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.999
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_4_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.998
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_5_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_1_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.997
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_2_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_3_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_4_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_5_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=1.000
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_1_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.997
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_2_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.989
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_3_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.998
#   ✓ glove_data_L_Dynamic_Double_cmere_3s_4_2026-05-04_    true=Double_cmere                  pred=Double_cmere                  conf=0.576
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_5_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.895
#   ✓ glove_data_L_Dynamic_Drum_Roll_3s_1_2026-05-04_08-    true=Drum_Roll                     pred=Drum_Roll                     conf=0.989
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_2_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.983
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_3_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.977
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_4_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.996
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_5_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.893
# ----------------------------------------------------------------------------------------------------
# Overall batch accuracy: 0.7000  (21/30)
# Files in unmatched subfolders: 5
#
# Per-class accuracy:
#   Double_Lower                                            0.8000  (4/5)
#   Double_Pistol_Recoil                                    1.0000  (5/5)
#   Double_Raise                                            1.0000  (5/5)
#   Double_Wiggle                                           1.0000  (5/5)
#   Double_cmere                                            0.2000  (1/5)
#   Drum_Roll                                               0.2000  (1/5)
#
# ── Batch test: CNN_BiLSTM ──
# Batch testing files from 7 subfolders under /home/jestin/ThesisRepo/ML/NewTestData/15_Tash/Dynamic
# ----------------------------------------------------------------------------------------------------
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_1_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.996
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_2_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.993
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_3_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.995
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_4_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.992
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_5_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.967
#   ? subfolder 'Double_Nothing' has no matching training class — skipping (5 files)
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_1_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_2_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.999
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_3_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_4_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=1.000
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_5_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.999
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_1_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.999
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_2_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.999
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_3_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.999
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_4_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.999
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_5_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.999
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_1_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.995
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_2_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.995
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_3_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.995
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_4_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.995
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_5_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.995
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_1_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.997
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_2_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.997
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_3_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.996
#   ✓ glove_data_L_Dynamic_Double_cmere_3s_4_2026-05-04_    true=Double_cmere                  pred=Double_cmere                  conf=0.613
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_5_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.990
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_1_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.982
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_2_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.994
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_3_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.994
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_4_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.993
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_5_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.992
# ----------------------------------------------------------------------------------------------------
# Overall batch accuracy: 0.7000  (21/30)
# Files in unmatched subfolders: 5
#
# Per-class accuracy:
#   Double_Lower                                            1.0000  (5/5)
#   Double_Pistol_Recoil                                    1.0000  (5/5)
#   Double_Raise                                            1.0000  (5/5)
#   Double_Wiggle                                           1.0000  (5/5)
#   Double_cmere                                            0.2000  (1/5)
#   Drum_Roll                                               0.0000  (0/5)
#
# === Summary across variants ===
# Variant           params                CV    hold-out       batch
# Baseline         113,190       0.990±0.025       1.000       0.767
# Deep             203,878       0.986±0.025       1.000       0.833
# BN_GAP            57,190       0.997±0.008       1.000       0.700
# CNN_BiLSTM       105,510       0.986±0.018       1.000       0.700

# %% [markdown]
# ## 14. Save model and append experiment row to CSV log

# %%
def _to_jsonable(obj):
    if isinstance(obj, dict):  return {str(k): _to_jsonable(v) for k, v in obj.items()}
    if isinstance(obj, (list, tuple)): return [_to_jsonable(v) for v in obj]
    if isinstance(obj, np.ndarray):    return obj.tolist()
    if isinstance(obj, np.integer):    return int(obj)
    if isinstance(obj, np.floating):   return float(obj)
    if isinstance(obj, np.bool_):      return bool(obj)
    return obj


def _stable_json(obj):
    return json.dumps(_to_jsonable(obj), sort_keys=True, separators=(',', ':'))


def build_experiment_row():
    hist = {k: [float(v) for v in vs] for k, vs in history.history.items()}
    row = {
        'timestamp': datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
        'data_paths': _stable_json([str(p) for p in (ACTIVE_DATA_PATHS or [])]),
        'data_paths_count': len(ACTIVE_DATA_PATHS or []),
        'batch_test_root': str(BATCH_TEST_ROOT),
        'sensor_cols_count': len(SENSOR_COLS),
        'sensor_cols': _stable_json(SENSOR_COLS),
        'resample_to_n_steps': RESAMPLE_TO_N_STEPS,
        'apply_butterworth': bool(APPLY_BUTTERWORTH),
        'butterworth_cutoff_hz': BUTTERWORTH_CUTOFF_HZ,
        'butterworth_order': BUTTERWORTH_ORDER,
        'sampling_rate_hz': SAMPLING_RATE_HZ,
        'normalisation': NORMALISATION,
        'test_size': float(TEST_SIZE),
        'random_state': int(RANDOM_STATE),
        'cv_folds': int(CV_FOLDS),
        'run_cross_validation': bool(RUN_CROSS_VALIDATION),
        'cv_shuffle': bool(CV_SHUFFLE),
        'augment_training_data': bool(AUGMENT_TRAINING_DATA),
        'augmentation_copies_per_sample': int(AUGMENTATION_COPIES_PER_SAMPLE),
        'augmentation_random_seed': int(AUGMENTATION_RANDOM_SEED),
        'augmentation_config': _stable_json(AUGMENT_CONFIG),
        'n_classes': int(n_classes),
        'class_names': _stable_json(list(le.classes_)),
        'n_total_samples': int(X.shape[0]),
        'n_train_pool_samples': int(X_train_pool.shape[0]),
        'n_train_after_aug': int(X_train_final.shape[0]),
        'n_test_samples': int(X_test.shape[0]),
        'sequence_length': int(sequence_length),
        'n_channels': int(n_channels),
        'epochs': int(TRAIN_EPOCHS),
        'batch_size': int(TRAIN_BATCH_SIZE),
        'validation_split': float(TRAIN_VALIDATION_SPLIT),
        'cv_mean_accuracy': cv_mean_accuracy,
        'cv_std_accuracy': cv_std_accuracy,
        'cv_best_fold_index': best_cv_fold_index,
        'cv_fold_results_json': _stable_json(cv_fold_results),
        'cv_histories_json': _stable_json(cv_histories),
        'final_train_accuracy': float(history.history['accuracy'][-1]),
        'final_val_accuracy':   float(history.history['val_accuracy'][-1]),
        'final_train_loss':     float(history.history['loss'][-1]),
        'final_val_loss':       float(history.history['val_loss'][-1]),
        'best_val_accuracy':    float(max(history.history['val_accuracy'])),
        'best_val_loss':        float(min(history.history['val_loss'])),
        'test_accuracy':        float(test_accuracy),
        'test_loss':            float(test_loss),
        'batch_test_accuracy':  float(batch_test_accuracy) if batch_test_accuracy is not None else None,
        'history_json': _stable_json(hist),
    }
    sig_payload = {k: v for k, v in row.items() if k != 'timestamp'}
    row['row_signature'] = hashlib.sha256(_stable_json(sig_payload).encode()).hexdigest()
    return row


def append_experiment_row(csv_path=EXPERIMENT_LOG_PATH):
    row = build_experiment_row()
    df_new = pd.DataFrame([row])
    if csv_path.exists():
        df_existing = pd.read_csv(csv_path)
        if 'row_signature' in df_existing.columns and row['row_signature'] in set(df_existing['row_signature'].astype(str)):
            print(f'Identical row already in {csv_path} — not appending.')
            return df_existing
        df_out = pd.concat([df_existing, df_new], ignore_index=True)
    else:
        df_out = df_new
    df_out.to_csv(csv_path, index=False)
    print(f'Experiment log: {csv_path} ({len(df_out)} rows)')
    return df_out


def save_model_artifact():
    timestamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
    sig = build_experiment_row()['row_signature'][:12]
    path = MODEL_OUTPUT_DIR / f'cnn_model_{timestamp}_{sig}.keras'
    model.save(path)
    print(f'Saved model to {path}')
    return path


model_path = save_model_artifact()
experiment_log_df = append_experiment_row()
experiment_log_df.tail(3)
# Out:
# Saved model to /home/jestin/ThesisRepo/ML/NewReports/DynamicReports/cnn_model_2026-05-14_23-07-51_3d09db3c35db.keras
# Experiment log: /home/jestin/ThesisRepo/ML/NewReports/DynamicReports/experiment_results.csv (2 rows)
#              timestamp                                         data_paths  \
# 0  2026-05-14 22:53:54  ["/home/jestin/ThesisRepo/ML/NewTestData/1_Ala...
# 1  2026-05-14 23:07:51  ["/home/jestin/ThesisRepo/ML/NewTestData/1_Ala...
#
#    data_paths_count                                    batch_test_root  \
# 0                11  /home/jestin/ThesisRepo/ML/NewTestData/15_Tash...
# 1                11  /home/jestin/ThesisRepo/ML/NewTestData/15_Tash...
#
#    sensor_cols_count                                        sensor_cols  \
# 0                176  ["left_wrist_heading","left_wrist_pitch","left...
# 1                176  ["left_wrist_heading","left_wrist_pitch","left...
#
#    resample_to_n_steps  apply_butterworth  butterworth_cutoff_hz  \
# 0                   90               True                   10.0
# 1                   90               True                   10.0
#
#    butterworth_order  ...  final_val_accuracy final_train_loss  \
# 0                  4  ...            0.875000         0.130827
# 1                  4  ...            0.988636         0.037853
#
#    final_val_loss  best_val_accuracy  best_val_loss  test_accuracy  test_loss  \
# 0        0.345132                1.0       0.007226            1.0   0.003620
# 1        0.023838                1.0       0.003258            1.0   0.002371
#
#    batch_test_accuracy                                       history_json  \
# 0             0.766667  {"accuracy":[0.272857129573822,0.4671428501605...
# 1             0.700000  {"accuracy":[0.3085714280605316,0.534285724163...
#
#                                        row_signature
# 0  3b3ad77d3c3db21021563c21f7aac17e47f6a8b7ee7ba9...
# 1  3d09db3c35db35d224b8f97bf4030f746f5cf1cd720dc1...
#
# [2 rows x 48 columns]

# %% [markdown]
# ## 15. Export PDF report (parameters, paths, results)
#
# Builds a compact PDF summarising the configuration, data locations, CV folds, hold-out and
# batch-test results, and the saved model path. Uses only `reportlab` so it works in any env.

# %%
from reportlab.lib.pagesizes import A4
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.lib.units import mm
from reportlab.lib import colors
from reportlab.platypus import (
    SimpleDocTemplate, Paragraph, Spacer, Table, TableStyle, Image, PageBreak
)
from reportlab.lib.enums import TA_LEFT


def _fmt(v, nd=4):
    if v is None:
        return '—'
    if isinstance(v, float):
        return f'{v:.{nd}f}'
    return str(v)


_VAL_STYLE = ParagraphStyle('KVValue', fontName='Helvetica', fontSize=7.5, leading=9.5,
                            textColor=colors.HexColor('#222222'))
_KEY_STYLE = ParagraphStyle('KVKey',   fontName='Helvetica-Bold', fontSize=7.5, leading=9.5,
                            textColor=colors.HexColor('#333333'))


def _wrap(text, style=_VAL_STYLE):
    if isinstance(text, Paragraph):
        return text
    s = str(text).replace('&', '&amp;').replace('<', '&lt;').replace('>', '&gt;')
    return Paragraph(s, style)


def _kv_table(rows, col_widths=(50*mm, 135*mm)):
    wrapped = [[_wrap(r[0], _KEY_STYLE), _wrap(r[1], _VAL_STYLE)] for r in rows]
    tbl = Table(wrapped, colWidths=col_widths, hAlign='LEFT')
    tbl.setStyle(TableStyle([
        ('VALIGN',       (0, 0), (-1, -1), 'TOP'),
        ('BOTTOMPADDING',(0, 0), (-1, -1), 1),
        ('TOPPADDING',   (0, 0), (-1, -1), 1),
        ('LINEBELOW',    (0, 0), (-1, -2), 0.25, colors.HexColor('#dddddd')),
    ]))
    return tbl


def _section(title, styles):
    return Paragraph(f'<b>{title}</b>', styles['Section'])


def _build_comparison_chart(variant_results, out_path, batch_subject):
    fig, ax = plt.subplots(figsize=(9, 4.5))
    labels    = [r['name'] for r in variant_results]
    cv_means  = [r['cv_mean'] if r['cv_mean'] is not None else 0 for r in variant_results]
    cv_stds   = [r['cv_std']  if r['cv_std']  is not None else 0 for r in variant_results]
    test_accs = [r['test_accuracy'] for r in variant_results]
    batch_acc = [r['batch_accuracy'] if r['batch_accuracy'] is not None else 0 for r in variant_results]
    x = np.arange(len(labels)); w = 0.27
    ax.bar(x - w, cv_means,  w, yerr=cv_stds, capsize=3, label=f'CV mean (k={CV_FOLDS})', color='#4c78a8')
    ax.bar(x,     test_accs, w, label='Hold-out', color='#f58518')
    ax.bar(x + w, batch_acc, w, label=f'Batch ({batch_subject})', color='#54a24b')
    ax.set_xticks(x); ax.set_xticklabels(labels, rotation=0)
    ax.set_ylim(0, 1.05); ax.set_ylabel('Accuracy')
    ax.set_title('1D CNN architecture variants — accuracy comparison')
    ax.legend(loc='lower right', fontsize=8); ax.grid(axis='y', alpha=0.3)
    for i, v in enumerate(test_accs):
        ax.text(i, v + 0.02, f'{v:.2f}', ha='center', fontsize=7)
    plt.tight_layout()
    plt.savefig(out_path, dpi=140); plt.close()


def export_variants_report_pdf(out_path):
    styles = getSampleStyleSheet()
    styles.add(ParagraphStyle(name='Section',    parent=styles['Heading2'],
                              fontSize=11, spaceBefore=6, spaceAfter=2,
                              textColor=colors.HexColor('#1a3a6c')))
    styles.add(ParagraphStyle(name='SubSection', parent=styles['Heading3'],
                              fontSize=9.5, spaceBefore=4, spaceAfter=1,
                              textColor=colors.HexColor('#2a4a7c')))
    styles.add(ParagraphStyle(name='Small',      parent=styles['BodyText'],
                              fontSize=8, leading=10))
    styles['Title'].fontSize = 15
    styles['Title'].spaceAfter = 4
    styles['Title'].alignment = TA_LEFT

    doc = SimpleDocTemplate(
        str(out_path), pagesize=A4,
        leftMargin=12*mm, rightMargin=12*mm,
        topMargin=10*mm, bottomMargin=10*mm,
        title='1D CNN Variant Comparison',
    )
    story = []
    batch_subject = os.path.basename(os.path.dirname(str(BATCH_TEST_ROOT).rstrip('/'))) or 'batch'

    # Header
    story.append(Paragraph('1D CNN — Architecture Variant Comparison', styles['Title']))
    story.append(Paragraph(f"Generated {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}", styles['Small']))
    story.append(Spacer(1, 4))

    # Data + config
    story.append(_section('Data &amp; configuration', styles))
    dp_rows = [[f'Training path {i+1}', p] for i, p in enumerate(ACTIVE_DATA_PATHS or [])]
    aug_enabled = ', '.join(n for n, c in AUGMENT_CONFIG.items() if c.get('enabled')) or 'no transforms enabled'
    dp_rows += [
        ['Batch-test root',     str(BATCH_TEST_ROOT)],
        ['Total trials',        f'{X.shape[0]} (train pool {X_train_pool.shape[0]}, hold-out {X_test.shape[0]})'],
        ['Classes',             f'{n_classes}: ' + ', '.join(le.classes_)],
        ['Sensor channels',     f'{n_channels} (sequence length {sequence_length})'],
        ['Resample / filter',   f'{RESAMPLE_TO_N_STEPS} steps · Butterworth cutoff {BUTTERWORTH_CUTOFF_HZ} Hz, order {BUTTERWORTH_ORDER}'],
        ['Normalisation',       str(NORMALISATION)],
        ['CV folds · shuffle',   f'{CV_FOLDS} · {CV_SHUFFLE}'],
        ['Augmentation',        ('on' if AUGMENT_TRAINING_DATA else 'off') + f' · copies={AUGMENTATION_COPIES_PER_SAMPLE} · ' + aug_enabled],
        ['Epochs · batch size',  f'{TRAIN_EPOCHS} · {TRAIN_BATCH_SIZE}'],
    ]
    story.append(_kv_table(dp_rows))

    # Comparison summary table
    story.append(_section('Variant comparison (summary)', styles))
    summary_rows = [['Variant', 'Params', f'CV mean (k={CV_FOLDS})', 'CV std',
                     'Hold-out acc', 'Hold-out loss', 'Batch acc', 'Batch n']]
    for r in variant_results:
        summary_rows.append([
            r['name'],
            f"{r['n_params']:,}",
            _fmt(r['cv_mean'], 4),
            _fmt(r['cv_std'], 4),
            _fmt(r['test_accuracy'], 4),
            _fmt(r['test_loss'], 4),
            _fmt(r['batch_accuracy'], 4) if r['batch_accuracy'] is not None else '—',
            f"{r['batch_correct']}/{r['batch_total']}" if r['batch_total'] else '—',
        ])
    best_test = max(variant_results, key=lambda r: r['test_accuracy'])['name']
    best_cv   = max(variant_results, key=lambda r: r['cv_mean'] or 0)['name']
    summary_t = Table(summary_rows, hAlign='LEFT',
                      colWidths=(22*mm, 22*mm, 24*mm, 18*mm, 24*mm, 22*mm, 22*mm, 18*mm))
    style_cmds = [
        ('FONT',         (0, 0), (-1, -1), 'Helvetica',     7.5),
        ('FONT',         (0, 0), (-1,  0), 'Helvetica-Bold', 7.5),
        ('BACKGROUND',   (0, 0), (-1,  0), colors.HexColor('#eef2f7')),
        ('GRID',         (0, 0), (-1, -1), 0.25, colors.HexColor('#cccccc')),
        ('VALIGN',       (0, 0), (-1, -1), 'MIDDLE'),
        ('ALIGN',        (1, 1), (-1, -1), 'CENTER'),
        ('BOTTOMPADDING',(0, 0), (-1, -1), 1),
        ('TOPPADDING',   (0, 0), (-1, -1), 1),
    ]
    for i, r in enumerate(variant_results, start=1):
        if r['name'] == best_test:
            style_cmds.append(('BACKGROUND', (0, i), (-1, i), colors.HexColor('#fff7e0')))
    summary_t.setStyle(TableStyle(style_cmds))
    story.append(summary_t)
    story.append(Spacer(1, 3))
    story.append(Paragraph(f'Best on hold-out: <b>{best_test}</b> · Best on CV: <b>{best_cv}</b>', styles['Small']))

    # Comparison chart
    cmp_chart = MODEL_OUTPUT_DIR / 'variants_comparison.png'
    _build_comparison_chart(variant_results, cmp_chart, batch_subject)
    img_w = 175*mm
    if cmp_chart.exists():
        story.append(Spacer(1, 4))
        story.append(Image(str(cmp_chart), width=img_w, height=img_w*0.5))

    # Training curves (already saved by curves cell)
    curves_path = MODEL_OUTPUT_DIR / 'training_curves.png'
    story.append(_section('Training curves (final retrain on full training pool)', styles))
    if curves_path.exists():
        story.append(Image(str(curves_path), width=img_w, height=img_w*0.36))

    # Per-variant detail pages
    for r in variant_results:
        story.append(PageBreak())
        story.append(Paragraph(f'Variant: {r["name"]}', styles['Title']))
        story.append(Paragraph(r['description'], styles['Small']))
        story.append(Spacer(1, 4))

        story.append(_kv_table([
            ['Trainable params',         f'{r["n_params"]:,}'],
            ['CV mean ± std',           f'{_fmt(r["cv_mean"])} ± {_fmt(r["cv_std"])}'],
            ['Hold-out test acc / loss', f'{_fmt(r["test_accuracy"])} · {_fmt(r["test_loss"])}'],
            ['Batch-test acc',
             f'{_fmt(r["batch_accuracy"])}  ({r["batch_correct"]}/{r["batch_total"]})'
             if r['batch_total'] else '—'],
        ]))

        if r['cv_fold_results']:
            story.append(Paragraph('<b>Cross-validation folds</b>', styles['SubSection']))
            ftbl = [['Fold', 'Train (post-aug)', 'Val', 'Val acc', 'Best val', 'Final val']]
            for fr in r['cv_fold_results']:
                ftbl.append([fr['fold'], fr['train_after_aug'], fr['val_samples'],
                             _fmt(fr['val_accuracy']),
                             _fmt(fr['best_val_accuracy']),
                             _fmt(fr['final_val_accuracy'])])
            t = Table(ftbl, hAlign='LEFT',
                      colWidths=(12*mm, 30*mm, 16*mm, 22*mm, 22*mm, 22*mm))
            t.setStyle(TableStyle([
                ('FONT',         (0, 0), (-1, -1), 'Helvetica',     7.5),
                ('FONT',         (0, 0), (-1,  0), 'Helvetica-Bold', 7.5),
                ('BACKGROUND',   (0, 0), (-1,  0), colors.HexColor('#eef2f7')),
                ('GRID',         (0, 0), (-1, -1), 0.25, colors.HexColor('#cccccc')),
                ('VALIGN',       (0, 0), (-1, -1), 'MIDDLE'),
                ('ALIGN',        (1, 1), (-1, -1), 'CENTER'),
                ('BOTTOMPADDING',(0, 0), (-1, -1), 1),
                ('TOPPADDING',   (0, 0), (-1, -1), 1),
            ]))
            story.append(t)

        # Per-class hold-out metrics
        story.append(Paragraph('<b>Per-class hold-out metrics</b>', styles['SubSection']))
        rep = r['classification_report']
        _cell = ParagraphStyle('Cell', fontName='Helvetica', fontSize=7, leading=8.5)
        cls_rows = [['Class', 'Precision', 'Recall', 'F1', 'Support']]
        for cls in le.classes_:
            d = rep.get(cls, {})
            cls_rows.append([_wrap(cls, _cell),
                             _fmt(d.get('precision'), 3),
                             _fmt(d.get('recall'), 3),
                             _fmt(d.get('f1-score'), 3),
                             int(d.get('support', 0))])
        for tag in ('macro avg', 'weighted avg'):
            d = rep.get(tag, {})
            cls_rows.append([tag,
                             _fmt(d.get('precision'), 3),
                             _fmt(d.get('recall'), 3),
                             _fmt(d.get('f1-score'), 3),
                             int(d.get('support', 0))])
        ct = Table(cls_rows, hAlign='LEFT', colWidths=(82*mm, 20*mm, 20*mm, 20*mm, 18*mm))
        ct.setStyle(TableStyle([
            ('FONT',         (0, 0), (-1, -1), 'Helvetica',     7),
            ('FONT',         (0, 0), (-1,  0), 'Helvetica-Bold', 7),
            ('FONT',         (0, -2), (-1, -1), 'Helvetica-Oblique', 7),
            ('BACKGROUND',   (0, 0), (-1,  0), colors.HexColor('#eef2f7')),
            ('GRID',         (0, 0), (-1, -1), 0.25, colors.HexColor('#cccccc')),
            ('VALIGN',       (0, 0), (-1, -1), 'MIDDLE'),
            ('ALIGN',        (1, 1), (-1, -1), 'CENTER'),
            ('BOTTOMPADDING',(0, 0), (-1, -1), 1),
            ('TOPPADDING',   (0, 0), (-1, -1), 1),
        ]))
        story.append(ct)

        # Batch-test per class
        if r.get('batch_df') is not None and len(r['batch_df']) > 0:
            story.append(Paragraph(f'<b>Batch test per class ({batch_subject})</b>', styles['SubSection']))
            bt_rows = [['Class', 'Correct', 'Total', 'Accuracy']]
            for cls, g in r['batch_df'].groupby('true'):
                c = int(g['correct'].sum()); n = int(len(g))
                bt_rows.append([_wrap(cls, _cell), c, n, _fmt(c/n if n else 0.0, 3)])
            bt_rows.append(['Overall', r['batch_correct'], r['batch_total'],
                            _fmt(r['batch_accuracy'], 3) if r['batch_accuracy'] is not None else '—'])
            bt = Table(bt_rows, hAlign='LEFT', colWidths=(102*mm, 20*mm, 20*mm, 22*mm))
            bt.setStyle(TableStyle([
                ('FONT',         (0, 0), (-1, -1), 'Helvetica',     7),
                ('FONT',         (0, 0), (-1,  0), 'Helvetica-Bold', 7),
                ('FONT',         (0, -1), (-1, -1), 'Helvetica-Bold', 7),
                ('BACKGROUND',   (0, 0), (-1,  0), colors.HexColor('#eef2f7')),
                ('BACKGROUND',   (0, -1), (-1, -1), colors.HexColor('#fff7e0')),
                ('GRID',         (0, 0), (-1, -1), 0.25, colors.HexColor('#cccccc')),
                ('VALIGN',       (0, 0), (-1, -1), 'MIDDLE'),
                ('ALIGN',        (1, 1), (-1, -1), 'CENTER'),
                ('BOTTOMPADDING',(0, 0), (-1, -1), 1),
                ('TOPPADDING',   (0, 0), (-1, -1), 1),
            ]))
            story.append(bt)

    doc.build(story)
    print(f'PDF report written to {out_path}')
    return out_path


# Unique filename so re-running never overwrites a previous report
_report_timestamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
_report_filename  = f'variants_report_{_report_timestamp}.pdf'
report_pdf_path   = export_variants_report_pdf(MODEL_OUTPUT_DIR / _report_filename)
# Out:
# PDF report written to /home/jestin/ThesisRepo/ML/NewReports/DynamicReports/variants_report_2026-05-14_23-07-51.pdf
