# %% [markdown]
# # 1D CNN — Two-Hand Dynamic Gesture Recognition (multi-variant)
#
# Clean, single-path pipeline for training **several 1D-CNN architecture variants** on the glove data and exporting a comparison PDF.
#
# **Pipeline stages**
# 1. Configuration (data paths, sensor selection, preprocessing, augmentation, training)
# 2. Sensor column selection
# 3. Load CSVs from `DynamicTrainingData/TwoSec`
# 4. Preprocess: resample to fixed length + Butterworth low-pass filter
# 5. Train/test split (hold-out)
# 6. Cross-validation with augmentation **inside** each fold (so the validation set is never augmented)
# 7. Final retrain on the full training pool and evaluation on hold-out
# 8. Batch test on `TestData/Jestin/TwoHandDynamic` using per-subfolder labels
# 9. Save model + log experiment row
#
# Only the CNN-on-sequences path is supported here. Engineered-feature/MLP variants have been removed to keep the notebook readable.

# %% [markdown]
# ## 1. Imports

# %%
import os
import re
import glob
import json
import hashlib
import warnings
from pathlib import Path
from datetime import datetime
from collections import Counter

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy import signal as scipy_signal
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout

warnings.filterwarnings('ignore')
np.random.seed(42)
pd.set_option('display.max_columns', 20)
print('Imports OK.')
# Out:
# Imports OK.

# %% [markdown]
# ## 2. Configuration
#
# All knobs in one place. Edit only this cell to run different experiments.

# %%
BATCH_TEST_ROOT = '/home/jestin/ThesisRepo/ML/NewTestData/15_Tash/Dynamic'

# %%
# ── Data locations ───────────────────────────────────────────────────────────
# You can include data from MULTIPLE users / source folders.
#
# Each entry in DATA_PATHS is a folder that DIRECTLY contains gesture-label
# subfolders (e.g. .../Alan/Dynamic, .../Bridgette/Dynamic). All matching label
# folders across these paths are merged by label name, so e.g.
# Alan/Dynamic/Wave and Bridgette/Dynamic/Wave end up in the same "Wave" class.
#
# Tip: comment out a path to exclude that user from training without deleting it.
DATA_PATHS = [
    # '/home/jestin/ThesisRepo/ML/NewTrainingData/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/1_Alan/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/2_Alex/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/3_Anghad/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/4_Daniel/Dynamic',
    # '/home/jestin/ThesisRepo/ML/NewTestData/5_Georgia/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/6_Harry/Dynamic',
    # '/home/jestin/ThesisRepo/ML/NewTestData/7_Henry/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/8_Jestin/Dynamic',
    # '/home/jestin/ThesisRepo/ML/NewTestData/9_Joselyn/Dynamic',
    # '/home/jestin/ThesisRepo/ML/NewTestData/10_Josh/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/11_Mansh/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/12_Marcus/Dynamic',
    # '/home/jestin/ThesisRepo/ML/NewTestData/13_Nat/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/14_StephenV2/Dynamic',
    # '/home/jestin/ThesisRepo/ML/NewTestData/15_Tash/Dynamic',
    # '/home/jestin/ThesisRepo/ML/NewTestData/16_Bella/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/17_Raquel/Dynamic',
    '/home/jestin/ThesisRepo/ML/NewTestData/18_Bridgette/Dynamic'

]


# Backwards-compat shortcut: set DATA_ROOT to a string and leave DATA_PATHS = None
# (or empty) to use the old single-folder workflow.
DATA_ROOT = None

INCLUDE_LABELS  = None   # None = use every label subfolder found

# ── Sensor selection ─────────────────────────────────────────────────────────
USE_LEFT_HAND  = True
USE_RIGHT_HAND = True

USE_YPR        = True   # yaw / pitch / roll (or heading/pitch/roll for wrist)
USE_QUAT       = False   # quaternion w/x/y/z
USE_ACCEL      = True   # ax / ay / az
USE_FLEX       = True   # mcp_flex / pip_flex (fingers only)

# Segments to include
USE_WRIST  = True
USE_PALM   = True
USE_THUMB  = True
USE_INDEX  = True
USE_MIDDLE = True
USE_RING   = True
USE_PINKY  = True

# ── Preprocessing ────────────────────────────────────────────────────────────
RESAMPLE_TO_N_STEPS    = 90
APPLY_BUTTERWORTH      = True
BUTTERWORTH_CUTOFF_HZ  = 15.0
BUTTERWORTH_ORDER      = 4
SAMPLING_RATE_HZ       = 30.0
NORMALISATION          = 'minmax'   # 'standard' | 'minmax' | None

# ── Train/test split ─────────────────────────────────────────────────────────
TEST_SIZE             = 0.10
RANDOM_STATE          = 42
STRATIFY_SPLIT        = True

# ── Cross-validation ─────────────────────────────────────────────────────────
RUN_CROSS_VALIDATION  = True
CV_FOLDS              = 5
CV_SHUFFLE            = True

# ── Augmentation (training only, inside each CV fold) ────────────────────────
AUGMENT_TRAINING_DATA          = True
AUGMENTATION_COPIES_PER_SAMPLE = 5
AUGMENTATION_RANDOM_SEED       = 42
AUGMENT_CONFIG = {
    'time_shift':      {'enabled': False,  'apply_prob': 0.7, 'max_shift_steps': 3, 'fill_mode': 'edge'},
    'time_warp':       {'enabled': False,  'apply_prob': 0.5, 'speed_range': (0.90, 1.10)},
    'time_mask':       {'enabled': False,  'apply_prob': 0.5, 'max_masks': 2, 'max_mask_size': 3, 'fill_mode': 'zero'},
    'gaussian_noise':  {'enabled': False,  'apply_prob': 1.0, 'std_ratio': 0.02},
    'amplitude_scale': {'enabled': True,  'apply_prob': 0.5, 'scale_range': (0.95, 1.05)},
    'baseline_offset': {'enabled': True,  'apply_prob': 0.5, 'offset_std_ratio': 0.02},
    'channel_dropout': {'enabled': False,  'apply_prob': 0.3, 'drop_fraction': 0.03, 'fill_mode': 'zero'},
    # Only enable left/right swap if the class label is symmetric under that swap
    'left_right_swap': {'enabled': False, 'apply_prob': 0.5},
}

# // ── Model architecture ─────────────────────────────────────────────────────
SELECTED_VARIANTS = ['Baseline', 'BN_GAP', 'WideKernel']  # <-- change me

# ── Training hyperparameters ─────────────────────────────────────────────────
TRAIN_EPOCHS           = 15
TRAIN_BATCH_SIZE       = 16
TRAIN_VALIDATION_SPLIT = 0.2   # only used by the final retrain (not by CV)
TRAIN_VERBOSE          = 1

# ── Output paths ─────────────────────────────────────────────────────────────
MODEL_OUTPUT_DIR     = Path('saved_models')
EXPERIMENT_LOG_PATH  = MODEL_OUTPUT_DIR / 'experiment_results.csv'
MODEL_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Resolve active data paths (supports both DATA_PATHS list and legacy DATA_ROOT)
ACTIVE_DATA_PATHS = []
if DATA_PATHS:
    ACTIVE_DATA_PATHS = [p for p in DATA_PATHS if p and not p.strip().startswith('#')]
if not ACTIVE_DATA_PATHS and DATA_ROOT:
    ACTIVE_DATA_PATHS = [DATA_ROOT]

print('Configuration loaded.')
print(f'  Data paths ({len(ACTIVE_DATA_PATHS)}):')
for p in ACTIVE_DATA_PATHS:
    print(f'    - {p}')
# Out:
# Configuration loaded.
#   Data paths (11):
#     - /home/jestin/ThesisRepo/ML/NewTestData/1_Alan/Dynamic
#     - /home/jestin/ThesisRepo/ML/NewTestData/2_Alex/Dynamic
#     - /home/jestin/ThesisRepo/ML/NewTestData/3_Anghad/Dynamic
#     - /home/jestin/ThesisRepo/ML/NewTestData/4_Daniel/Dynamic
#     - /home/jestin/ThesisRepo/ML/NewTestData/6_Harry/Dynamic
#     - /home/jestin/ThesisRepo/ML/NewTestData/8_Jestin/Dynamic
#     - /home/jestin/ThesisRepo/ML/NewTestData/11_Mansh/Dynamic
#     - /home/jestin/ThesisRepo/ML/NewTestData/12_Marcus/Dynamic
#     - /home/jestin/ThesisRepo/ML/NewTestData/14_StephenV2/Dynamic
#     - /home/jestin/ThesisRepo/ML/NewTestData/17_Raquel/Dynamic
#     - /home/jestin/ThesisRepo/ML/NewTestData/18_Bridgette/Dynamic

# %%
from tensorflow.keras.layers import (
    BatchNormalization, GlobalAveragePooling1D, Activation, Input,
    LSTM, Bidirectional,
)
from tensorflow.keras.models import Sequential


def build_baseline(seq_len, n_chan, n_classes):
    """Original architecture from the notebook."""
    m = Sequential([
        Input(shape=(seq_len, n_chan)),
        Conv1D(32, 4, activation='relu'),
        MaxPooling1D(2),
        Conv1D(64, 4, activation='relu'),
        MaxPooling1D(2),
        Flatten(),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(n_classes, activation='softmax'),
    ], name='Baseline')
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return m


def build_shallow(seq_len, n_chan, n_classes):
    """Single Conv block — fewer params, faster to train."""
    m = Sequential([
        Input(shape=(seq_len, n_chan)),
        Conv1D(32, 5, activation='relu'),
        MaxPooling1D(2),
        Flatten(),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(n_classes, activation='softmax'),
    ], name='Shallow')
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return m


def build_deep(seq_len, n_chan, n_classes):
    """Three Conv blocks — more representational depth."""
    m = Sequential([
        Input(shape=(seq_len, n_chan)),
        Conv1D(32, 4, activation='relu'),
        MaxPooling1D(2),
        Conv1D(64, 4, activation='relu'),
        MaxPooling1D(2),
        Conv1D(128, 3, activation='relu'),
        MaxPooling1D(2),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.4),
        Dense(n_classes, activation='softmax'),
    ], name='Deep')
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return m


def build_bn_gap(seq_len, n_chan, n_classes):
    """BatchNorm + GlobalAveragePooling — typically better generalisation, fewer params."""
    m = Sequential([
        Input(shape=(seq_len, n_chan)),
        Conv1D(32, 4, padding='same'),
        BatchNormalization(), Activation('relu'),
        MaxPooling1D(2),
        Conv1D(64, 4, padding='same'),
        BatchNormalization(), Activation('relu'),
        MaxPooling1D(2),
        Conv1D(128, 3, padding='same'),
        BatchNormalization(), Activation('relu'),
        GlobalAveragePooling1D(),
        Dropout(0.3),
        Dense(n_classes, activation='softmax'),
    ], name='BN_GAP')
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return m


def build_wide_kernel(seq_len, n_chan, n_classes):
    """Wider kernels — larger temporal receptive field per layer."""
    m = Sequential([
        Input(shape=(seq_len, n_chan)),
        Conv1D(32, 8, activation='relu'),
        MaxPooling1D(2),
        Conv1D(64, 8, activation='relu'),
        MaxPooling1D(2),
        Flatten(),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(n_classes, activation='softmax'),
    ], name='WideKernel')
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return m


def build_cnn_lstm(seq_len, n_chan, n_classes):
    """CNN feature extractor → LSTM temporal model.

    Two Conv1D blocks pull out local temporal features, then a single LSTM
    consumes the resulting (T', F) sequence and a final Dense head classifies.
    Conv layers use padding='same' so MaxPooling controls the temporal
    downsampling explicitly.
    """
    m = Sequential([
        Input(shape=(seq_len, n_chan)),
        Conv1D(32, 4, padding='same', activation='relu'),
        MaxPooling1D(2),
        Conv1D(64, 4, padding='same', activation='relu'),
        MaxPooling1D(2),
        Dropout(0.3),
        LSTM(64, return_sequences=False),
        Dropout(0.3),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(n_classes, activation='softmax'),
    ], name='CNN_LSTM')
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return m


def build_cnn_bilstm(seq_len, n_chan, n_classes):
    """CNN feature extractor → Bidirectional LSTM temporal model.

    Same Conv front-end as CNN_LSTM but the recurrent stage is bidirectional,
    so each timestep's representation sees both past and future context within
    the trial — useful for gestures where the discriminative motion can sit
    anywhere along the trial.
    """
    m = Sequential([
        Input(shape=(seq_len, n_chan)),
        Conv1D(32, 4, padding='same', activation='relu'),
        MaxPooling1D(2),
        Conv1D(64, 4, padding='same', activation='relu'),
        MaxPooling1D(2),
        Dropout(0.3),
        Bidirectional(LSTM(64, return_sequences=False)),
        Dropout(0.3),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(n_classes, activation='softmax'),
    ], name='CNN_BiLSTM')
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return m


VARIANTS = [
    ('Baseline',   'Conv1D(32,k=4)→Pool→Conv1D(64,k=4)→Pool→Flatten→Dense(64)→Dropout(0.3)→Softmax', build_baseline),
    ('Shallow',    'Single Conv block: Conv1D(32,k=5)→Pool→Flatten→Dense(32)→Dropout(0.3)→Softmax',           build_shallow),
    ('Deep',       'Three Conv blocks: Conv1D(32,4)→Conv1D(64,4)→Conv1D(128,3)→Flatten→Dense(128)→Dropout(0.4)→Softmax', build_deep),
    ('BN_GAP',     'Conv+BN+ReLU ×3 with GlobalAveragePooling1D head — fewer params, less overfit',                build_bn_gap),
    ('WideKernel', 'Conv1D(32,k=8)→Pool→Conv1D(64,k=8)→Pool→Flatten→Dense(64)→Dropout(0.3)→Softmax', build_wide_kernel),
    ('CNN_LSTM',   'Conv1D(32,4)→Pool→Conv1D(64,4)→Pool→Dropout→LSTM(64)→Dense(64)→Dropout→Softmax',           build_cnn_lstm),
    ('CNN_BiLSTM', 'Conv1D(32,4)→Pool→Conv1D(64,4)→Pool→Dropout→BiLSTM(64)→Dense(64)→Dropout→Softmax',         build_cnn_bilstm),
]

# Container populated by the CV / retrain / hold-out / batch-test cells below.
# Each entry: dict with name, description, n_params, cv_results, cv_mean, cv_std,
# history, test_accuracy, test_loss, classification_report, y_pred, batch_df,
# batch_correct, batch_total, batch_accuracy, model, model_path, scaler.
variant_results = []
print(f'Configured {len(VARIANTS)} variants:')
for n, d, _ in VARIANTS:
    print(f'  - {n}: {d}')
# Out:
# Configured 7 variants:
#   - Baseline: Conv1D(32,k=4)→Pool→Conv1D(64,k=4)→Pool→Flatten→Dense(64)→Dropout(0.3)→Softmax
#   - Shallow: Single Conv block: Conv1D(32,k=5)→Pool→Flatten→Dense(32)→Dropout(0.3)→Softmax
#   - Deep: Three Conv blocks: Conv1D(32,4)→Conv1D(64,4)→Conv1D(128,3)→Flatten→Dense(128)→Dropout(0.4)→Softmax
#   - BN_GAP: Conv+BN+ReLU ×3 with GlobalAveragePooling1D head — fewer params, less overfit
#   - WideKernel: Conv1D(32,k=8)→Pool→Conv1D(64,k=8)→Pool→Flatten→Dense(64)→Dropout(0.3)→Softmax
#   - CNN_LSTM: Conv1D(32,4)→Pool→Conv1D(64,4)→Pool→Dropout→LSTM(64)→Dense(64)→Dropout→Softmax
#   - CNN_BiLSTM: Conv1D(32,4)→Pool→Conv1D(64,4)→Pool→Dropout→BiLSTM(64)→Dense(64)→Dropout→Softmax

# %% [markdown]
# ## 6b. Select which classifiers to run
#
# Choose which architectures from the `VARIANTS` list above should be trained, cross-validated and evaluated downstream. Two equivalent ways are provided:
#
# 1. **Quick / scripted** — edit the `SELECTED_VARIANTS` list below.
# 2. **Interactive** — run the cell and use the checkbox UI (requires `ipywidgets`).    Tick the boxes you want and click **Apply selection**; the chosen variants are    written back to `SELECTED_VARIANTS` and the resolved `ACTIVE_VARIANTS` list.
#
# Every downstream cell (cross-validation, final retrain, training curves, hold-out test, batch test, model save, PDF report) iterates over the selection automatically. Use `SELECTED_VARIANTS = None` (or an empty list) to keep all variants active.

# %%
# Edit this list to pick the architectures you want to train.
# Use None or [] to keep ALL variants from VARIANTS active.
# Names must match the first element of each tuple in VARIANTS (case-insensitive).


# ── Resolve SELECTED_VARIANTS -> ACTIVE_VARIANTS ──────────────────────────
def _resolve_active_variants(selected, all_variants):
    """Return the subset of all_variants whose names appear in `selected`.
    Preserves the order of `selected` so the report tables match user intent.
    If `selected` is None or empty, returns all_variants unchanged.
    """
    if not selected:
        return list(all_variants)
    by_name = {n.lower(): (n, d, b) for (n, d, b) in all_variants}
    resolved, unknown = [], []
    for s in selected:
        key = s.strip().lower()
        if key in by_name:
            resolved.append(by_name[key])
        else:
            unknown.append(s)
    if unknown:
        known = ', '.join(n for n, _, _ in all_variants)
        raise ValueError(
            f'Unknown variant(s): {unknown!r}. Available: {known}'
        )
    return resolved

ACTIVE_VARIANTS = _resolve_active_variants(SELECTED_VARIANTS, VARIANTS)
print(f'Active variants ({len(ACTIVE_VARIANTS)}/{len(VARIANTS)}):')
for n, _, _ in ACTIVE_VARIANTS:
    print(f'  ✓ {n}')
skipped = [n for n, _, _ in VARIANTS if n not in {a[0] for a in ACTIVE_VARIANTS}]
if skipped:
    print('Skipped:')
    for n in skipped:
        print(f'  · {n}')

# ── Optional interactive checkbox UI ──────────────────────────────────────
# Shown when ipywidgets is available; clicking 'Apply selection' updates
# SELECTED_VARIANTS and ACTIVE_VARIANTS in this notebook's namespace.
try:
    import ipywidgets as widgets
    from IPython.display import display

    _initial = {n for n, _, _ in ACTIVE_VARIANTS}
    _checkboxes = [
        widgets.Checkbox(value=(n in _initial), description=n, indent=False)
        for n, _, _ in VARIANTS
    ]
    _apply_btn = widgets.Button(description='Apply selection', button_style='primary')
    _all_btn   = widgets.Button(description='Select all')
    _none_btn  = widgets.Button(description='Clear')
    _output    = widgets.Output()

    def _on_apply(_):
        chosen = [cb.description for cb in _checkboxes if cb.value]
        # Mutate the module-level names so downstream cells see the new selection
        globals()['SELECTED_VARIANTS'] = chosen if chosen else None
        globals()['ACTIVE_VARIANTS'] = _resolve_active_variants(
            globals()['SELECTED_VARIANTS'], VARIANTS
        )
        with _output:
            _output.clear_output()
            if not chosen:
                print(f'No boxes ticked – keeping ALL {len(VARIANTS)} variants active.')
            else:
                print(f'Active variants ({len(chosen)}/{len(VARIANTS)}): {chosen}')

    def _on_all(_):
        for cb in _checkboxes: cb.value = True
    def _on_none(_):
        for cb in _checkboxes: cb.value = False

    _apply_btn.on_click(_on_apply)
    _all_btn.on_click(_on_all)
    _none_btn.on_click(_on_none)

    print()  # spacer
    display(
        widgets.VBox([
            widgets.HTML('<b>Tick the classifiers to include, then click Apply selection:</b>'),
            widgets.GridBox(_checkboxes,
                            layout=widgets.Layout(grid_template_columns='repeat(3, max-content)',
                                                  grid_gap='4px 24px')),
            widgets.HBox([_apply_btn, _all_btn, _none_btn]),
            _output,
        ])
    )
except ImportError:
    print('\n(ipywidgets not installed — edit SELECTED_VARIANTS above and re-run this cell.)')

# %% [markdown]
# ## 3. Sensor column selection
#
# Build the list of channel names that match the configuration toggles. The CSVs share a known column schema, so we generate names directly rather than parsing every header.

# %%
SEGMENTS_WITH_FLEX = ['thumb', 'index', 'middle', 'ring', 'pinky']  # palm has no flex


def build_sensor_columns(hands, segments, use_ypr, use_quat, use_accel, use_flex):
    cols = []
    for hand in hands:
        for seg in segments:
            if seg == 'wrist':
                # wrist has a single IMU; YPR fields are heading/pitch/roll
                p = f'{hand}_wrist'
                if use_ypr:   cols += [f'{p}_heading', f'{p}_pitch', f'{p}_roll']
                if use_quat:  cols += [f'{p}_quat_w', f'{p}_quat_x', f'{p}_quat_y', f'{p}_quat_z']
                if use_accel: cols += [f'{p}_ax', f'{p}_ay', f'{p}_az']
                # no flex on wrist
            else:
                for loc in ['mid', 'prox']:
                    p = f'{hand}_{seg}_{loc}'
                    if use_ypr:   cols += [f'{p}_yaw', f'{p}_pitch', f'{p}_roll']
                    if use_quat:  cols += [f'{p}_quat_w', f'{p}_quat_x', f'{p}_quat_y', f'{p}_quat_z']
                    if use_accel: cols += [f'{p}_ax', f'{p}_ay', f'{p}_az']
                if use_flex and seg in SEGMENTS_WITH_FLEX:
                    cols += [f'{hand}_{seg}_mcp_flex', f'{hand}_{seg}_pip_flex']
    return cols


resolved_hands = [h for h, on in [('left', USE_LEFT_HAND), ('right', USE_RIGHT_HAND)] if on]
resolved_segs = [s for s, on in [
    ('wrist', USE_WRIST), ('palm', USE_PALM), ('thumb', USE_THUMB),
    ('index', USE_INDEX), ('middle', USE_MIDDLE), ('ring', USE_RING), ('pinky', USE_PINKY)
] if on]

SENSOR_COLS = build_sensor_columns(
    hands=resolved_hands, segments=resolved_segs,
    use_ypr=USE_YPR, use_quat=USE_QUAT, use_accel=USE_ACCEL, use_flex=USE_FLEX,
)

print(f'Selected {len(SENSOR_COLS)} sensor columns.')
print('First 6:', SENSOR_COLS[:6])
print('Last  6:', SENSOR_COLS[-6:])
# Out:
# Selected 176 sensor columns.
# First 6: ['left_wrist_heading', 'left_wrist_pitch', 'left_wrist_roll', 'left_wrist_ax', 'left_wrist_ay', 'left_wrist_az']
# Last  6: ['right_pinky_prox_roll', 'right_pinky_prox_ax', 'right_pinky_prox_ay', 'right_pinky_prox_az', 'right_pinky_mcp_flex', 'right_pinky_pip_flex']

# %% [markdown]
# ## 4. Load training data
#
# Walk the label subfolders under `DATA_ROOT` and read each CSV as a `(T, C)` array of the selected sensor channels.

# %%
def load_dataset(data_paths, include_labels, sensor_cols):
    """
    Load all CSVs from gesture-label subfolders found inside each path in
    `data_paths`. Trials from the same label across different source folders
    are merged into a single class.

    Returns:
        trials      : list of np.ndarray (per-trial sensor matrices)
        labels      : list of class label strings
        class_names : sorted list of unique class labels
        source_info : list of source label-folder paths per trial (parallel to trials)
    """
    if isinstance(data_paths, str):
        data_paths = [data_paths]
    if not data_paths:
        raise ValueError('No data paths provided. Set DATA_PATHS or DATA_ROOT.')

    resolved_paths = []
    for p in data_paths:
        p_exp = os.path.expanduser(p)
        if not os.path.isdir(p_exp):
            raise FileNotFoundError(
                f"Data path not found: {p_exp!r}\n"
                "Update DATA_PATHS in the Configuration cell."
            )
        resolved_paths.append(p_exp)

    SKIP = {'PDF', 'sdb', 'idk'}
    label_to_folders = {}   # label -> list of full folder paths
    for root in resolved_paths:
        for d in sorted(os.listdir(root)):
            full = os.path.join(root, d)
            if not os.path.isdir(full) or d in SKIP:
                continue
            label_to_folders.setdefault(d, []).append(full)

    if include_labels is not None:
        label_to_folders = {k: v for k, v in label_to_folders.items()
                            if k in include_labels}
    if not label_to_folders:
        raise ValueError('No label folders found. Check DATA_PATHS and INCLUDE_LABELS.')

    label_names = sorted(label_to_folders.keys())
    print(f'Found {len(label_names)} gesture classes across {len(resolved_paths)} source folder(s):')

    trials, labels, source_info = [], [], []
    for label in label_names:
        folders = label_to_folders[label]
        per_source_counts = []
        for folder in folders:
            csv_files = sorted(glob.glob(os.path.join(folder, '*.csv')))
            per_source_counts.append((folder, len(csv_files)))
            for fpath in csv_files:
                try:
                    df = pd.read_csv(fpath)
                    available = [c for c in sensor_cols if c in df.columns]
                    if not available:
                        print(f'    WARNING: no matching sensor columns in {os.path.basename(fpath)}')
                        continue
                    trials.append(df[available].values.astype(np.float32))
                    labels.append(label)
                    source_info.append(folder)
                except Exception as e:
                    print(f'    ERROR loading {os.path.basename(fpath)}: {e}')
        total = sum(c for _, c in per_source_counts)
        extra = ''
        if len(per_source_counts) > 1:
            extra = ' from ' + ', '.join(
                f"{os.path.basename(os.path.dirname(fp))}({n})"
                for fp, n in per_source_counts
            )
        print(f'  [{label}]  →  {total} files{extra}')

    print(f'\nTotal trials loaded: {len(trials)}')
    return trials, labels, label_names, source_info


trials_raw, labels_raw, class_names, source_info = load_dataset(
    ACTIVE_DATA_PATHS, INCLUDE_LABELS, SENSOR_COLS
)

print('\nClass distribution:')
for cls, cnt in sorted(Counter(labels_raw).items()):
    print(f'  {cls}: {cnt} trials')

# Per-source-folder distribution
print('\nTrials per source folder:')
for src, cnt in sorted(Counter(source_info).items()):
    tag = os.sep.join(src.split(os.sep)[-3:])
    print(f'  {tag}: {cnt} trials')
# Out:
# Found 7 gesture classes across 11 source folder(s):
#   [Double_Lower]  →  55 files from Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5)
#   [Double_Nothing]  →  51 files from Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(0), Dynamic(5), Dynamic(5), Dynamic(6), Dynamic(5), Dynamic(5)
#   [Double_Pistol_Recoil]  →  55 files from Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5)
#   [Double_Raise]  →  55 files from Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5)
#   [Double_Wiggle]  →  54 files from Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(4), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5)
#   [Double_cmere]  →  56 files from Dynamic(5), Dynamic(5), Dynamic(6), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5)
#   [Drum_Roll]  →  50 files from Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(0), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5), Dynamic(5)
#
# Total trials loaded: 376
#
# Class distribution:
#   Double_Lower: 55 trials
#   Double_Nothing: 51 trials
#   Double_Pistol_Recoil: 55 trials
#   Double_Raise: 55 trials
#   Double_Wiggle: 54 trials
#   Double_cmere: 56 trials
#   Drum_Roll: 50 trials
#
# Trials per source folder:
#   11_Mansh/Dynamic/Double_Lower: 5 trials
#   11_Mansh/Dynamic/Double_Nothing: 5 trials
#   11_Mansh/Dynamic/Double_Pistol_Recoil: 5 trials
#   11_Mansh/Dynamic/Double_Raise: 5 trials
#   11_Mansh/Dynamic/Double_Wiggle: 5 trials
#   11_Mansh/Dynamic/Double_cmere: 5 trials
#   11_Mansh/Dynamic/Drum_Roll: 5 trials
#   12_Marcus/Dynamic/Double_Lower: 5 trials
#   12_Marcus/Dynamic/Double_Nothing: 5 trials
#   12_Marcus/Dynamic/Double_Pistol_Recoil: 5 trials
#   12_Marcus/Dynamic/Double_Raise: 5 trials
#   12_Marcus/Dynamic/Double_Wiggle: 5 trials
#   12_Marcus/Dynamic/Double_cmere: 5 trials
#   12_Marcus/Dynamic/Drum_Roll: 5 trials
#   14_StephenV2/Dynamic/Double_Lower: 5 trials
#   14_StephenV2/Dynamic/Double_Nothing: 6 trials
#   14_StephenV2/Dynamic/Double_Pistol_Recoil: 5 trials
#   14_StephenV2/Dynamic/Double_Raise: 5 trials
#   14_StephenV2/Dynamic/Double_Wiggle: 5 trials
#   14_StephenV2/Dynamic/Double_cmere: 5 trials
#   14_StephenV2/Dynamic/Drum_Roll: 5 trials
#   17_Raquel/Dynamic/Double_Lower: 5 trials
#   17_Raquel/Dynamic/Double_Nothing: 5 trials
#   17_Raquel/Dynamic/Double_Pistol_Recoil: 5 trials
#   17_Raquel/Dynamic/Double_Raise: 5 trials
#   17_Raquel/Dynamic/Double_Wiggle: 5 trials
#   17_Raquel/Dynamic/Double_cmere: 5 trials
#   17_Raquel/Dynamic/Drum_Roll: 5 trials
#   18_Bridgette/Dynamic/Double_Lower: 5 trials
#   18_Bridgette/Dynamic/Double_Nothing: 5 trials
#   18_Bridgette/Dynamic/Double_Pistol_Recoil: 5 trials
#   18_Bridgette/Dynamic/Double_Raise: 5 trials
#   18_Bridgette/Dynamic/Double_Wiggle: 5 trials
#   18_Bridgette/Dynamic/Double_cmere: 5 trials
#   18_Bridgette/Dynamic/Drum_Roll: 5 trials
#   1_Alan/Dynamic/Double_Lower: 5 trials
#   1_Alan/Dynamic/Double_Nothing: 5 trials
#   1_Alan/Dynamic/Double_Pistol_Recoil: 5 trials
#   1_Alan/Dynamic/Double_Raise: 5 trials
#   1_Alan/Dynamic/Double_Wiggle: 5 trials
#   1_Alan/Dynamic/Double_cmere: 5 trials
#   1_Alan/Dynamic/Drum_Roll: 5 trials
#   2_Alex/Dynamic/Double_Lower: 5 trials
#   2_Alex/Dynamic/Double_Nothing: 5 trials
#   2_Alex/Dynamic/Double_Pistol_Recoil: 5 trials
#   2_Alex/Dynamic/Double_Raise: 5 trials
#   2_Alex/Dynamic/Double_Wiggle: 5 trials
#   2_Alex/Dynamic/Double_cmere: 5 trials
#   2_Alex/Dynamic/Drum_Roll: 5 trials
#   3_Anghad/Dynamic/Double_Lower: 5 trials
#   3_Anghad/Dynamic/Double_Nothing: 5 trials
#   3_Anghad/Dynamic/Double_Pistol_Recoil: 5 trials
#   3_Anghad/Dynamic/Double_Raise: 5 trials
#   3_Anghad/Dynamic/Double_Wiggle: 5 trials
#   3_Anghad/Dynamic/Double_cmere: 6 trials
#   3_Anghad/Dynamic/Drum_Roll: 5 trials
#   4_Daniel/Dynamic/Double_Lower: 5 trials
#   4_Daniel/Dynamic/Double_Nothing: 5 trials
#   4_Daniel/Dynamic/Double_Pistol_Recoil: 5 trials
#   4_Daniel/Dynamic/Double_Raise: 5 trials
#   4_Daniel/Dynamic/Double_Wiggle: 5 trials
#   4_Daniel/Dynamic/Double_cmere: 5 trials
#   4_Daniel/Dynamic/Drum_Roll: 5 trials
#   6_Harry/Dynamic/Double_Lower: 5 trials
#   6_Harry/Dynamic/Double_Nothing: 5 trials
#   6_Harry/Dynamic/Double_Pistol_Recoil: 5 trials
#   6_Harry/Dynamic/Double_Raise: 5 trials
#   6_Harry/Dynamic/Double_Wiggle: 5 trials
#   6_Harry/Dynamic/Double_cmere: 5 trials
#   6_Harry/Dynamic/Drum_Roll: 5 trials
#   8_Jestin/Dynamic/Double_Lower: 5 trials
#   8_Jestin/Dynamic/Double_Pistol_Recoil: 5 trials
#   8_Jestin/Dynamic/Double_Raise: 5 trials
#   8_Jestin/Dynamic/Double_Wiggle: 4 trials
#   8_Jestin/Dynamic/Double_cmere: 5 trials

# %% [markdown]
# ## 5. Preprocessing
#
# 1. Resample every trial to a fixed length so the CNN gets a constant input shape.
# 2. Optional zero-phase Butterworth low-pass filter to smooth high-frequency noise.

# %%
def resample_trial(trial, n_steps):
    """Linear resample (T, C) → (n_steps, C)."""
    T, C = trial.shape
    if T == n_steps:
        return trial.astype(np.float32, copy=False)
    old_idx = np.linspace(0, 1, T)
    new_idx = np.linspace(0, 1, n_steps)
    out = np.zeros((n_steps, C), dtype=np.float32)
    for c in range(C):
        out[:, c] = np.interp(new_idx, old_idx, trial[:, c])
    return out


def apply_butterworth(trials, cutoff, order, fs):
    """Zero-phase low-pass filter applied per channel."""
    nyq = fs / 2.0
    norm_cutoff = cutoff / nyq
    if norm_cutoff >= 1.0:
        print(f'  WARNING: cutoff {cutoff} Hz >= Nyquist {nyq} Hz — skipping filter.')
        return trials
    b, a = scipy_signal.butter(order, norm_cutoff, btype='low', analog=False)
    return [scipy_signal.filtfilt(b, a, t, axis=0).astype(np.float32) for t in trials]


# Resample
if RESAMPLE_TO_N_STEPS is not None:
    trials_resampled = [resample_trial(t, RESAMPLE_TO_N_STEPS) for t in trials_raw]
    print(f'Resampled all trials to {RESAMPLE_TO_N_STEPS} time steps.')
else:
    trials_resampled = trials_raw

# Filter
if APPLY_BUTTERWORTH:
    trials_filtered = apply_butterworth(trials_resampled, BUTTERWORTH_CUTOFF_HZ,
                                        BUTTERWORTH_ORDER, SAMPLING_RATE_HZ)
    print(f'Butterworth low-pass: cutoff={BUTTERWORTH_CUTOFF_HZ} Hz, order={BUTTERWORTH_ORDER}.')
else:
    trials_filtered = trials_resampled
    print('Butterworth filter skipped.')

sequence_length, n_channels = trials_filtered[0].shape
print(f'Trial shape: ({sequence_length}, {n_channels})  (time_steps × channels)')
# Out:
# Resampled all trials to 90 time steps.
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
# Butterworth low-pass: cutoff=15.0 Hz, order=4.
# Trial shape: (90, 176)  (time_steps × channels)

# %% [markdown]
# ## 6. Build X, y and the train/test split
#
# We stack all trials into a single `(N, T, C)` tensor, encode labels, then carve off a stratified hold-out test set. The hold-out set is **never** seen during training, augmentation, or scaler fitting.

# %%
X = np.stack(trials_filtered, axis=0).astype(np.float32)
X = np.nan_to_num(X, nan=0.0, posinf=0.0, neginf=0.0)

le = LabelEncoder()
y = le.fit_transform(labels_raw)
n_classes = len(le.classes_)
print(f'X shape: {X.shape}    y shape: {y.shape}    n_classes: {n_classes}')
print('Label mapping:', dict(zip(le.classes_, range(n_classes))))

X_train_pool, X_test, y_train_pool, y_test = train_test_split(
    X, y,
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE,
    stratify=y if STRATIFY_SPLIT and n_classes > 1 else None,
)
print(f'Train pool: {X_train_pool.shape}    Hold-out test: {X_test.shape}')
# Out:
# X shape: (376, 90, 176)    y shape: (376,)    n_classes: 7
# Label mapping: {np.str_('Double_Lower'): 0, np.str_('Double_Nothing'): 1, np.str_('Double_Pistol_Recoil'): 2, np.str_('Double_Raise'): 3, np.str_('Double_Wiggle'): 4, np.str_('Double_cmere'): 5, np.str_('Drum_Roll'): 6}
# Train pool: (338, 90, 176)    Hold-out test: (38, 90, 176)

# %% [markdown]
# ## 7. Augmentation helpers
#
# Each augmentation operates on a single `(T, C)` trial and is applied probabilistically per `AUGMENT_CONFIG`. `augment_training_set` produces `copies_per_sample` augmented variants per original trial and concatenates them with the originals.
#
# Augmentation is applied **inside** each CV fold's training split — the fold's validation split is left untouched, just like the hold-out test set.

# %%
def _resize_linear(trial, target_steps):
    T, C = trial.shape
    if T == target_steps:
        return trial.astype(np.float32, copy=False)
    old_idx = np.linspace(0, 1, T)
    new_idx = np.linspace(0, 1, target_steps)
    out = np.zeros((target_steps, C), dtype=np.float32)
    for c in range(C):
        out[:, c] = np.interp(new_idx, old_idx, trial[:, c])
    return out


def aug_time_shift(trial, max_shift_steps=3, fill_mode='edge', rng=None):
    rng = rng or np.random.default_rng()
    if max_shift_steps <= 0:
        return trial.copy()
    shift = int(rng.integers(-max_shift_steps, max_shift_steps + 1))
    if shift == 0:
        return trial.copy()
    out = np.empty_like(trial)
    out[:] = 0.0 if fill_mode == 'zero' else (trial[0] if shift > 0 else trial[-1])
    if shift > 0:
        out[shift:] = trial[:-shift]
    else:
        out[:shift] = trial[-shift:]
    return out


def aug_time_warp(trial, speed_range=(0.9, 1.1), rng=None):
    rng = rng or np.random.default_rng()
    factor = float(rng.uniform(*speed_range))
    T = trial.shape[0]
    warped_steps = max(4, int(round(T * factor)))
    return _resize_linear(_resize_linear(trial, warped_steps), T)


def aug_time_mask(trial, max_masks=2, max_mask_size=3, fill_mode='zero', rng=None):
    rng = rng or np.random.default_rng()
    out = trial.copy()
    T, C = out.shape
    n_masks = int(rng.integers(1, max_masks + 1)) if max_masks > 0 else 0
    for _ in range(n_masks):
        size = int(rng.integers(1, max_mask_size + 1))
        start = int(rng.integers(0, max(1, T - size + 1)))
        if fill_mode == 'mean':
            out[start:start+size] = out.mean(axis=0, keepdims=True)
        elif fill_mode == 'noise':
            ch_std = np.std(out, axis=0, keepdims=True)
            out[start:start+size] = rng.normal(0.0, np.maximum(ch_std, 1e-6), size=(size, C))
        else:
            out[start:start+size] = 0.0
    return out


def aug_gaussian_noise(trial, std_ratio=0.02, rng=None):
    rng = rng or np.random.default_rng()
    ch_std = np.std(trial, axis=0, keepdims=True)
    noise_std = np.maximum(ch_std * std_ratio, 1e-6)
    return (trial + rng.normal(0.0, noise_std, size=trial.shape)).astype(np.float32)


def aug_amplitude_scale(trial, scale_range=(0.95, 1.05), rng=None):
    rng = rng or np.random.default_rng()
    scale = rng.uniform(scale_range[0], scale_range[1], size=(1, trial.shape[1]))
    return (trial * scale).astype(np.float32)


def aug_baseline_offset(trial, offset_std_ratio=0.02, rng=None):
    rng = rng or np.random.default_rng()
    ch_std = np.std(trial, axis=0, keepdims=True)
    offset_std = np.maximum(ch_std * offset_std_ratio, 1e-6)
    offset = rng.normal(0.0, offset_std, size=(1, trial.shape[1]))
    return (trial + offset).astype(np.float32)


def aug_channel_dropout(trial, drop_fraction=0.03, fill_mode='zero', rng=None):
    rng = rng or np.random.default_rng()
    out = trial.copy()
    C = out.shape[1]
    n_drop = max(1, int(round(C * drop_fraction))) if drop_fraction > 0 else 0
    if n_drop == 0:
        return out
    idx = rng.choice(C, size=min(n_drop, C), replace=False)
    if fill_mode == 'mean':
        out[:, idx] = out.mean(axis=0, keepdims=True)[:, idx]
    else:
        out[:, idx] = 0.0
    return out


def aug_left_right_swap(trial, sensor_cols, rng=None):
    out = trial.copy()
    name_to_idx = {col: i for i, col in enumerate(sensor_cols)}
    for col in sensor_cols:
        if col.startswith('left'):
            partner = 'right' + col[4:]
            if partner in name_to_idx:
                i, j = name_to_idx[col], name_to_idx[partner]
                out[:, i], out[:, j] = trial[:, j], trial[:, i]
    return out


def apply_augmentations(trial, sensor_cols, config, rng):
    """Apply each augmentation independently with its own probability."""
    out = trial.astype(np.float32, copy=True)

    def _drop_meta(cfg):
        return {k: v for k, v in cfg.items() if k not in ('enabled', 'apply_prob')}

    def _maybe(name, fn, **extra):
        cfg = config.get(name, {})
        if cfg.get('enabled', False) and rng.random() < cfg.get('apply_prob', 1.0):
            return fn(out, **_drop_meta(cfg), **extra, rng=rng)
        return out

    out = _maybe('time_shift',      aug_time_shift)
    out = _maybe('time_warp',       aug_time_warp)
    out = _maybe('time_mask',       aug_time_mask)
    out = _maybe('gaussian_noise',  aug_gaussian_noise)
    out = _maybe('amplitude_scale', aug_amplitude_scale)
    out = _maybe('baseline_offset', aug_baseline_offset)
    out = _maybe('channel_dropout', aug_channel_dropout)
    if config.get('left_right_swap', {}).get('enabled', False) \
            and rng.random() < config['left_right_swap'].get('apply_prob', 1.0):
        out = aug_left_right_swap(out, sensor_cols=sensor_cols, rng=rng)

    return np.nan_to_num(out, nan=0.0, posinf=0.0, neginf=0.0).astype(np.float32)


def augment_training_set(X_tr, y_tr, sensor_cols, config, copies_per_sample=1, random_state=42):
    if copies_per_sample <= 0 or len(X_tr) == 0:
        return X_tr, y_tr
    rng = np.random.default_rng(random_state)
    X_aug, y_aug = [], []
    for trial, label in zip(X_tr, y_tr):
        for _ in range(copies_per_sample):
            X_aug.append(apply_augmentations(trial, sensor_cols, config, rng))
            y_aug.append(label)
    X_combined = np.concatenate([X_tr, np.stack(X_aug, axis=0)], axis=0)
    y_combined = np.concatenate([y_tr, np.array(y_aug, dtype=y_tr.dtype)], axis=0)
    return X_combined, y_combined

# %% [markdown]
# ## 8. CNN model and scaler helper
#
# `scale_train_val_test` fits the scaler on the training fold only, then applies it to validation and to a copy of the hold-out test set so we always have a correctly-scaled view of the test set per fold.

# %%
def build_cnn_model(sequence_length, n_channels, n_classes):
    model = Sequential([
        Conv1D(32, kernel_size=4, activation='relu', input_shape=(sequence_length, n_channels)),
        MaxPooling1D(pool_size=2),
        Conv1D(64, kernel_size=4, activation='relu'),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(n_classes, activation='softmax'),
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model


def make_scaler(kind):
    if kind == 'standard':
        return StandardScaler()
    if kind == 'minmax':
        return MinMaxScaler()
    return None


def scale_sets(X_train, X_val, X_test, kind):
    """Fit on train only; transform val and test."""
    scaler = make_scaler(kind)
    if scaler is None:
        return X_train, X_val, X_test, None
    Nt, T, C = X_train.shape
    Xt = scaler.fit_transform(X_train.reshape(Nt, T * C)).reshape(Nt, T, C).astype(np.float32)
    Xv = scaler.transform(X_val.reshape(X_val.shape[0], T * C)).reshape(X_val.shape[0], T, C).astype(np.float32) \
         if len(X_val) else X_val
    Xs = scaler.transform(X_test.reshape(X_test.shape[0], T * C)).reshape(X_test.shape[0], T, C).astype(np.float32) \
         if len(X_test) else X_test
    return Xt, Xv, Xs, scaler

# %% [markdown]
# ## 8b. CNN architecture variants
#
# We compare several 1D-CNN architectures using the same data, splits, CV folds, augmentation, scaler, and training loop. Each entry in `VARIANTS` is `(name, description, builder)` and the rest of the notebook iterates over it.
#
# Variants:
#
# - **Baseline** — the original 2-block CNN.
# - **Shallow** — single Conv block, fewer params.
# - **Deep** — three Conv blocks for more depth.
# - **BN_GAP** — BatchNorm + GlobalAveragePooling head, typically generalises better.
# - **WideKernel** — larger Conv kernels for a bigger temporal receptive field.
# - **CNN_LSTM** — Conv1D front-end feeding an LSTM that models temporal dynamics across the gesture.
# - **CNN_BiLSTM** — same Conv front-end, but a Bidirectional LSTM so each step sees both past and future context within the trial.

# %% [markdown]
# ## 9. Cross-validation (augmentation inside each fold)
#
# For every fold:
# 1. Split `X_train_pool` into fold train / fold val.
# 2. Augment **only** fold train.
# 3. Fit scaler on fold train; transform fold val and the (separate) hold-out test.
# 4. Train a fresh CNN; record validation accuracy.
#
# We keep the best-fold model as a starting point, but the final reported test accuracy comes from a clean retrain on the full training pool (next cell).

# %%
# Per-variant cross-validation. Reuses augment_training_set / scale_sets / build_*
# from the helper cells above. The familiar legacy variables (cv_histories,
# cv_fold_results, cv_mean_accuracy, cv_std_accuracy, best_cv_fold_index) end up
# pointing at the LAST variant trained, so existing downstream cells still run.
import tensorflow as tf

variant_results = []  # reset on re-run

# If the selector cell (Section 6b) hasn't been run yet, fall back to all variants.
ACTIVE_VARIANTS = globals().get('ACTIVE_VARIANTS', VARIANTS)

for v_name, v_desc, v_builder in ACTIVE_VARIANTS:
    print(f'\n{"="*72}\n  Variant: {v_name}\n{"="*72}')
    cv_histories = []
    cv_fold_results = []
    cv_mean_accuracy = None
    cv_std_accuracy = None
    best_cv_fold_index = None

    if RUN_CROSS_VALIDATION and CV_FOLDS > 1:
        skf = StratifiedKFold(n_splits=CV_FOLDS, shuffle=CV_SHUFFLE,
                              random_state=RANDOM_STATE if CV_SHUFFLE else None)
        for fold_idx, (tr_idx, va_idx) in enumerate(skf.split(X_train_pool, y_train_pool), start=1):
            X_tr, y_tr = X_train_pool[tr_idx].copy(), y_train_pool[tr_idx].copy()
            X_va, y_va = X_train_pool[va_idx].copy(), y_train_pool[va_idx].copy()

            if AUGMENT_TRAINING_DATA:
                X_tr, y_tr = augment_training_set(
                    X_tr, y_tr,
                    sensor_cols=SENSOR_COLS,
                    config=AUGMENT_CONFIG,
                    copies_per_sample=AUGMENTATION_COPIES_PER_SAMPLE,
                    random_state=AUGMENTATION_RANDOM_SEED + fold_idx,
                )

            X_tr_s, X_va_s, _, _ = scale_sets(X_tr, X_va, X_test, NORMALISATION)

            tf.keras.backend.clear_session()
            tf.random.set_seed(RANDOM_STATE + fold_idx)
            fold_model = v_builder(sequence_length, n_channels, n_classes)
            history = fold_model.fit(
                X_tr_s, y_tr,
                epochs=TRAIN_EPOCHS, batch_size=TRAIN_BATCH_SIZE,
                validation_data=(X_va_s, y_va), verbose=TRAIN_VERBOSE,
            )
            val_pred = np.argmax(fold_model.predict(X_va_s, verbose=0), axis=1)
            val_acc = float(accuracy_score(y_va, val_pred))

            cv_histories.append(history.history)
            cv_fold_results.append({
                'fold': fold_idx,
                'train_after_aug': int(X_tr.shape[0]),
                'val_samples': int(len(va_idx)),
                'val_accuracy': val_acc,
                'best_val_accuracy': float(max(history.history.get('val_accuracy', [val_acc]))),
                'final_val_accuracy': float(history.history.get('val_accuracy', [val_acc])[-1]),
            })
            print(f'  Fold {fold_idx}/{CV_FOLDS}: val_acc={val_acc:.4f}')

        val_accs = [r['val_accuracy'] for r in cv_fold_results]
        cv_mean_accuracy = float(np.mean(val_accs))
        cv_std_accuracy  = float(np.std(val_accs))
        best_cv_fold_index = int(np.argmax(val_accs)) + 1
        print(f'  CV mean: {cv_mean_accuracy:.4f} ± {cv_std_accuracy:.4f}, best fold {best_cv_fold_index}')

    variant_results.append({
        'name': v_name,
        'description': v_desc,
        'builder': v_builder,
        'cv_histories': cv_histories,
        'cv_fold_results': cv_fold_results,
        'cv_mean': cv_mean_accuracy,
        'cv_std':  cv_std_accuracy,
        'best_cv_fold_index': best_cv_fold_index,
    })
# Out:
# ========================================================================
#   Variant: Baseline
# ========================================================================
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4099 - loss: 1.4176 - val_accuracy: 0.5882 - val_loss: 0.9039
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6179 - loss: 0.9049 - val_accuracy: 0.7059 - val_loss: 0.6546
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7383 - loss: 0.6441 - val_accuracy: 0.6765 - val_loss: 0.7331
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8019 - loss: 0.5609 - val_accuracy: 0.8235 - val_loss: 0.3917
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8512 - loss: 0.4093 - val_accuracy: 0.8529 - val_loss: 0.3726
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9160 - loss: 0.2731 - val_accuracy: 0.9265 - val_loss: 0.2173
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9432 - loss: 0.2018 - val_accuracy: 0.9265 - val_loss: 0.2384
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9562 - loss: 0.1597 - val_accuracy: 0.9412 - val_loss: 0.1367
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9623 - loss: 0.1383 - val_accuracy: 0.9412 - val_loss: 0.1454
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9772 - loss: 0.0815 - val_accuracy: 0.9559 - val_loss: 0.1549
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9691 - loss: 0.1128 - val_accuracy: 0.9706 - val_loss: 0.0686
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9802 - loss: 0.0687 - val_accuracy: 0.9118 - val_loss: 0.4144
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9679 - loss: 0.1020 - val_accuracy: 0.9559 - val_loss: 0.1149
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9914 - loss: 0.0352 - val_accuracy: 0.9853 - val_loss: 0.0598
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9901 - loss: 0.0350 - val_accuracy: 0.9118 - val_loss: 0.5124
#   Fold 1/5: val_acc=0.9118
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4574 - loss: 1.3595 - val_accuracy: 0.5294 - val_loss: 1.0173
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6512 - loss: 0.8526 - val_accuracy: 0.6618 - val_loss: 0.7970
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7241 - loss: 0.7023 - val_accuracy: 0.6912 - val_loss: 0.7460
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7667 - loss: 0.5598 - val_accuracy: 0.7500 - val_loss: 0.6627
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8543 - loss: 0.3867 - val_accuracy: 0.8529 - val_loss: 0.5126
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8833 - loss: 0.3340 - val_accuracy: 0.8529 - val_loss: 0.4327
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8920 - loss: 0.2746 - val_accuracy: 0.8971 - val_loss: 0.3500
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9191 - loss: 0.2354 - val_accuracy: 0.9118 - val_loss: 0.3215
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9549 - loss: 0.1378 - val_accuracy: 0.9265 - val_loss: 0.2999
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9377 - loss: 0.1765 - val_accuracy: 0.9118 - val_loss: 0.2801
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9691 - loss: 0.0871 - val_accuracy: 0.9706 - val_loss: 0.2631
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9852 - loss: 0.0478 - val_accuracy: 0.9559 - val_loss: 0.2363
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9944 - loss: 0.0213 - val_accuracy: 0.9706 - val_loss: 0.2339
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9648 - loss: 0.1189 - val_accuracy: 0.9265 - val_loss: 0.3350
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9673 - loss: 0.1094 - val_accuracy: 0.9118 - val_loss: 0.3134
#   Fold 2/5: val_acc=0.9118
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4253 - loss: 1.3861 - val_accuracy: 0.5588 - val_loss: 0.9433
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6327 - loss: 0.9083 - val_accuracy: 0.6029 - val_loss: 0.8135
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7222 - loss: 0.7171 - val_accuracy: 0.6912 - val_loss: 0.6927
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8370 - loss: 0.4898 - val_accuracy: 0.8676 - val_loss: 0.4895
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8951 - loss: 0.3346 - val_accuracy: 0.9118 - val_loss: 0.4060
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9358 - loss: 0.2299 - val_accuracy: 0.8971 - val_loss: 0.2994
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9290 - loss: 0.2196 - val_accuracy: 0.9118 - val_loss: 0.3376
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9593 - loss: 0.1427 - val_accuracy: 0.9265 - val_loss: 0.3301
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9691 - loss: 0.1084 - val_accuracy: 0.8824 - val_loss: 0.4443
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9704 - loss: 0.0907 - val_accuracy: 0.8971 - val_loss: 0.3897
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9747 - loss: 0.0729 - val_accuracy: 0.8971 - val_loss: 0.4246
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9833 - loss: 0.0629 - val_accuracy: 0.9118 - val_loss: 0.3887
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9722 - loss: 0.0880 - val_accuracy: 0.8971 - val_loss: 0.3457
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9636 - loss: 0.1131 - val_accuracy: 0.8971 - val_loss: 0.3214
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9901 - loss: 0.0297 - val_accuracy: 0.9118 - val_loss: 0.4073
#   Fold 3/5: val_acc=0.9118
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4096 - loss: 1.3806 - val_accuracy: 0.6567 - val_loss: 0.8675
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6667 - loss: 0.8126 - val_accuracy: 0.7612 - val_loss: 0.6971
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7497 - loss: 0.6019 - val_accuracy: 0.8955 - val_loss: 0.5568
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8875 - loss: 0.3399 - val_accuracy: 0.8507 - val_loss: 0.6003
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9157 - loss: 0.2692 - val_accuracy: 0.8358 - val_loss: 0.7026
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8942 - loss: 0.3387 - val_accuracy: 0.8209 - val_loss: 0.6369
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9508 - loss: 0.1577 - val_accuracy: 0.9104 - val_loss: 0.4337
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9736 - loss: 0.0941 - val_accuracy: 0.8507 - val_loss: 0.6756
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9551 - loss: 0.1433 - val_accuracy: 0.9104 - val_loss: 0.4707
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9834 - loss: 0.0681 - val_accuracy: 0.9104 - val_loss: 0.4396
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9613 - loss: 0.1065 - val_accuracy: 0.9104 - val_loss: 0.3830
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9859 - loss: 0.0564 - val_accuracy: 0.8955 - val_loss: 0.5720
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9865 - loss: 0.0437 - val_accuracy: 0.9254 - val_loss: 0.6131
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9883 - loss: 0.0491 - val_accuracy: 0.8657 - val_loss: 0.6775
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9822 - loss: 0.0574 - val_accuracy: 0.9552 - val_loss: 0.4586
#   Fold 4/5: val_acc=0.9552
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4772 - loss: 1.2500 - val_accuracy: 0.7910 - val_loss: 0.7973
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7362 - loss: 0.7118 - val_accuracy: 0.7015 - val_loss: 0.7341
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8432 - loss: 0.4599 - val_accuracy: 0.9104 - val_loss: 0.3610
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9342 - loss: 0.2229 - val_accuracy: 0.9403 - val_loss: 0.2442
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9336 - loss: 0.2242 - val_accuracy: 0.8657 - val_loss: 0.4476
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9569 - loss: 0.1451 - val_accuracy: 0.9403 - val_loss: 0.2535
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9705 - loss: 0.1185 - val_accuracy: 0.9552 - val_loss: 0.3355
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9791 - loss: 0.0810 - val_accuracy: 0.8806 - val_loss: 0.3685
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9729 - loss: 0.0819 - val_accuracy: 0.9552 - val_loss: 0.2902
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9828 - loss: 0.0588 - val_accuracy: 0.9701 - val_loss: 0.3291
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9699 - loss: 0.0953 - val_accuracy: 0.9104 - val_loss: 0.3506
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9877 - loss: 0.0441 - val_accuracy: 0.9552 - val_loss: 0.3798
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9791 - loss: 0.0690 - val_accuracy: 0.9701 - val_loss: 0.2598
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9772 - loss: 0.0793 - val_accuracy: 0.9552 - val_loss: 0.2181
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9834 - loss: 0.0604 - val_accuracy: 0.9254 - val_loss: 0.3411
#   Fold 5/5: val_acc=0.9254
#   CV mean: 0.9232 ± 0.0169, best fold 4
#
# ========================================================================
#   Variant: Shallow
# ========================================================================
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4080 - loss: 1.3999 - val_accuracy: 0.6176 - val_loss: 0.8354
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6093 - loss: 0.9451 - val_accuracy: 0.7206 - val_loss: 0.6484
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6938 - loss: 0.7523 - val_accuracy: 0.6912 - val_loss: 0.6684
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7340 - loss: 0.6936 - val_accuracy: 0.8088 - val_loss: 0.5633
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7901 - loss: 0.5578 - val_accuracy: 0.8529 - val_loss: 0.4117
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8315 - loss: 0.4930 - val_accuracy: 0.8824 - val_loss: 0.3562
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8364 - loss: 0.4636 - val_accuracy: 0.9118 - val_loss: 0.3062
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8735 - loss: 0.3580 - val_accuracy: 0.8824 - val_loss: 0.2982
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8759 - loss: 0.3454 - val_accuracy: 0.8971 - val_loss: 0.2666
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9117 - loss: 0.2583 - val_accuracy: 0.9118 - val_loss: 0.2427
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9327 - loss: 0.2084 - val_accuracy: 0.9265 - val_loss: 0.2449
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9204 - loss: 0.2144 - val_accuracy: 0.9853 - val_loss: 0.1269
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9191 - loss: 0.2200 - val_accuracy: 0.8971 - val_loss: 0.2815
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9259 - loss: 0.2347 - val_accuracy: 0.9412 - val_loss: 0.2021
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9377 - loss: 0.1784 - val_accuracy: 0.9118 - val_loss: 0.1813
#   Fold 1/5: val_acc=0.9118
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3296 - loss: 1.6146 - val_accuracy: 0.5000 - val_loss: 1.2348
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4988 - loss: 1.2154 - val_accuracy: 0.5588 - val_loss: 1.0011
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5636 - loss: 0.9995 - val_accuracy: 0.7206 - val_loss: 0.8507
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6253 - loss: 0.8390 - val_accuracy: 0.7353 - val_loss: 0.7463
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6765 - loss: 0.7632 - val_accuracy: 0.7059 - val_loss: 0.7490
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6901 - loss: 0.7454 - val_accuracy: 0.7206 - val_loss: 0.6865
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7519 - loss: 0.5917 - val_accuracy: 0.7500 - val_loss: 0.6307
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7333 - loss: 0.6598 - val_accuracy: 0.8235 - val_loss: 0.5446
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8062 - loss: 0.5026 - val_accuracy: 0.8235 - val_loss: 0.5514
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8173 - loss: 0.4772 - val_accuracy: 0.8529 - val_loss: 0.4920
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8247 - loss: 0.4421 - val_accuracy: 0.8971 - val_loss: 0.4329
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8617 - loss: 0.3894 - val_accuracy: 0.8382 - val_loss: 0.5077
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8747 - loss: 0.3300 - val_accuracy: 0.9118 - val_loss: 0.3750
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8963 - loss: 0.2926 - val_accuracy: 0.9265 - val_loss: 0.3426
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8963 - loss: 0.2785 - val_accuracy: 0.9706 - val_loss: 0.3077
#   Fold 2/5: val_acc=0.9706
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4340 - loss: 1.3670 - val_accuracy: 0.5588 - val_loss: 0.9790
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5617 - loss: 1.0582 - val_accuracy: 0.5588 - val_loss: 0.9521
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6068 - loss: 0.9384 - val_accuracy: 0.6618 - val_loss: 0.8339
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6136 - loss: 0.9014 - val_accuracy: 0.6912 - val_loss: 0.7247
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6469 - loss: 0.8064 - val_accuracy: 0.6324 - val_loss: 0.7905
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6833 - loss: 0.7324 - val_accuracy: 0.7206 - val_loss: 0.6422
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7130 - loss: 0.6598 - val_accuracy: 0.7353 - val_loss: 0.6648
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7204 - loss: 0.6275 - val_accuracy: 0.7647 - val_loss: 0.5779
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7111 - loss: 0.6961 - val_accuracy: 0.8235 - val_loss: 0.5092
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7377 - loss: 0.6150 - val_accuracy: 0.7353 - val_loss: 0.6655
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7586 - loss: 0.5548 - val_accuracy: 0.7500 - val_loss: 0.5169
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7716 - loss: 0.5429 - val_accuracy: 0.7794 - val_loss: 0.6209
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7673 - loss: 0.5613 - val_accuracy: 0.7794 - val_loss: 0.5245
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7932 - loss: 0.4685 - val_accuracy: 0.6912 - val_loss: 0.6195
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7735 - loss: 0.4770 - val_accuracy: 0.7353 - val_loss: 0.5352
#   Fold 3/5: val_acc=0.7353
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2854 - loss: 1.7185 - val_accuracy: 0.4478 - val_loss: 1.3278
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5068 - loss: 1.2368 - val_accuracy: 0.6567 - val_loss: 0.9663
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5566 - loss: 1.0188 - val_accuracy: 0.7313 - val_loss: 0.8546
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6335 - loss: 0.8653 - val_accuracy: 0.6866 - val_loss: 0.7767
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6581 - loss: 0.7792 - val_accuracy: 0.7761 - val_loss: 0.7290
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6943 - loss: 0.7339 - val_accuracy: 0.7463 - val_loss: 0.7501
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7417 - loss: 0.6247 - val_accuracy: 0.7910 - val_loss: 0.7037
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7312 - loss: 0.6299 - val_accuracy: 0.8060 - val_loss: 0.7173
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7755 - loss: 0.5553 - val_accuracy: 0.8507 - val_loss: 0.6738
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8075 - loss: 0.4839 - val_accuracy: 0.9104 - val_loss: 0.6561
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8137 - loss: 0.4685 - val_accuracy: 0.8806 - val_loss: 0.7205
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8376 - loss: 0.4248 - val_accuracy: 0.8955 - val_loss: 0.7587
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8419 - loss: 0.4144 - val_accuracy: 0.8507 - val_loss: 0.8445
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8542 - loss: 0.3689 - val_accuracy: 0.8507 - val_loss: 0.7238
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8604 - loss: 0.3828 - val_accuracy: 0.8955 - val_loss: 0.7099
#   Fold 4/5: val_acc=0.8955
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2011 - loss: 1.8330 - val_accuracy: 0.3433 - val_loss: 1.5877
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3881 - loss: 1.3589 - val_accuracy: 0.5522 - val_loss: 1.1801
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5062 - loss: 1.0998 - val_accuracy: 0.5224 - val_loss: 1.0405
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5338 - loss: 1.0027 - val_accuracy: 0.5970 - val_loss: 0.9469
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5615 - loss: 0.9472 - val_accuracy: 0.7015 - val_loss: 0.9226
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5670 - loss: 0.9357 - val_accuracy: 0.6269 - val_loss: 0.9017
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5787 - loss: 0.8872 - val_accuracy: 0.7313 - val_loss: 0.8641
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5861 - loss: 0.8830 - val_accuracy: 0.7015 - val_loss: 0.8020
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5972 - loss: 0.8676 - val_accuracy: 0.6269 - val_loss: 0.8524
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6125 - loss: 0.8390 - val_accuracy: 0.7463 - val_loss: 0.8052
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6531 - loss: 0.7607 - val_accuracy: 0.7015 - val_loss: 0.8266
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6193 - loss: 0.7920 - val_accuracy: 0.7910 - val_loss: 0.7541
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6371 - loss: 0.7757 - val_accuracy: 0.7761 - val_loss: 0.7536
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6784 - loss: 0.7191 - val_accuracy: 0.7313 - val_loss: 0.7478
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6796 - loss: 0.7308 - val_accuracy: 0.7164 - val_loss: 0.7404
#   Fold 5/5: val_acc=0.7164
#   CV mean: 0.8459 ± 0.1013, best fold 2
#
# ========================================================================
#   Variant: Deep
# ========================================================================
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4463 - loss: 1.3204 - val_accuracy: 0.6176 - val_loss: 0.8421
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6395 - loss: 0.8955 - val_accuracy: 0.7206 - val_loss: 0.6528
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7432 - loss: 0.6723 - val_accuracy: 0.8088 - val_loss: 0.5726
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7988 - loss: 0.5365 - val_accuracy: 0.8676 - val_loss: 0.4073
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9043 - loss: 0.3337 - val_accuracy: 0.9265 - val_loss: 0.2097
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9333 - loss: 0.2139 - val_accuracy: 0.9559 - val_loss: 0.1405
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9525 - loss: 0.1577 - val_accuracy: 0.9265 - val_loss: 0.1658
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9580 - loss: 0.1414 - val_accuracy: 0.9559 - val_loss: 0.1372
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9506 - loss: 0.1480 - val_accuracy: 0.9559 - val_loss: 0.1294
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9722 - loss: 0.0925 - val_accuracy: 0.9559 - val_loss: 0.1307
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9667 - loss: 0.1002 - val_accuracy: 0.9559 - val_loss: 0.1469
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9673 - loss: 0.1125 - val_accuracy: 0.9559 - val_loss: 0.1306
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9679 - loss: 0.1045 - val_accuracy: 0.9559 - val_loss: 0.1003
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9809 - loss: 0.0665 - val_accuracy: 0.9559 - val_loss: 0.1130
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9765 - loss: 0.0717 - val_accuracy: 0.9559 - val_loss: 0.1003
#   Fold 1/5: val_acc=0.9559
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4833 - loss: 1.2224 - val_accuracy: 0.6324 - val_loss: 0.8189
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6747 - loss: 0.7795 - val_accuracy: 0.7500 - val_loss: 0.6446
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7636 - loss: 0.6041 - val_accuracy: 0.7353 - val_loss: 0.6721
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8623 - loss: 0.3891 - val_accuracy: 0.7941 - val_loss: 0.5972
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9265 - loss: 0.2210 - val_accuracy: 0.9412 - val_loss: 0.2597
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9438 - loss: 0.1797 - val_accuracy: 0.9412 - val_loss: 0.2640
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9617 - loss: 0.1228 - val_accuracy: 0.9853 - val_loss: 0.1956
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9506 - loss: 0.1492 - val_accuracy: 0.8676 - val_loss: 0.5869
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9599 - loss: 0.1437 - val_accuracy: 0.8824 - val_loss: 0.4213
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9605 - loss: 0.1254 - val_accuracy: 0.9853 - val_loss: 0.1950
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9679 - loss: 0.0851 - val_accuracy: 0.9853 - val_loss: 0.1790
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9802 - loss: 0.0583 - val_accuracy: 0.9706 - val_loss: 0.3134
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9710 - loss: 0.0906 - val_accuracy: 0.9853 - val_loss: 0.2306
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9531 - loss: 0.1641 - val_accuracy: 0.9118 - val_loss: 0.4423
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9556 - loss: 0.1362 - val_accuracy: 0.9559 - val_loss: 0.2336
#   Fold 2/5: val_acc=0.9559
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4988 - loss: 1.2165 - val_accuracy: 0.6765 - val_loss: 0.8700
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6722 - loss: 0.8350 - val_accuracy: 0.7794 - val_loss: 0.6140
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7790 - loss: 0.5892 - val_accuracy: 0.7941 - val_loss: 0.4403
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8716 - loss: 0.3773 - val_accuracy: 0.7500 - val_loss: 0.4723
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9302 - loss: 0.2242 - val_accuracy: 0.9265 - val_loss: 0.2160
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9247 - loss: 0.2363 - val_accuracy: 0.8529 - val_loss: 0.3376
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9691 - loss: 0.1097 - val_accuracy: 0.9265 - val_loss: 0.1763
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9796 - loss: 0.0618 - val_accuracy: 0.9559 - val_loss: 0.2053
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9858 - loss: 0.0506 - val_accuracy: 0.9559 - val_loss: 0.1932
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9796 - loss: 0.0591 - val_accuracy: 0.9265 - val_loss: 0.3042
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9389 - loss: 0.1898 - val_accuracy: 0.8971 - val_loss: 0.2650
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9846 - loss: 0.0593 - val_accuracy: 0.9118 - val_loss: 0.2348
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9932 - loss: 0.0242 - val_accuracy: 0.9265 - val_loss: 0.3545
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9963 - loss: 0.0160 - val_accuracy: 0.9265 - val_loss: 0.3592
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9938 - loss: 0.0190 - val_accuracy: 0.8971 - val_loss: 0.3878
#   Fold 3/5: val_acc=0.8971
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4508 - loss: 1.3307 - val_accuracy: 0.5970 - val_loss: 0.9201
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7109 - loss: 0.7423 - val_accuracy: 0.8209 - val_loss: 0.7286
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8180 - loss: 0.4756 - val_accuracy: 0.6567 - val_loss: 1.0461
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8684 - loss: 0.3868 - val_accuracy: 0.9104 - val_loss: 0.4251
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9403 - loss: 0.1882 - val_accuracy: 0.9403 - val_loss: 0.3531
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9717 - loss: 0.1084 - val_accuracy: 0.9104 - val_loss: 0.3790
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9748 - loss: 0.0943 - val_accuracy: 0.9403 - val_loss: 0.4343
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9674 - loss: 0.1266 - val_accuracy: 0.9403 - val_loss: 0.3966
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9397 - loss: 0.1828 - val_accuracy: 0.9403 - val_loss: 0.2816
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9852 - loss: 0.0596 - val_accuracy: 0.9403 - val_loss: 0.3491
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9840 - loss: 0.0558 - val_accuracy: 0.9254 - val_loss: 0.3360
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9889 - loss: 0.0329 - val_accuracy: 0.9403 - val_loss: 0.3653
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9680 - loss: 0.1106 - val_accuracy: 0.9403 - val_loss: 0.1908
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9889 - loss: 0.0312 - val_accuracy: 0.9254 - val_loss: 0.3035
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9729 - loss: 0.0961 - val_accuracy: 0.8657 - val_loss: 0.6808
#   Fold 4/5: val_acc=0.8657
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4397 - loss: 1.3002 - val_accuracy: 0.6119 - val_loss: 1.2726
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6950 - loss: 0.7497 - val_accuracy: 0.8209 - val_loss: 0.7622
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7958 - loss: 0.5504 - val_accuracy: 0.8657 - val_loss: 0.6797
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9225 - loss: 0.2451 - val_accuracy: 0.8806 - val_loss: 0.5478
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9336 - loss: 0.2193 - val_accuracy: 0.9254 - val_loss: 0.3236
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9133 - loss: 0.2641 - val_accuracy: 0.9254 - val_loss: 0.3785
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9649 - loss: 0.1126 - val_accuracy: 0.9104 - val_loss: 0.5186
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9656 - loss: 0.0937 - val_accuracy: 0.9104 - val_loss: 0.6486
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9071 - loss: 0.2899 - val_accuracy: 0.9254 - val_loss: 0.3075
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9649 - loss: 0.1187 - val_accuracy: 0.9403 - val_loss: 0.4570
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9748 - loss: 0.0743 - val_accuracy: 0.9254 - val_loss: 0.4077
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9908 - loss: 0.0285 - val_accuracy: 0.8806 - val_loss: 0.5542
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9582 - loss: 0.1331 - val_accuracy: 0.9254 - val_loss: 0.4946
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9637 - loss: 0.1074 - val_accuracy: 0.9701 - val_loss: 0.3594
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9859 - loss: 0.0552 - val_accuracy: 0.9552 - val_loss: 0.3286
#   Fold 5/5: val_acc=0.9552
#   CV mean: 0.9259 ± 0.0377, best fold 1
#
# ========================================================================
#   Variant: BN_GAP
# ========================================================================
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8247 - loss: 0.5201 - val_accuracy: 0.3235 - val_loss: 1.7887
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9802 - loss: 0.0991 - val_accuracy: 0.7647 - val_loss: 0.5422
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9975 - loss: 0.0383 - val_accuracy: 0.9706 - val_loss: 0.1393
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9969 - loss: 0.0257 - val_accuracy: 0.9559 - val_loss: 0.1553
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0121 - val_accuracy: 0.9412 - val_loss: 0.1944
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 0.9853 - val_loss: 0.0677
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.9853 - val_loss: 0.0945
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9706 - val_loss: 0.1072
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9853 - val_loss: 0.0710
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9706 - val_loss: 0.0835
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9853 - val_loss: 0.0813
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9853 - val_loss: 0.0745
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9853 - val_loss: 0.0774
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9853 - val_loss: 0.0879
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9853 - val_loss: 0.0756
#   Fold 1/5: val_acc=0.9853
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8037 - loss: 0.5954 - val_accuracy: 0.6471 - val_loss: 1.1024
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9704 - loss: 0.1133 - val_accuracy: 0.7353 - val_loss: 0.5883
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9920 - loss: 0.0479 - val_accuracy: 0.8824 - val_loss: 0.3386
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9981 - loss: 0.0214 - val_accuracy: 0.9853 - val_loss: 0.1271
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9994 - loss: 0.0152 - val_accuracy: 0.9853 - val_loss: 0.1372
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9994 - loss: 0.0089 - val_accuracy: 0.9853 - val_loss: 0.1470
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.9853 - val_loss: 0.1740
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.9853 - val_loss: 0.1493
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9853 - val_loss: 0.1680
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9853 - val_loss: 0.1719
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9853 - val_loss: 0.1725
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9853 - val_loss: 0.1665
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9853 - val_loss: 0.1639
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9853 - val_loss: 0.1753
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9853 - val_loss: 0.1688
#   Fold 2/5: val_acc=0.9853
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8327 - loss: 0.5305 - val_accuracy: 0.2059 - val_loss: 2.0579
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9858 - loss: 0.0971 - val_accuracy: 0.8235 - val_loss: 0.6856
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9951 - loss: 0.0391 - val_accuracy: 0.8971 - val_loss: 0.3921
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9988 - loss: 0.0204 - val_accuracy: 0.9706 - val_loss: 0.0656
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9994 - loss: 0.0117 - val_accuracy: 0.9853 - val_loss: 0.0368
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9994 - loss: 0.0087 - val_accuracy: 0.8382 - val_loss: 1.1873
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9981 - loss: 0.0204 - val_accuracy: 0.9118 - val_loss: 0.2433
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9994 - loss: 0.0090 - val_accuracy: 0.9706 - val_loss: 0.0804
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9994 - loss: 0.0080 - val_accuracy: 0.9706 - val_loss: 0.1097
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9559 - val_loss: 0.1024
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9706 - val_loss: 0.0928
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9559 - val_loss: 0.1109
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9559 - val_loss: 0.1295
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9706 - val_loss: 0.0757
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9706 - val_loss: 0.0917
#   Fold 3/5: val_acc=0.9706
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8413 - loss: 0.5138 - val_accuracy: 0.3582 - val_loss: 1.5367
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9803 - loss: 0.0934 - val_accuracy: 0.8657 - val_loss: 0.5288
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9988 - loss: 0.0316 - val_accuracy: 0.9254 - val_loss: 0.4023
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9994 - loss: 0.0161 - val_accuracy: 0.9552 - val_loss: 0.2651
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.9701 - val_loss: 0.2249
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.9701 - val_loss: 0.2278
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9701 - val_loss: 0.2231
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9701 - val_loss: 0.2008
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9701 - val_loss: 0.2189
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9701 - val_loss: 0.1882
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9701 - val_loss: 0.2086
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9701 - val_loss: 0.2033
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9701 - val_loss: 0.1959
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9701 - val_loss: 0.2064
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9701 - val_loss: 0.2132
#   Fold 4/5: val_acc=0.9701
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8358 - loss: 0.5381 - val_accuracy: 0.4328 - val_loss: 1.2704
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9852 - loss: 0.0801 - val_accuracy: 0.8955 - val_loss: 0.4061
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9975 - loss: 0.0285 - val_accuracy: 0.9701 - val_loss: 0.1856
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.9851 - val_loss: 0.1557
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.9851 - val_loss: 0.1603
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.9851 - val_loss: 0.1457
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9851 - val_loss: 0.1616
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9851 - val_loss: 0.1628
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9851 - val_loss: 0.1776
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9701 - val_loss: 0.1770
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9851 - val_loss: 0.1786
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9851 - val_loss: 0.1941
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9851 - val_loss: 0.1834
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9851 - val_loss: 0.1863
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9851 - val_loss: 0.1967
#   Fold 5/5: val_acc=0.9851
#   CV mean: 0.9793 ± 0.0073, best fold 1
#
# ========================================================================
#   Variant: WideKernel
# ========================================================================
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4099 - loss: 1.4076 - val_accuracy: 0.6029 - val_loss: 0.9745
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5790 - loss: 0.9764 - val_accuracy: 0.6912 - val_loss: 0.6649
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7062 - loss: 0.7404 - val_accuracy: 0.7206 - val_loss: 0.6290
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7549 - loss: 0.5956 - val_accuracy: 0.7794 - val_loss: 0.4472
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7747 - loss: 0.5378 - val_accuracy: 0.8824 - val_loss: 0.3373
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8216 - loss: 0.4483 - val_accuracy: 0.8676 - val_loss: 0.3740
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8278 - loss: 0.4223 - val_accuracy: 0.8971 - val_loss: 0.3198
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8667 - loss: 0.3793 - val_accuracy: 0.8971 - val_loss: 0.2411
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9019 - loss: 0.2771 - val_accuracy: 0.9118 - val_loss: 0.2872
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9167 - loss: 0.2422 - val_accuracy: 0.9412 - val_loss: 0.1782
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9401 - loss: 0.1882 - val_accuracy: 0.9118 - val_loss: 0.1810
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9315 - loss: 0.2334 - val_accuracy: 0.9118 - val_loss: 0.2345
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9568 - loss: 0.1448 - val_accuracy: 0.9265 - val_loss: 0.2028
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9556 - loss: 0.1400 - val_accuracy: 0.9265 - val_loss: 0.1483
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9654 - loss: 0.1055 - val_accuracy: 0.9118 - val_loss: 0.2806
#   Fold 1/5: val_acc=0.9118
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4019 - loss: 1.4363 - val_accuracy: 0.4853 - val_loss: 1.0739
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5901 - loss: 0.9609 - val_accuracy: 0.6765 - val_loss: 0.7907
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6074 - loss: 0.9348 - val_accuracy: 0.5882 - val_loss: 0.8122
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6747 - loss: 0.7474 - val_accuracy: 0.6324 - val_loss: 0.8175
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7333 - loss: 0.6266 - val_accuracy: 0.6912 - val_loss: 0.7602
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6864 - loss: 0.7336 - val_accuracy: 0.7794 - val_loss: 0.6769
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7667 - loss: 0.5652 - val_accuracy: 0.7794 - val_loss: 0.7032
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7741 - loss: 0.5251 - val_accuracy: 0.7647 - val_loss: 0.6668
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7957 - loss: 0.4427 - val_accuracy: 0.6912 - val_loss: 0.8032
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7784 - loss: 0.5337 - val_accuracy: 0.7941 - val_loss: 0.5971
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8389 - loss: 0.3748 - val_accuracy: 0.8971 - val_loss: 0.5263
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8858 - loss: 0.2861 - val_accuracy: 0.8676 - val_loss: 0.6398
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9198 - loss: 0.2381 - val_accuracy: 0.8529 - val_loss: 0.6417
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9296 - loss: 0.2124 - val_accuracy: 0.9559 - val_loss: 0.3412
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9444 - loss: 0.1914 - val_accuracy: 0.9853 - val_loss: 0.3643
#   Fold 2/5: val_acc=0.9853
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4340 - loss: 1.3957 - val_accuracy: 0.4853 - val_loss: 1.0541
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6191 - loss: 0.9054 - val_accuracy: 0.5294 - val_loss: 1.0361
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7204 - loss: 0.7179 - val_accuracy: 0.6471 - val_loss: 0.8661
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7599 - loss: 0.6377 - val_accuracy: 0.7353 - val_loss: 0.6732
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7981 - loss: 0.5041 - val_accuracy: 0.7059 - val_loss: 0.6625
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8000 - loss: 0.5147 - val_accuracy: 0.7794 - val_loss: 0.4771
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8599 - loss: 0.4004 - val_accuracy: 0.8088 - val_loss: 0.4738
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8599 - loss: 0.3872 - val_accuracy: 0.8088 - val_loss: 0.6513
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9111 - loss: 0.2730 - val_accuracy: 0.7500 - val_loss: 0.5207
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9358 - loss: 0.2162 - val_accuracy: 0.8382 - val_loss: 0.5329
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9346 - loss: 0.2007 - val_accuracy: 0.8824 - val_loss: 0.4947
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9395 - loss: 0.1823 - val_accuracy: 0.9265 - val_loss: 0.2653
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9667 - loss: 0.1005 - val_accuracy: 0.8971 - val_loss: 0.6638
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9327 - loss: 0.2206 - val_accuracy: 0.8971 - val_loss: 0.3568
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9667 - loss: 0.1083 - val_accuracy: 0.9265 - val_loss: 0.2781
#   Fold 3/5: val_acc=0.9265
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3979 - loss: 1.4479 - val_accuracy: 0.5075 - val_loss: 1.1073
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5941 - loss: 0.9822 - val_accuracy: 0.7463 - val_loss: 0.7512
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6845 - loss: 0.7795 - val_accuracy: 0.6567 - val_loss: 0.7362
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7153 - loss: 0.6892 - val_accuracy: 0.7313 - val_loss: 0.6598
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7306 - loss: 0.6571 - val_accuracy: 0.6119 - val_loss: 1.0065
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7823 - loss: 0.5616 - val_accuracy: 0.8806 - val_loss: 0.6779
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8290 - loss: 0.4714 - val_accuracy: 0.8806 - val_loss: 0.6349
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8309 - loss: 0.4539 - val_accuracy: 0.8806 - val_loss: 0.5188
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8819 - loss: 0.3282 - val_accuracy: 0.9104 - val_loss: 0.5175
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8708 - loss: 0.3743 - val_accuracy: 0.9104 - val_loss: 0.3974
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9367 - loss: 0.2185 - val_accuracy: 0.8955 - val_loss: 0.4762
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9237 - loss: 0.2578 - val_accuracy: 0.8955 - val_loss: 0.4165
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9016 - loss: 0.2967 - val_accuracy: 0.8955 - val_loss: 0.5275
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9637 - loss: 0.1337 - val_accuracy: 0.9104 - val_loss: 0.5410
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9748 - loss: 0.1206 - val_accuracy: 0.8806 - val_loss: 0.5544
#   Fold 4/5: val_acc=0.8806
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4674 - loss: 1.3767 - val_accuracy: 0.5970 - val_loss: 1.0727
# ...
#   Fold 2/5: val_acc=0.8676
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.3451 - loss: 1.5518 - val_accuracy: 0.4118 - val_loss: 1.1839
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5037 - loss: 1.0845 - val_accuracy: 0.5147 - val_loss: 1.0094
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5932 - loss: 0.9263 - val_accuracy: 0.6765 - val_loss: 0.7672
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6204 - loss: 0.9506 - val_accuracy: 0.6912 - val_loss: 0.7721
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6994 - loss: 0.7135 - val_accuracy: 0.6618 - val_loss: 0.7362
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7111 - loss: 0.6715 - val_accuracy: 0.6912 - val_loss: 0.8227
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6981 - loss: 0.7715 - val_accuracy: 0.5735 - val_loss: 0.8910
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7475 - loss: 0.6299 - val_accuracy: 0.6029 - val_loss: 0.8543
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7438 - loss: 0.6233 - val_accuracy: 0.7500 - val_loss: 0.6704
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7870 - loss: 0.5368 - val_accuracy: 0.6471 - val_loss: 0.8992
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7889 - loss: 0.5513 - val_accuracy: 0.7500 - val_loss: 0.5616
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8284 - loss: 0.4681 - val_accuracy: 0.6618 - val_loss: 1.0103
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8574 - loss: 0.4148 - val_accuracy: 0.7647 - val_loss: 0.6099
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9136 - loss: 0.3017 - val_accuracy: 0.9118 - val_loss: 0.3418
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9123 - loss: 0.3029 - val_accuracy: 0.9118 - val_loss: 0.2615
#   Fold 3/5: val_acc=0.9118
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.3014 - loss: 1.6190 - val_accuracy: 0.3433 - val_loss: 1.4206
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4545 - loss: 1.1292 - val_accuracy: 0.4179 - val_loss: 1.1235
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5560 - loss: 0.9850 - val_accuracy: 0.6866 - val_loss: 0.7923
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6230 - loss: 0.8323 - val_accuracy: 0.6716 - val_loss: 0.8877
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6273 - loss: 0.7881 - val_accuracy: 0.7313 - val_loss: 0.7498
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7011 - loss: 0.6568 - val_accuracy: 0.7612 - val_loss: 0.7157
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6722 - loss: 0.7360 - val_accuracy: 0.7313 - val_loss: 0.7044
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6900 - loss: 0.7178 - val_accuracy: 0.7015 - val_loss: 0.7357
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6919 - loss: 0.7111 - val_accuracy: 0.7612 - val_loss: 0.6952
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7515 - loss: 0.5697 - val_accuracy: 0.7910 - val_loss: 0.6588
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7774 - loss: 0.5152 - val_accuracy: 0.7761 - val_loss: 0.6034
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7983 - loss: 0.4656 - val_accuracy: 0.8209 - val_loss: 0.5564
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8204 - loss: 0.3842 - val_accuracy: 0.7761 - val_loss: 0.6214
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7897 - loss: 0.4684 - val_accuracy: 0.8358 - val_loss: 0.5790
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8456 - loss: 0.3247 - val_accuracy: 0.8209 - val_loss: 0.5768
#   Fold 4/5: val_acc=0.8209
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.4121 - loss: 1.4478 - val_accuracy: 0.5373 - val_loss: 1.0057
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5726 - loss: 0.9935 - val_accuracy: 0.6418 - val_loss: 0.8741
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6353 - loss: 0.8829 - val_accuracy: 0.6567 - val_loss: 0.8103
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7066 - loss: 0.7122 - val_accuracy: 0.6716 - val_loss: 0.8384
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7220 - loss: 0.6766 - val_accuracy: 0.7463 - val_loss: 0.7282
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7183 - loss: 0.6797 - val_accuracy: 0.8209 - val_loss: 0.6186
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7614 - loss: 0.5800 - val_accuracy: 0.7164 - val_loss: 0.7124
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7632 - loss: 0.5515 - val_accuracy: 0.7910 - val_loss: 0.5859
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7712 - loss: 0.5046 - val_accuracy: 0.6567 - val_loss: 1.0647
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7823 - loss: 0.5216 - val_accuracy: 0.7761 - val_loss: 0.5493
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7737 - loss: 0.5328 - val_accuracy: 0.8060 - val_loss: 0.5849
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7122 - loss: 0.6562 - val_accuracy: 0.8209 - val_loss: 0.6242
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7700 - loss: 0.5195 - val_accuracy: 0.7612 - val_loss: 0.6823
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7786 - loss: 0.4806 - val_accuracy: 0.8507 - val_loss: 0.4748
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8014 - loss: 0.4402 - val_accuracy: 0.8657 - val_loss: 0.4490
#   Fold 5/5: val_acc=0.8657
#   CV mean: 0.8550 ± 0.0369, best fold 3
#
# ========================================================================
#   Variant: CNN_BiLSTM
# ========================================================================
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3037 - loss: 1.6144 - val_accuracy: 0.5147 - val_loss: 1.1939
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5407 - loss: 1.0630 - val_accuracy: 0.6176 - val_loss: 0.8249
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6167 - loss: 0.8965 - val_accuracy: 0.6029 - val_loss: 0.8834
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6043 - loss: 0.9431 - val_accuracy: 0.7206 - val_loss: 0.7235
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7123 - loss: 0.6673 - val_accuracy: 0.7059 - val_loss: 0.5855
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7593 - loss: 0.5734 - val_accuracy: 0.7500 - val_loss: 0.5461
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7975 - loss: 0.4808 - val_accuracy: 0.7941 - val_loss: 0.4088
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7969 - loss: 0.4791 - val_accuracy: 0.7647 - val_loss: 0.4417
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8037 - loss: 0.4733 - val_accuracy: 0.7647 - val_loss: 0.5365
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8401 - loss: 0.3686 - val_accuracy: 0.8382 - val_loss: 0.3569
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8568 - loss: 0.3534 - val_accuracy: 0.8382 - val_loss: 0.3516
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8938 - loss: 0.3068 - val_accuracy: 0.9412 - val_loss: 0.2630
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8580 - loss: 0.3988 - val_accuracy: 0.8676 - val_loss: 0.3401
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9358 - loss: 0.2206 - val_accuracy: 0.6471 - val_loss: 1.0259
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7994 - loss: 0.6283 - val_accuracy: 0.9118 - val_loss: 0.2941
#   Fold 1/5: val_acc=0.9118
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3914 - loss: 1.4588 - val_accuracy: 0.6029 - val_loss: 0.9349
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6062 - loss: 0.9623 - val_accuracy: 0.7059 - val_loss: 0.7582
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6895 - loss: 0.7856 - val_accuracy: 0.5588 - val_loss: 1.2191
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7099 - loss: 0.7122 - val_accuracy: 0.8235 - val_loss: 0.5748
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7037 - loss: 0.7219 - val_accuracy: 0.6618 - val_loss: 0.8762
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7673 - loss: 0.5931 - val_accuracy: 0.6765 - val_loss: 0.9613
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7975 - loss: 0.5557 - val_accuracy: 0.8676 - val_loss: 0.4246
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8444 - loss: 0.4730 - val_accuracy: 0.8971 - val_loss: 0.4466
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8753 - loss: 0.3993 - val_accuracy: 0.7941 - val_loss: 0.7192
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8877 - loss: 0.3637 - val_accuracy: 0.9559 - val_loss: 0.2048
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9049 - loss: 0.2941 - val_accuracy: 0.9412 - val_loss: 0.3220
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8747 - loss: 0.3930 - val_accuracy: 0.8382 - val_loss: 0.4117
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9432 - loss: 0.1997 - val_accuracy: 0.9412 - val_loss: 0.3081
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9037 - loss: 0.3106 - val_accuracy: 0.9412 - val_loss: 0.3141
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7938 - loss: 0.6249 - val_accuracy: 0.8529 - val_loss: 0.5421
#   Fold 2/5: val_acc=0.8529
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4123 - loss: 1.4191 - val_accuracy: 0.5588 - val_loss: 0.9634
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5833 - loss: 0.9653 - val_accuracy: 0.6176 - val_loss: 0.8579
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6605 - loss: 0.8393 - val_accuracy: 0.6176 - val_loss: 0.8328
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7272 - loss: 0.6830 - val_accuracy: 0.6176 - val_loss: 0.7906
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8006 - loss: 0.5746 - val_accuracy: 0.8088 - val_loss: 0.5071
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8457 - loss: 0.4576 - val_accuracy: 0.8382 - val_loss: 0.4117
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8432 - loss: 0.4664 - val_accuracy: 0.8529 - val_loss: 0.4092
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8963 - loss: 0.3350 - val_accuracy: 0.8676 - val_loss: 0.5027
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8475 - loss: 0.4611 - val_accuracy: 0.8824 - val_loss: 0.3137
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8883 - loss: 0.3410 - val_accuracy: 0.8088 - val_loss: 0.5304
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8796 - loss: 0.3364 - val_accuracy: 0.8676 - val_loss: 0.3311
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9302 - loss: 0.2090 - val_accuracy: 0.9118 - val_loss: 0.2348
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9364 - loss: 0.2140 - val_accuracy: 0.9265 - val_loss: 0.2699
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9148 - loss: 0.2696 - val_accuracy: 0.8088 - val_loss: 0.5993
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9370 - loss: 0.2054 - val_accuracy: 0.9118 - val_loss: 0.2402
#   Fold 3/5: val_acc=0.9118
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.3223 - loss: 1.5924 - val_accuracy: 0.6269 - val_loss: 1.0351
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5670 - loss: 1.0028 - val_accuracy: 0.5522 - val_loss: 0.9346
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6857 - loss: 0.7631 - val_accuracy: 0.7015 - val_loss: 0.7926
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7460 - loss: 0.6544 - val_accuracy: 0.8507 - val_loss: 0.5489
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8370 - loss: 0.4840 - val_accuracy: 0.6866 - val_loss: 0.8765
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8604 - loss: 0.4594 - val_accuracy: 0.7612 - val_loss: 0.6434
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8998 - loss: 0.3255 - val_accuracy: 0.9403 - val_loss: 0.2784
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9606 - loss: 0.1651 - val_accuracy: 0.8657 - val_loss: 0.4659
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9453 - loss: 0.1830 - val_accuracy: 0.8955 - val_loss: 0.3876
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9471 - loss: 0.1769 - val_accuracy: 0.9403 - val_loss: 0.2597
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9723 - loss: 0.0982 - val_accuracy: 0.9254 - val_loss: 0.3615
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9723 - loss: 0.1044 - val_accuracy: 0.9254 - val_loss: 0.3984
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9613 - loss: 0.1546 - val_accuracy: 0.8657 - val_loss: 0.7386
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9569 - loss: 0.1599 - val_accuracy: 0.9104 - val_loss: 0.2986
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9582 - loss: 0.1753 - val_accuracy: 0.9403 - val_loss: 0.3135
#   Fold 4/5: val_acc=0.9403
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.3893 - loss: 1.4683 - val_accuracy: 0.4776 - val_loss: 1.3536
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5849 - loss: 0.9832 - val_accuracy: 0.6418 - val_loss: 0.9841
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6673 - loss: 0.8007 - val_accuracy: 0.7015 - val_loss: 0.8100
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7079 - loss: 0.7335 - val_accuracy: 0.7463 - val_loss: 0.7303
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7589 - loss: 0.6594 - val_accuracy: 0.6418 - val_loss: 0.9095
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7823 - loss: 0.5808 - val_accuracy: 0.8209 - val_loss: 0.5802
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8499 - loss: 0.4695 - val_accuracy: 0.8358 - val_loss: 0.5963
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8499 - loss: 0.4643 - val_accuracy: 0.7313 - val_loss: 0.8406
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9164 - loss: 0.2661 - val_accuracy: 0.8806 - val_loss: 0.5152
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9139 - loss: 0.2805 - val_accuracy: 0.9403 - val_loss: 0.3137
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9317 - loss: 0.2217 - val_accuracy: 0.9254 - val_loss: 0.3425
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9342 - loss: 0.2231 - val_accuracy: 0.9403 - val_loss: 0.2937
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9496 - loss: 0.1540 - val_accuracy: 0.9254 - val_loss: 0.2961
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9342 - loss: 0.2129 - val_accuracy: 0.9552 - val_loss: 0.2815
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9508 - loss: 0.1616 - val_accuracy: 0.7910 - val_loss: 0.6478
#   Fold 5/5: val_acc=0.7910
#   CV mean: 0.8816 ± 0.0535, best fold 4

# %% [markdown]
# ## 10. Final retrain on the full training pool
#
# CV gave us an honest estimate of generalisation. Now we retrain on the whole training pool with augmentation, fit a fresh scaler, and evaluate on the hold-out test set. This `model` and `scaler` are what get used for batch testing.

# %%
# Final retrain on the full training pool — once per variant. The familiar
# `model`, `scaler`, `history`, `X_train_final`, `y_train_final`, `X_test_final`
# variables end up pointing at the LAST variant for compatibility with cells
# 23/25/27 if you ever decide to skip the variants loop and run a single one.
import tensorflow as tf

# Build the training set once (same data + augmentation seed for fair comparison)
if AUGMENT_TRAINING_DATA:
    X_tr_full, y_tr_full = augment_training_set(
        X_train_pool, y_train_pool,
        sensor_cols=SENSOR_COLS,
        config=AUGMENT_CONFIG,
        copies_per_sample=AUGMENTATION_COPIES_PER_SAMPLE,
        random_state=AUGMENTATION_RANDOM_SEED,
    )
else:
    X_tr_full, y_tr_full = X_train_pool.copy(), y_train_pool.copy()
print(f'Final training set size: {X_tr_full.shape[0]} (orig pool {X_train_pool.shape[0]})')

for entry in variant_results:
    print(f'\n── Final retrain: {entry["name"]} ──')

    # Fresh scaler per variant (fit on full augmented pool, applied to hold-out)
    X_tr_s, _, X_test_s, scaler_v = scale_sets(X_tr_full, X_tr_full[:0], X_test, NORMALISATION)

    tf.keras.backend.clear_session()
    tf.random.set_seed(RANDOM_STATE)
    model_v = entry['builder'](sequence_length, n_channels, n_classes)
    n_params = int(model_v.count_params())
    history_v = model_v.fit(
        X_tr_s, y_tr_full,
        epochs=TRAIN_EPOCHS, batch_size=TRAIN_BATCH_SIZE,
        validation_split=TRAIN_VALIDATION_SPLIT, verbose=TRAIN_VERBOSE,
    )

    entry.update({
        'model':   model_v,
        'scaler':  scaler_v,
        'history': history_v.history,
        'n_params': n_params,
        'X_test_final': X_test_s,
    })
    print(f'  trainable params: {n_params:,}')

# Legacy aliases pointing at the last variant
_last = variant_results[-1]
model         = _last['model']
scaler        = _last['scaler']
history       = type('H', (), {'history': _last['history']})()
X_train_final = X_tr_s
y_train_final = y_tr_full
X_test_final  = _last['X_test_final']
# Out:
# Final training set size: 2028 (orig pool 338)
#
# ── Final retrain: Baseline ──
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4568 - loss: 1.2959 - val_accuracy: 0.6453 - val_loss: 0.8654
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6862 - loss: 0.7739 - val_accuracy: 0.7315 - val_loss: 0.7663
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7811 - loss: 0.5832 - val_accuracy: 0.7315 - val_loss: 0.6779
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8483 - loss: 0.4298 - val_accuracy: 0.8350 - val_loss: 0.4804
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9125 - loss: 0.2829 - val_accuracy: 0.8842 - val_loss: 0.3951
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9346 - loss: 0.2302 - val_accuracy: 0.8892 - val_loss: 0.3045
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9507 - loss: 0.1613 - val_accuracy: 0.8916 - val_loss: 0.3024
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9408 - loss: 0.1763 - val_accuracy: 0.9236 - val_loss: 0.2467
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9599 - loss: 0.1284 - val_accuracy: 0.9680 - val_loss: 0.1183
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9618 - loss: 0.1237 - val_accuracy: 0.8621 - val_loss: 0.4205
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9618 - loss: 0.1336 - val_accuracy: 0.9310 - val_loss: 0.2115
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9735 - loss: 0.0888 - val_accuracy: 0.9507 - val_loss: 0.1537
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9901 - loss: 0.0448 - val_accuracy: 0.9458 - val_loss: 0.1683
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9760 - loss: 0.0875 - val_accuracy: 0.9212 - val_loss: 0.2102
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9538 - loss: 0.1783 - val_accuracy: 0.7463 - val_loss: 1.2552
#   trainable params: 113,255
#
# ── Final retrain: Shallow ──
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3206 - loss: 1.6133 - val_accuracy: 0.3793 - val_loss: 1.3847
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4858 - loss: 1.2405 - val_accuracy: 0.5443 - val_loss: 1.1296
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5734 - loss: 1.0244 - val_accuracy: 0.6749 - val_loss: 0.8589
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6264 - loss: 0.8528 - val_accuracy: 0.7291 - val_loss: 0.7592
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6831 - loss: 0.7594 - val_accuracy: 0.7734 - val_loss: 0.6547
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7417 - loss: 0.6450 - val_accuracy: 0.7414 - val_loss: 0.7053
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7226 - loss: 0.6641 - val_accuracy: 0.7537 - val_loss: 0.6419
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7417 - loss: 0.6067 - val_accuracy: 0.7833 - val_loss: 0.5846
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7713 - loss: 0.5512 - val_accuracy: 0.7217 - val_loss: 0.7257
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7842 - loss: 0.5229 - val_accuracy: 0.6330 - val_loss: 0.8829
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7799 - loss: 0.5273 - val_accuracy: 0.7906 - val_loss: 0.5838
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7996 - loss: 0.4944 - val_accuracy: 0.8202 - val_loss: 0.4513
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8089 - loss: 0.4398 - val_accuracy: 0.8202 - val_loss: 0.4969
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8064 - loss: 0.4775 - val_accuracy: 0.8621 - val_loss: 0.4185
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8274 - loss: 0.4075 - val_accuracy: 0.8621 - val_loss: 0.4066
#   trainable params: 72,487
#
# ── Final retrain: Deep ──
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4686 - loss: 1.2795 - val_accuracy: 0.6281 - val_loss: 0.8920
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6628 - loss: 0.8111 - val_accuracy: 0.6773 - val_loss: 0.8517
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7996 - loss: 0.5747 - val_accuracy: 0.8251 - val_loss: 0.6734
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8835 - loss: 0.3937 - val_accuracy: 0.8596 - val_loss: 0.4902
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9229 - loss: 0.2393 - val_accuracy: 0.8498 - val_loss: 0.4848
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9229 - loss: 0.2585 - val_accuracy: 0.8744 - val_loss: 0.4466
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9556 - loss: 0.1453 - val_accuracy: 0.9163 - val_loss: 0.2791
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9445 - loss: 0.1798 - val_accuracy: 0.8571 - val_loss: 0.4833
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9599 - loss: 0.1403 - val_accuracy: 0.9606 - val_loss: 0.2670
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9753 - loss: 0.0768 - val_accuracy: 0.9754 - val_loss: 0.1395
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9704 - loss: 0.0868 - val_accuracy: 0.9631 - val_loss: 0.1463
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9686 - loss: 0.0883 - val_accuracy: 0.9828 - val_loss: 0.0699
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9451 - loss: 0.1677 - val_accuracy: 0.9089 - val_loss: 0.3175
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9716 - loss: 0.0974 - val_accuracy: 0.9064 - val_loss: 0.3805
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9753 - loss: 0.0826 - val_accuracy: 0.9335 - val_loss: 0.2372
#   trainable params: 204,007
#
# ── Final retrain: BN_GAP ──
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8342 - loss: 0.5018 - val_accuracy: 0.1749 - val_loss: 2.9213
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9809 - loss: 0.1033 - val_accuracy: 0.4778 - val_loss: 1.6183
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9889 - loss: 0.0554 - val_accuracy: 0.7488 - val_loss: 0.6698
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9982 - loss: 0.0245 - val_accuracy: 0.9655 - val_loss: 0.1288
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9988 - loss: 0.0144 - val_accuracy: 0.9828 - val_loss: 0.0993
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9994 - loss: 0.0097 - val_accuracy: 0.9877 - val_loss: 0.0840
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9994 - loss: 0.0071 - val_accuracy: 0.9877 - val_loss: 0.0965
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9994 - loss: 0.0065 - val_accuracy: 0.9877 - val_loss: 0.0898
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9877 - val_loss: 0.0685
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9877 - val_loss: 0.0580
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9877 - val_loss: 0.1143
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9994 - loss: 0.0039 - val_accuracy: 0.9877 - val_loss: 0.0994
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9877 - val_loss: 0.0900
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9877 - val_loss: 0.0334
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9877 - val_loss: 0.0471
#   trainable params: 57,319
#
# ── Final retrain: WideKernel ──
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4420 - loss: 1.3396 - val_accuracy: 0.5493 - val_loss: 1.1273
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6547 - loss: 0.8611 - val_accuracy: 0.7143 - val_loss: 0.7772
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7867 - loss: 0.5801 - val_accuracy: 0.8030 - val_loss: 0.4502
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8693 - loss: 0.4018 - val_accuracy: 0.7857 - val_loss: 0.5198
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8822 - loss: 0.3406 - val_accuracy: 0.8719 - val_loss: 0.4085
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9236 - loss: 0.2632 - val_accuracy: 0.8498 - val_loss: 0.4646
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9297 - loss: 0.2249 - val_accuracy: 0.9064 - val_loss: 0.2563
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9494 - loss: 0.1550 - val_accuracy: 0.8695 - val_loss: 0.2705
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9581 - loss: 0.1307 - val_accuracy: 0.8522 - val_loss: 0.4443
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9605 - loss: 0.1233 - val_accuracy: 0.8399 - val_loss: 0.3124
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9704 - loss: 0.0817 - val_accuracy: 0.9089 - val_loss: 0.2586
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9667 - loss: 0.1021 - val_accuracy: 0.9360 - val_loss: 0.2485
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9408 - loss: 0.1934 - val_accuracy: 0.8719 - val_loss: 0.3227
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9784 - loss: 0.0708 - val_accuracy: 0.9360 - val_loss: 0.2906
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9599 - loss: 0.1095 - val_accuracy: 0.8867 - val_loss: 0.2992
#   trainable params: 131,687
#
# ── Final retrain: CNN_LSTM ──
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3915 - loss: 1.4368 - val_accuracy: 0.5172 - val_loss: 0.9954
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5801 - loss: 0.9732 - val_accuracy: 0.6108 - val_loss: 0.9857
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6837 - loss: 0.8009 - val_accuracy: 0.6897 - val_loss: 0.7416
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7367 - loss: 0.6897 - val_accuracy: 0.6650 - val_loss: 0.7065
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8058 - loss: 0.5872 - val_accuracy: 0.7611 - val_loss: 0.6836
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8212 - loss: 0.5620 - val_accuracy: 0.7291 - val_loss: 0.7010
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8798 - loss: 0.3969 - val_accuracy: 0.8941 - val_loss: 0.3658
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8835 - loss: 0.3668 - val_accuracy: 0.7956 - val_loss: 0.5949
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8921 - loss: 0.3347 - val_accuracy: 0.8547 - val_loss: 0.4325
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8896 - loss: 0.3357 - val_accuracy: 0.7783 - val_loss: 0.7319
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9396 - loss: 0.1944 - val_accuracy: 0.8941 - val_loss: 0.3557
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8915 - loss: 0.3768 - val_accuracy: 0.9236 - val_loss: 0.2749
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9562 - loss: 0.1755 - val_accuracy: 0.9581 - val_loss: 0.2167
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9562 - loss: 0.1750 - val_accuracy: 0.8103 - val_loss: 0.5861
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9501 - loss: 0.1896 - val_accuracy: 0.8916 - val_loss: 0.3080
#   trainable params: 68,455
#
# ── Final retrain: CNN_BiLSTM ──
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.3520 - loss: 1.4679 - val_accuracy: 0.6601 - val_loss: 0.9480
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.5869 - loss: 0.9826 - val_accuracy: 0.7414 - val_loss: 0.6514
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.6936 - loss: 0.7514 - val_accuracy: 0.7414 - val_loss: 0.6845
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7522 - loss: 0.6353 - val_accuracy: 0.7118 - val_loss: 0.7217
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.8138 - loss: 0.5233 - val_accuracy: 0.7463 - val_loss: 0.7808
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.8317 - loss: 0.5103 - val_accuracy: 0.6749 - val_loss: 1.1627
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.8329 - loss: 0.4912 - val_accuracy: 0.7463 - val_loss: 0.9012
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.8527 - loss: 0.4638 - val_accuracy: 0.7882 - val_loss: 0.5352
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.9223 - loss: 0.2585 - val_accuracy: 0.8621 - val_loss: 0.3794
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9494 - loss: 0.1931 - val_accuracy: 0.7709 - val_loss: 0.6049
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9402 - loss: 0.1944 - val_accuracy: 0.8867 - val_loss: 0.3492
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.9390 - loss: 0.2121 - val_accuracy: 0.8966 - val_loss: 0.3455
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9383 - loss: 0.2125 - val_accuracy: 0.8399 - val_loss: 0.5803
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9248 - loss: 0.2541 - val_accuracy: 0.7635 - val_loss: 0.6484
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9624 - loss: 0.1264 - val_accuracy: 0.9557 - val_loss: 0.1690
#   trainable params: 105,575

# %% [markdown]
# ## 11. Training curves

# %%
# Overlay validation curves for all variants
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
for entry in variant_results:
    h = entry.get('history', {})
    if 'val_accuracy' in h:
        plt.plot(h['val_accuracy'], label=entry['name'])
plt.title('Validation accuracy (final retrain)')
plt.xlabel('Epoch'); plt.ylabel('Accuracy')
plt.legend(fontsize=8); plt.grid(alpha=0.3)

plt.subplot(1, 2, 2)
for entry in variant_results:
    h = entry.get('history', {})
    if 'val_loss' in h:
        plt.plot(h['val_loss'], label=entry['name'])
plt.title('Validation loss (final retrain)')
plt.xlabel('Epoch'); plt.ylabel('Loss')
plt.legend(fontsize=8); plt.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(MODEL_OUTPUT_DIR / 'training_curves.png', dpi=140, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 12. Hold-out test evaluation

# %%
# Hold-out evaluation per variant
for entry in variant_results:
    test_loss_v, test_accuracy_v = entry['model'].evaluate(
        entry['X_test_final'], y_test, verbose=0
    )
    y_pred_v = np.argmax(entry['model'].predict(entry['X_test_final'], verbose=0), axis=1)
    rep_v = classification_report(
        y_test, y_pred_v, target_names=le.classes_, output_dict=True, zero_division=0
    )
    entry.update({
        'test_loss': float(test_loss_v),
        'test_accuracy': float(test_accuracy_v),
        'y_pred': y_pred_v,
        'classification_report': rep_v,
    })
    print(f'{entry["name"]:<12} test_loss={test_loss_v:.4f}  test_acc={test_accuracy_v:.4f}')

print('\nConfusion matrix (last variant):')
print(confusion_matrix(y_test, variant_results[-1]['y_pred']))
print('\nClassification report (last variant):')
print(classification_report(
    y_test, variant_results[-1]['y_pred'], target_names=le.classes_, zero_division=0
))

# Legacy aliases for downstream cells
test_loss     = variant_results[-1]['test_loss']
test_accuracy = variant_results[-1]['test_accuracy']
y_pred        = variant_results[-1]['y_pred']
# Out:
# Baseline     test_loss=1.1509  test_acc=0.7895
# Shallow      test_loss=0.5573  test_acc=0.8421
# Deep         test_loss=0.1618  test_acc=0.9474
# BN_GAP       test_loss=0.2458  test_acc=0.9737
# WideKernel   test_loss=0.2467  test_acc=0.8947
# CNN_LSTM     test_loss=0.2456  test_acc=0.9474
# CNN_BiLSTM   test_loss=0.2894  test_acc=0.9474
#
# Confusion matrix (last variant):
# [[5 0 0 0 0 0 0]
#  [0 3 0 1 1 0 0]
#  [0 0 6 0 0 0 0]
#  [0 0 0 6 0 0 0]
#  [0 0 0 0 5 0 0]
#  [0 0 0 0 0 6 0]
#  [0 0 0 0 0 0 5]]
#
# Classification report (last variant):
#                       precision    recall  f1-score   support
#
#         Double_Lower       1.00      1.00      1.00         5
#       Double_Nothing       1.00      0.60      0.75         5
# Double_Pistol_Recoil       1.00      1.00      1.00         6
#         Double_Raise       0.86      1.00      0.92         6
#        Double_Wiggle       0.83      1.00      0.91         5
#         Double_cmere       1.00      1.00      1.00         6
#            Drum_Roll       1.00      1.00      1.00         5
#
#             accuracy                           0.95        38
#            macro avg       0.96      0.94      0.94        38
#         weighted avg       0.96      0.95      0.94        38

# %% [markdown]
# ## 13. Batch test on TestData/Jestin/TwoHandDynamic
#
# The test folder contains one subfolder per gesture (matching the training class names, sometimes with case differences). We use **the subfolder name** as the ground-truth label — this is far more robust than parsing filenames. Class-name matching is case-insensitive so e.g. `TwoHandDynamic_L_Fist_R_LightBulb` (test) maps to `TwoHandDynamic_L_Fist_R_Lightbulb` (training).

# %%
def preprocess_csv_for_cnn(fpath, sensor_cols, resample_n, apply_butter, cutoff, order, fs, scaler,
                            seq_len, n_chan):
    """Read one CSV → (1, seq_len, n_chan) tensor ready for model.predict."""
    df = pd.read_csv(fpath)
    available = [c for c in sensor_cols if c in df.columns]
    if not available:
        raise ValueError('No matching sensor columns')
    if len(available) != len(sensor_cols):
        # Pad missing columns with zeros so the channel order matches training
        data = np.zeros((len(df), len(sensor_cols)), dtype=np.float32)
        idx_map = {c: i for i, c in enumerate(sensor_cols)}
        for c in available:
            data[:, idx_map[c]] = df[c].values.astype(np.float32)
    else:
        data = df[sensor_cols].values.astype(np.float32)

    if resample_n is not None:
        data = resample_trial(data, resample_n)
    if apply_butter:
        data = apply_butterworth([data], cutoff, order, fs)[0]
    data = np.nan_to_num(data, nan=0.0, posinf=0.0, neginf=0.0)

    if scaler is not None:
        data = scaler.transform(data.reshape(1, -1)).reshape(seq_len, n_chan).astype(np.float32)

    return data.reshape(1, seq_len, n_chan)


def build_test_label_map(class_names):
    """Case-insensitive map from test-folder class name → training class name."""
    m = {}
    for cls in class_names:
        m[cls.lower()] = cls
    return m


def run_batch_test(test_root, model, scaler, le, sensor_cols, class_names,
                   resample_n, apply_butter, cutoff, order, fs, seq_len, n_chan):
    test_root = os.path.expanduser(test_root)
    if not os.path.isdir(test_root):
        raise FileNotFoundError(f'BATCH_TEST_ROOT not found: {test_root!r}')

    label_map = build_test_label_map(class_names)
    sub_dirs = sorted(d for d in os.listdir(test_root)
                      if os.path.isdir(os.path.join(test_root, d)))
    if not sub_dirs:
        print(f'No subfolders found in {test_root}')
        return None

    correct, total, unrecognised = 0, 0, 0
    per_class = {}
    rows = []
    print(f'Batch testing files from {len(sub_dirs)} subfolders under {test_root}')
    print('-' * 100)

    for sub in sub_dirs:
        true_label = label_map.get(sub.lower())
        sub_path = os.path.join(test_root, sub)
        csv_files = sorted(f for f in glob.glob(os.path.join(sub_path, '*.csv'))
                           if not os.path.basename(f).startswith('_'))
        if true_label is None:
            print(f'  ? subfolder {sub!r} has no matching training class — skipping ({len(csv_files)} files)')
            unrecognised += len(csv_files)
            continue

        per_class.setdefault(true_label, {'correct': 0, 'total': 0})

        for fpath in csv_files:
            fname = os.path.basename(fpath)
            try:
                x = preprocess_csv_for_cnn(
                    fpath, sensor_cols,
                    resample_n, apply_butter, cutoff, order, fs,
                    scaler, seq_len, n_chan,
                )
                probs = model.predict(x, verbose=0)[0]
                pred_idx = int(np.argmax(probs))
                pred = le.inverse_transform([pred_idx])[0]
                conf = float(probs.max())
                ok = (pred == true_label)
                correct += int(ok); total += 1
                per_class[true_label]['correct'] += int(ok)
                per_class[true_label]['total']   += 1
                rows.append({'file': fname, 'true': true_label, 'pred': pred,
                             'confidence': conf, 'correct': ok})
                tag = '✓' if ok else '✗'
                t_short = true_label.replace('TwoHandDynamic_', '')
                p_short = pred.replace('TwoHandDynamic_', '')
                print(f'  {tag} {fname[:50]:<52}  true={t_short:<28}  pred={p_short:<28}  conf={conf:.3f}')
            except Exception as e:
                print(f'  ERROR {fname}: {e}')

    print('-' * 100)
    if total > 0:
        print(f'Overall batch accuracy: {correct/total:.4f}  ({correct}/{total})')
    if unrecognised:
        print(f'Files in unmatched subfolders: {unrecognised}')

    print('\nPer-class accuracy:')
    for cls, d in sorted(per_class.items()):
        if d['total']:
            print(f'  {cls:<55} {d["correct"]/d["total"]:.4f}  ({d["correct"]}/{d["total"]})')

    return pd.DataFrame(rows), correct, total

# %%
# Batch test per variant (reuses run_batch_test defined above)
for entry in variant_results:
    print(f'\n── Batch test: {entry["name"]} ──')
    res = run_batch_test(
        BATCH_TEST_ROOT, entry['model'], entry['scaler'], le,
        SENSOR_COLS, class_names,
        RESAMPLE_TO_N_STEPS, APPLY_BUTTERWORTH, BUTTERWORTH_CUTOFF_HZ, BUTTERWORTH_ORDER,
        SAMPLING_RATE_HZ, sequence_length, n_channels,
    )
    if res is not None:
        df_v, c_v, t_v = res
        entry['batch_df'] = df_v
        entry['batch_correct'] = int(c_v)
        entry['batch_total'] = int(t_v)
        entry['batch_accuracy'] = float(c_v / t_v) if t_v else None
    else:
        entry['batch_df'] = None
        entry['batch_correct'] = 0
        entry['batch_total'] = 0
        entry['batch_accuracy'] = None

print('\n=== Summary across variants ===')
print(f'{"Variant":<12}  {"params":>10}  {"CV":>16}  {"hold-out":>10}  {"batch":>10}')
for e in variant_results:
    cv = f'{e["cv_mean"]:.3f}±{e["cv_std"]:.3f}' if e["cv_mean"] is not None else '—'
    bt = f'{e["batch_accuracy"]:.3f}' if e["batch_accuracy"] is not None else '—'
    print(f'{e["name"]:<12}  {e["n_params"]:>10,}  {cv:>16}  {e["test_accuracy"]:>10.3f}  {bt:>10}')

# Legacy aliases
batch_df = variant_results[-1].get('batch_df')
batch_correct = variant_results[-1].get('batch_correct', 0)
batch_total = variant_results[-1].get('batch_total', 0)
batch_test_accuracy = variant_results[-1].get('batch_accuracy')
# Out:
# ── Batch test: Baseline ──
# Batch testing files from 7 subfolders under /home/jestin/ThesisRepo/ML/NewTestData/15_Tash/Dynamic
# ----------------------------------------------------------------------------------------------------
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_1_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_2_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_3_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_4_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_5_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.997
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_1_2026-05-0    true=Double_Nothing                pred=Double_cmere                  conf=0.790
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_2_2026-05-0    true=Double_Nothing                pred=Double_cmere                  conf=0.993
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_3_2026-05-0    true=Double_Nothing                pred=Double_Lower                  conf=0.990
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_4_2026-05-0    true=Double_Nothing                pred=Double_Pistol_Recoil          conf=0.863
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_5_2026-05-0    true=Double_Nothing                pred=Double_Pistol_Recoil          conf=0.883
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_1_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.989
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_2_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.995
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_3_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_4_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_5_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.998
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_1_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_2_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_3_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_4_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_5_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_1_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.603
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_2_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.954
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_3_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.958
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_4_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.961
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_5_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.974
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_1_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.992
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_2_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.977
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_3_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.996
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_cmere_3s_4_2026-05-04_    true=Double_cmere                  pred=Double_cmere                  conf=0.998
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_cmere_3s_5_2026-05-04_    true=Double_cmere                  pred=Double_cmere                  conf=0.990
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_1_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.916
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_2_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.950
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_3_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.961
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_4_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.963
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_5_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.958
# ----------------------------------------------------------------------------------------------------
# Overall batch accuracy: 0.6286  (22/35)
#
# Per-class accuracy:
#   Double_Lower                                            1.0000  (5/5)
#   Double_Nothing                                          0.0000  (0/5)
#   Double_Pistol_Recoil                                    1.0000  (5/5)
#   Double_Raise                                            1.0000  (5/5)
#   Double_Wiggle                                           1.0000  (5/5)
#   Double_cmere                                            0.4000  (2/5)
#   Drum_Roll                                               0.0000  (0/5)
#
# ── Batch test: Shallow ──
# Batch testing files from 7 subfolders under /home/jestin/ThesisRepo/ML/NewTestData/15_Tash/Dynamic
# ----------------------------------------------------------------------------------------------------
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_1_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.533
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_2_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.422
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Lower_3s_3_2026-05-04_    true=Double_Lower                  pred=Double_Wiggle                 conf=0.454
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Lower_3s_4_2026-05-04_    true=Double_Lower                  pred=Double_Wiggle                 conf=0.452
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Lower_3s_5_2026-05-04_    true=Double_Lower                  pred=Double_Wiggle                 conf=0.716
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_1_2026-05-0    true=Double_Nothing                pred=Double_cmere                  conf=0.518
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_2_2026-05-0    true=Double_Nothing                pred=Double_cmere                  conf=0.998
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_3_2026-05-0    true=Double_Nothing                pred=Double_Wiggle                 conf=0.602
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_4_2026-05-0    true=Double_Nothing                pred=Double_Pistol_Recoil          conf=0.729
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Nothing_3s_5_2026-05-0    true=Double_Nothing                pred=Double_Nothing                conf=0.677
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_1_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.714
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_2_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.735
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_3_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.535
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_4_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.537
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_5_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.583
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_1_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_2_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_3_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_4_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_5_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_1_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.422
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_2_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.833
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_3_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.809
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_4_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.813
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_5_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.823
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_1_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.974
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_2_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.986
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_3_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.987
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_cmere_3s_4_2026-05-04_    true=Double_cmere                  pred=Double_cmere                  conf=0.905
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_5_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.594
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_1_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.817
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_2_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.871
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_3_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.867
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_4_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.848
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_5_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.848
# ----------------------------------------------------------------------------------------------------
# Overall batch accuracy: 0.5429  (19/35)
#
# Per-class accuracy:
#   Double_Lower                                            0.4000  (2/5)
#   Double_Nothing                                          0.2000  (1/5)
#   Double_Pistol_Recoil                                    1.0000  (5/5)
#   Double_Raise                                            1.0000  (5/5)
#   Double_Wiggle                                           1.0000  (5/5)
#   Double_cmere                                            0.2000  (1/5)
#   Drum_Roll                                               0.0000  (0/5)
#
# ── Batch test: Deep ──
# Batch testing files from 7 subfolders under /home/jestin/ThesisRepo/ML/NewTestData/15_Tash/Dynamic
# ----------------------------------------------------------------------------------------------------
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_1_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_2_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_3_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_4_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_5_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Nothing_3s_1_2026-05-0    true=Double_Nothing                pred=Double_Nothing                conf=0.746
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Nothing_3s_2_2026-05-0    true=Double_Nothing                pred=Double_Nothing                conf=0.302
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_3_2026-05-0    true=Double_Nothing                pred=Double_Lower                  conf=0.763
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_4_2026-05-0    true=Double_Nothing                pred=Double_Pistol_Recoil          conf=0.957
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_5_2026-05-0    true=Double_Nothing                pred=Double_Pistol_Recoil          conf=0.853
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_1_202    true=Double_Pistol_Recoil          pred=Drum_Roll                     conf=0.564
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_2_202    true=Double_Pistol_Recoil          pred=Drum_Roll                     conf=0.804
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_3_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_4_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.911
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_5_202    true=Double_Pistol_Recoil          pred=Drum_Roll                     conf=0.931
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_1_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.983
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_2_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.992
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_3_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.990
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_4_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.990
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_5_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.997
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_1_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.965
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_2_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.996
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_3_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.989
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_4_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.990
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_5_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.988
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_1_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.958
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_2_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.873
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_3_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.906
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_4_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.653
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_5_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.775
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_1_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.997
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_2_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_3_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_4_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_5_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.976
# ----------------------------------------------------------------------------------------------------
# Overall batch accuracy: 0.5429  (19/35)
#
# Per-class accuracy:
#   Double_Lower                                            1.0000  (5/5)
#   Double_Nothing                                          0.4000  (2/5)
#   Double_Pistol_Recoil                                    0.4000  (2/5)
#   Double_Raise                                            1.0000  (5/5)
#   Double_Wiggle                                           1.0000  (5/5)
#   Double_cmere                                            0.0000  (0/5)
#   Drum_Roll                                               0.0000  (0/5)
#
# ── Batch test: BN_GAP ──
# Batch testing files from 7 subfolders under /home/jestin/ThesisRepo/ML/NewTestData/15_Tash/Dynamic
# ----------------------------------------------------------------------------------------------------
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_1_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.696
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Lower_3s_2_2026-05-04_    true=Double_Lower                  pred=Double_Nothing                conf=0.972
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Lower_3s_3_2026-05-04_    true=Double_Lower                  pred=Double_Nothing                conf=0.735
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Lower_3s_4_2026-05-04_    true=Double_Lower                  pred=Double_Nothing                conf=0.919
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_5_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.663
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_1_2026-05-0    true=Double_Nothing                pred=Double_cmere                  conf=0.533
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_2_2026-05-0    true=Double_Nothing                pred=Double_cmere                  conf=0.944
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Nothing_3s_3_2026-05-0    true=Double_Nothing                pred=Double_Nothing                conf=0.562
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Nothing_3s_4_2026-05-0    true=Double_Nothing                pred=Double_Nothing                conf=0.841
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Nothing_3s_5_2026-05-0    true=Double_Nothing                pred=Double_Nothing                conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_1_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_2_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_3_202    true=Double_Pistol_Recoil          pred=Double_Nothing                conf=0.816
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_4_202    true=Double_Pistol_Recoil          pred=Double_Nothing                conf=0.700
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_5_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.936
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_1_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.972
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_2_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.992
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_3_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.975
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_4_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.974
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_5_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.997
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_1_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.920
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_2_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_3_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.998
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_4_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.996
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_5_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.996
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_1_2026-05-04_    true=Double_cmere                  pred=Double_Nothing                conf=0.850
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_2_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.948
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_3_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.942
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_cmere_3s_4_2026-05-04_    true=Double_cmere                  pred=Double_cmere                  conf=0.886
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_cmere_3s_5_2026-05-04_    true=Double_cmere                  pred=Double_cmere                  conf=0.663
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_1_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.960
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_2_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_3_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_4_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_5_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.998
# ----------------------------------------------------------------------------------------------------
# Overall batch accuracy: 0.5714  (20/35)
#
# Per-class accuracy:
#   Double_Lower                                            0.4000  (2/5)
#   Double_Nothing                                          0.6000  (3/5)
#   Double_Pistol_Recoil                                    0.6000  (3/5)
#   Double_Raise                                            1.0000  (5/5)
#   Double_Wiggle                                           1.0000  (5/5)
#   Double_cmere                                            0.4000  (2/5)
#   Drum_Roll                                               0.0000  (0/5)
#
# ── Batch test: WideKernel ──
# Batch testing files from 7 subfolders under /home/jestin/ThesisRepo/ML/NewTestData/15_Tash/Dynamic
# ----------------------------------------------------------------------------------------------------
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_1_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_2_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.667
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_3_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.975
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_4_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.993
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_5_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.614
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Nothing_3s_1_2026-05-0    true=Double_Nothing                pred=Double_Nothing                conf=0.978
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Nothing_3s_2_2026-05-0    true=Double_Nothing                pred=Double_Nothing                conf=0.972
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_3_2026-05-0    true=Double_Nothing                pred=Drum_Roll                     conf=0.978
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Nothing_3s_4_2026-05-0    true=Double_Nothing                pred=Double_Nothing                conf=0.694
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_5_2026-05-0    true=Double_Nothing                pred=Double_Pistol_Recoil          conf=0.790
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_1_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_2_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.998
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_3_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.991
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_4_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.998
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_5_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_1_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_2_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_3_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_4_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_5_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_1_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.656
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_2_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.992
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_3_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.986
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_4_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.981
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_5_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.987
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_1_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=1.000
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_2_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_3_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_4_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.998
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_5_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.998
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_1_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.726
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_2_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.996
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_3_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.995
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_4_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.992
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Drum_Roll_3s_5_2026-05-04_08-    true=Drum_Roll                     pred=Drum_Roll                     conf=0.919
# ----------------------------------------------------------------------------------------------------
# Overall batch accuracy: 0.6857  (24/35)
#
# Per-class accuracy:
#   Double_Lower                                            1.0000  (5/5)
#   Double_Nothing                                          0.6000  (3/5)
#   Double_Pistol_Recoil                                    1.0000  (5/5)
#   Double_Raise                                            1.0000  (5/5)
#   Double_Wiggle                                           1.0000  (5/5)
#   Double_cmere                                            0.0000  (0/5)
#   Drum_Roll                                               0.2000  (1/5)
#
# ── Batch test: CNN_LSTM ──
# Batch testing files from 7 subfolders under /home/jestin/ThesisRepo/ML/NewTestData/15_Tash/Dynamic
# ----------------------------------------------------------------------------------------------------
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_1_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_2_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_3_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_4_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_5_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.984
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Nothing_3s_1_2026-05-0    true=Double_Nothing                pred=Double_Nothing                conf=0.997
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Nothing_3s_2_2026-05-0    true=Double_Nothing                pred=Double_Nothing                conf=0.977
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_3_2026-05-0    true=Double_Nothing                pred=Double_Lower                  conf=0.994
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_4_2026-05-0    true=Double_Nothing                pred=Double_Pistol_Recoil          conf=0.946
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Nothing_3s_5_2026-05-0    true=Double_Nothing                pred=Double_Nothing                conf=0.977
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_1_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.881
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_2_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.985
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_3_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.995
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_4_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.992
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_5_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.964
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_1_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.851
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_2_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.940
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_3_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.673
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_4_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.581
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_5_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.983
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_1_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.901
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_2_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.929
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_3_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.926
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_4_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.929
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_5_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.926
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_cmere_3s_1_2026-05-04_    true=Double_cmere                  pred=Double_cmere                  conf=0.778
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_cmere_3s_2_2026-05-04_    true=Double_cmere                  pred=Double_cmere                  conf=0.696
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_3_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.663
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_cmere_3s_4_2026-05-04_    true=Double_cmere                  pred=Double_cmere                  conf=0.998
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_cmere_3s_5_2026-05-04_    true=Double_cmere                  pred=Double_cmere                  conf=0.998
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Drum_Roll_3s_1_2026-05-04_08-    true=Drum_Roll                     pred=Drum_Roll                     conf=0.866
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_2_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.912
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_3_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.918
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_4_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.924
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_5_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.865
# ----------------------------------------------------------------------------------------------------
# Overall batch accuracy: 0.8000  (28/35)
#
# Per-class accuracy:
#   Double_Lower                                            1.0000  (5/5)
#   Double_Nothing                                          0.6000  (3/5)
#   Double_Pistol_Recoil                                    1.0000  (5/5)
#   Double_Raise                                            1.0000  (5/5)
#   Double_Wiggle                                           1.0000  (5/5)
#   Double_cmere                                            0.8000  (4/5)
#   Drum_Roll                                               0.2000  (1/5)
#
# ── Batch test: CNN_BiLSTM ──
# Batch testing files from 7 subfolders under /home/jestin/ThesisRepo/ML/NewTestData/15_Tash/Dynamic
# ----------------------------------------------------------------------------------------------------
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_1_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_2_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_3_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_4_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Lower_3s_5_2026-05-04_    true=Double_Lower                  pred=Double_Lower                  conf=0.997
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Nothing_3s_1_2026-05-0    true=Double_Nothing                pred=Double_Nothing                conf=0.967
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Nothing_3s_2_2026-05-0    true=Double_Nothing                pred=Double_Nothing                conf=0.977
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_3_2026-05-0    true=Double_Nothing                pred=Double_Lower                  conf=0.966
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_4_2026-05-0    true=Double_Nothing                pred=Double_Pistol_Recoil          conf=0.987
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Nothing_3s_5_2026-05-0    true=Double_Nothing                pred=Double_Pistol_Recoil          conf=0.940
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_1_202    true=Double_Pistol_Recoil          pred=Double_Nothing                conf=0.495
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_2_202    true=Double_Pistol_Recoil          pred=Double_Nothing                conf=0.630
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_3_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.996
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_4_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.989
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Pistol_Recoil_3s_5_202    true=Double_Pistol_Recoil          pred=Double_Pistol_Recoil          conf=0.956
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_1_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.998
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_2_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.998
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_3_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.997
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_4_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.998
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Raise_3s_5_2026-05-04_    true=Double_Raise                  pred=Double_Raise                  conf=0.998
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_1_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.914
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_2_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.906
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_3_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.926
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_4_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.927
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_Wiggle_3s_5_2026-05-04    true=Double_Wiggle                 pred=Double_Wiggle                 conf=0.931
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_1_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.959
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_2_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.988
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Double_cmere_3s_3_2026-05-04_    true=Double_cmere                  pred=Double_Raise                  conf=0.994
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_cmere_3s_4_2026-05-04_    true=Double_cmere                  pred=Double_cmere                  conf=0.999
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Double_cmere_3s_5_2026-05-04_    true=Double_cmere                  pred=Double_cmere                  conf=0.997
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Drum_Roll_3s_1_2026-05-04_08-    true=Drum_Roll                     pred=Drum_Roll                     conf=0.978
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_2_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.917
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_3_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.903
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✗ glove_data_L_Dynamic_Drum_Roll_3s_4_2026-05-04_08-    true=Drum_Roll                     pred=Double_Wiggle                 conf=0.932
#   WARNING: cutoff 15.0 Hz >= Nyquist 15.0 Hz — skipping filter.
#   ✓ glove_data_L_Dynamic_Drum_Roll_3s_5_2026-05-04_08-    true=Drum_Roll                     pred=Drum_Roll                     conf=0.838
# ----------------------------------------------------------------------------------------------------
# Overall batch accuracy: 0.6857  (24/35)
#
# Per-class accuracy:
#   Double_Lower                                            1.0000  (5/5)
#   Double_Nothing                                          0.4000  (2/5)
#   Double_Pistol_Recoil                                    0.6000  (3/5)
#   Double_Raise                                            1.0000  (5/5)
#   Double_Wiggle                                           1.0000  (5/5)
#   Double_cmere                                            0.4000  (2/5)
#   Drum_Roll                                               0.4000  (2/5)
#
# === Summary across variants ===
# Variant           params                CV    hold-out       batch
# Baseline         113,255       0.923±0.017       0.789       0.629
# Shallow           72,487       0.846±0.101       0.842       0.543
# Deep             204,007       0.926±0.038       0.947       0.543
# BN_GAP            57,319       0.979±0.007       0.974       0.571
# WideKernel       131,687       0.932±0.036       0.895       0.686
# CNN_LSTM          68,455       0.855±0.037       0.947       0.800
# CNN_BiLSTM       105,575       0.882±0.053       0.947       0.686

# %% [markdown]
# ## 14. Save model and append experiment row to CSV log

# %%
def _to_jsonable(obj):
    if isinstance(obj, dict):  return {str(k): _to_jsonable(v) for k, v in obj.items()}
    if isinstance(obj, (list, tuple)): return [_to_jsonable(v) for v in obj]
    if isinstance(obj, np.ndarray):    return obj.tolist()
    if isinstance(obj, np.integer):    return int(obj)
    if isinstance(obj, np.floating):   return float(obj)
    if isinstance(obj, np.bool_):      return bool(obj)
    return obj


def _stable_json(obj):
    return json.dumps(_to_jsonable(obj), sort_keys=True, separators=(',', ':'))


def build_experiment_row():
    hist = {k: [float(v) for v in vs] for k, vs in history.history.items()}
    row = {
        'timestamp': datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
        'data_paths': _stable_json([str(p) for p in (ACTIVE_DATA_PATHS or [])]),
        'data_paths_count': len(ACTIVE_DATA_PATHS or []),
        'batch_test_root': str(BATCH_TEST_ROOT),
        'sensor_cols_count': len(SENSOR_COLS),
        'sensor_cols': _stable_json(SENSOR_COLS),
        'resample_to_n_steps': RESAMPLE_TO_N_STEPS,
        'apply_butterworth': bool(APPLY_BUTTERWORTH),
        'butterworth_cutoff_hz': BUTTERWORTH_CUTOFF_HZ,
        'butterworth_order': BUTTERWORTH_ORDER,
        'sampling_rate_hz': SAMPLING_RATE_HZ,
        'normalisation': NORMALISATION,
        'test_size': float(TEST_SIZE),
        'random_state': int(RANDOM_STATE),
        'cv_folds': int(CV_FOLDS),
        'run_cross_validation': bool(RUN_CROSS_VALIDATION),
        'cv_shuffle': bool(CV_SHUFFLE),
        'augment_training_data': bool(AUGMENT_TRAINING_DATA),
        'augmentation_copies_per_sample': int(AUGMENTATION_COPIES_PER_SAMPLE),
        'augmentation_random_seed': int(AUGMENTATION_RANDOM_SEED),
        'augmentation_config': _stable_json(AUGMENT_CONFIG),
        'n_classes': int(n_classes),
        'class_names': _stable_json(list(le.classes_)),
        'n_total_samples': int(X.shape[0]),
        'n_train_pool_samples': int(X_train_pool.shape[0]),
        'n_train_after_aug': int(X_train_final.shape[0]),
        'n_test_samples': int(X_test.shape[0]),
        'sequence_length': int(sequence_length),
        'n_channels': int(n_channels),
        'epochs': int(TRAIN_EPOCHS),
        'batch_size': int(TRAIN_BATCH_SIZE),
        'validation_split': float(TRAIN_VALIDATION_SPLIT),
        'cv_mean_accuracy': cv_mean_accuracy,
        'cv_std_accuracy': cv_std_accuracy,
        'cv_best_fold_index': best_cv_fold_index,
        'cv_fold_results_json': _stable_json(cv_fold_results),
        'cv_histories_json': _stable_json(cv_histories),
        'final_train_accuracy': float(history.history['accuracy'][-1]),
        'final_val_accuracy':   float(history.history['val_accuracy'][-1]),
        'final_train_loss':     float(history.history['loss'][-1]),
        'final_val_loss':       float(history.history['val_loss'][-1]),
        'best_val_accuracy':    float(max(history.history['val_accuracy'])),
        'best_val_loss':        float(min(history.history['val_loss'])),
        'test_accuracy':        float(test_accuracy),
        'test_loss':            float(test_loss),
        'batch_test_accuracy':  float(batch_test_accuracy) if batch_test_accuracy is not None else None,
        'history_json': _stable_json(hist),
    }
    sig_payload = {k: v for k, v in row.items() if k != 'timestamp'}
    row['row_signature'] = hashlib.sha256(_stable_json(sig_payload).encode()).hexdigest()
    return row


def append_experiment_row(csv_path=EXPERIMENT_LOG_PATH):
    row = build_experiment_row()
    df_new = pd.DataFrame([row])
    if csv_path.exists():
        df_existing = pd.read_csv(csv_path)
        if 'row_signature' in df_existing.columns and row['row_signature'] in set(df_existing['row_signature'].astype(str)):
            print(f'Identical row already in {csv_path} — not appending.')
            return df_existing
        df_out = pd.concat([df_existing, df_new], ignore_index=True)
    else:
        df_out = df_new
    df_out.to_csv(csv_path, index=False)
    print(f'Experiment log: {csv_path} ({len(df_out)} rows)')
    return df_out


def save_model_artifact():
    timestamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
    sig = build_experiment_row()['row_signature'][:12]
    path = MODEL_OUTPUT_DIR / f'cnn_model_{timestamp}_{sig}.keras'
    model.save(path)
    print(f'Saved model to {path}')
    return path


model_path = save_model_artifact()
experiment_log_df = append_experiment_row()
experiment_log_df.tail(3)
# Out:
# Saved model to saved_models/cnn_model_2026-05-11_16-57-13_65f06c71b08d.keras
# Experiment log: saved_models/experiment_results.csv (64 rows)
#               timestamp data_root  \
# 61  2026-05-10 20:20:33       NaN
# 62  2026-05-11 15:29:45       NaN
# 63  2026-05-11 16:57:13       NaN
#
#                                       batch_test_root  sensor_cols_count  \
# 61  /home/jestin/ThesisRepo/ML/NewTestData/17_Raqu...                176
# 62  /home/jestin/ThesisRepo/ML/NewTestData/15_Tash...                176
# 63  /home/jestin/ThesisRepo/ML/NewTestData/15_Tash...                176
#
#                                           sensor_cols  resample_to_n_steps  \
# 61  ["left_wrist_heading","left_wrist_pitch","left...                   90
# 62  ["left_wrist_heading","left_wrist_pitch","left...                   90
# 63  ["left_wrist_heading","left_wrist_pitch","left...                   90
#
#     apply_butterworth  butterworth_cutoff_hz  butterworth_order  \
# 61               True                   15.0                  4
# 62               True                   15.0                  4
# 63               True                   15.0                  4
#
#     sampling_rate_hz  ... final_val_loss  best_val_accuracy  best_val_loss  \
# 61              30.0  ...       0.620769           0.880435       0.424634
# 62              30.0  ...       0.253228           0.942935       0.207881
# 63              30.0  ...       0.168991           0.955665       0.168991
#
#     test_accuracy  test_loss  batch_test_accuracy  \
# 61       0.885714   0.365175             0.800000
# 62       0.914286   0.306539             0.771429
# 63       0.947368   0.289391             0.685714
#
#                                          history_json  \
# 61  {"accuracy":[0.36920979619026184,0.54768389463...
# 62  {"accuracy":[0.3521798253059387,0.613760232925...
# 63  {"accuracy":[0.3520345389842987,0.586929738521...
#
#                                         row_signature  \
# 61  6865599ed65d9ff6a5c3788b457f39de08a311f0510912...
# 62  c1e504d338a49c842a1040bc09edb8307d6085ac08943b...
# 63  65f06c71b08de517129c0d41d146eaece361b24acdd2b7...
#
#                                            data_paths data_paths_count
# 61  ["/home/jestin/ThesisRepo/ML/NewTestData/1_Ala...             10.0
# 62  ["/home/jestin/ThesisRepo/ML/NewTestData/1_Ala...             10.0
# 63  ["/home/jestin/ThesisRepo/ML/NewTestData/1_Ala...             11.0
#
# [3 rows x 49 columns]

# %% [markdown]
# ## 15. Export PDF report (parameters, paths, results)
#
# Builds a compact PDF summarising the configuration, data locations, CV folds, hold-out and
# batch-test results, and the saved model path. Uses only `reportlab` so it works in any env.

# %%
from reportlab.lib.pagesizes import A4
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.lib.units import mm
from reportlab.lib import colors
from reportlab.platypus import (
    SimpleDocTemplate, Paragraph, Spacer, Table, TableStyle, Image, PageBreak
)
from reportlab.lib.enums import TA_LEFT


def _fmt(v, nd=4):
    if v is None:
        return '—'
    if isinstance(v, float):
        return f'{v:.{nd}f}'
    return str(v)


_VAL_STYLE = ParagraphStyle('KVValue', fontName='Helvetica', fontSize=7.5, leading=9.5,
                            textColor=colors.HexColor('#222222'))
_KEY_STYLE = ParagraphStyle('KVKey',   fontName='Helvetica-Bold', fontSize=7.5, leading=9.5,
                            textColor=colors.HexColor('#333333'))


def _wrap(text, style=_VAL_STYLE):
    if isinstance(text, Paragraph):
        return text
    s = str(text).replace('&', '&amp;').replace('<', '&lt;').replace('>', '&gt;')
    return Paragraph(s, style)


def _kv_table(rows, col_widths=(50*mm, 135*mm)):
    wrapped = [[_wrap(r[0], _KEY_STYLE), _wrap(r[1], _VAL_STYLE)] for r in rows]
    tbl = Table(wrapped, colWidths=col_widths, hAlign='LEFT')
    tbl.setStyle(TableStyle([
        ('VALIGN',       (0, 0), (-1, -1), 'TOP'),
        ('BOTTOMPADDING',(0, 0), (-1, -1), 1),
        ('TOPPADDING',   (0, 0), (-1, -1), 1),
        ('LINEBELOW',    (0, 0), (-1, -2), 0.25, colors.HexColor('#dddddd')),
    ]))
    return tbl


def _section(title, styles):
    return Paragraph(f'<b>{title}</b>', styles['Section'])


def _build_comparison_chart(variant_results, out_path, batch_subject):
    fig, ax = plt.subplots(figsize=(9, 4.5))
    labels    = [r['name'] for r in variant_results]
    cv_means  = [r['cv_mean'] if r['cv_mean'] is not None else 0 for r in variant_results]
    cv_stds   = [r['cv_std']  if r['cv_std']  is not None else 0 for r in variant_results]
    test_accs = [r['test_accuracy'] for r in variant_results]
    batch_acc = [r['batch_accuracy'] if r['batch_accuracy'] is not None else 0 for r in variant_results]
    x = np.arange(len(labels)); w = 0.27
    ax.bar(x - w, cv_means,  w, yerr=cv_stds, capsize=3, label=f'CV mean (k={CV_FOLDS})', color='#4c78a8')
    ax.bar(x,     test_accs, w, label='Hold-out', color='#f58518')
    ax.bar(x + w, batch_acc, w, label=f'Batch ({batch_subject})', color='#54a24b')
    ax.set_xticks(x); ax.set_xticklabels(labels, rotation=0)
    ax.set_ylim(0, 1.05); ax.set_ylabel('Accuracy')
    ax.set_title('1D CNN architecture variants — accuracy comparison')
    ax.legend(loc='lower right', fontsize=8); ax.grid(axis='y', alpha=0.3)
    for i, v in enumerate(test_accs):
        ax.text(i, v + 0.02, f'{v:.2f}', ha='center', fontsize=7)
    plt.tight_layout()
    plt.savefig(out_path, dpi=140); plt.close()


def export_variants_report_pdf(out_path):
    styles = getSampleStyleSheet()
    styles.add(ParagraphStyle(name='Section',    parent=styles['Heading2'],
                              fontSize=11, spaceBefore=6, spaceAfter=2,
                              textColor=colors.HexColor('#1a3a6c')))
    styles.add(ParagraphStyle(name='SubSection', parent=styles['Heading3'],
                              fontSize=9.5, spaceBefore=4, spaceAfter=1,
                              textColor=colors.HexColor('#2a4a7c')))
    styles.add(ParagraphStyle(name='Small',      parent=styles['BodyText'],
                              fontSize=8, leading=10))
    styles['Title'].fontSize = 15
    styles['Title'].spaceAfter = 4
    styles['Title'].alignment = TA_LEFT

    doc = SimpleDocTemplate(
        str(out_path), pagesize=A4,
        leftMargin=12*mm, rightMargin=12*mm,
        topMargin=10*mm, bottomMargin=10*mm,
        title='1D CNN Variant Comparison',
    )
    story = []
    batch_subject = os.path.basename(os.path.dirname(str(BATCH_TEST_ROOT).rstrip('/'))) or 'batch'

    # Header
    story.append(Paragraph('1D CNN — Architecture Variant Comparison', styles['Title']))
    story.append(Paragraph(f"Generated {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}", styles['Small']))
    story.append(Spacer(1, 4))

    # Data + config
    story.append(_section('Data &amp; configuration', styles))
    dp_rows = [[f'Training path {i+1}', p] for i, p in enumerate(ACTIVE_DATA_PATHS or [])]
    aug_enabled = ', '.join(n for n, c in AUGMENT_CONFIG.items() if c.get('enabled')) or 'no transforms enabled'
    dp_rows += [
        ['Batch-test root',     str(BATCH_TEST_ROOT)],
        ['Total trials',        f'{X.shape[0]} (train pool {X_train_pool.shape[0]}, hold-out {X_test.shape[0]})'],
        ['Classes',             f'{n_classes}: ' + ', '.join(le.classes_)],
        ['Sensor channels',     f'{n_channels} (sequence length {sequence_length})'],
        ['Resample / filter',   f'{RESAMPLE_TO_N_STEPS} steps · Butterworth cutoff {BUTTERWORTH_CUTOFF_HZ} Hz, order {BUTTERWORTH_ORDER}'],
        ['Normalisation',       str(NORMALISATION)],
        ['CV folds · shuffle',   f'{CV_FOLDS} · {CV_SHUFFLE}'],
        ['Augmentation',        ('on' if AUGMENT_TRAINING_DATA else 'off') + f' · copies={AUGMENTATION_COPIES_PER_SAMPLE} · ' + aug_enabled],
        ['Epochs · batch size',  f'{TRAIN_EPOCHS} · {TRAIN_BATCH_SIZE}'],
    ]
    story.append(_kv_table(dp_rows))

    # Comparison summary table
    story.append(_section('Variant comparison (summary)', styles))
    summary_rows = [['Variant', 'Params', f'CV mean (k={CV_FOLDS})', 'CV std',
                     'Hold-out acc', 'Hold-out loss', 'Batch acc', 'Batch n']]
    for r in variant_results:
        summary_rows.append([
            r['name'],
            f"{r['n_params']:,}",
            _fmt(r['cv_mean'], 4),
            _fmt(r['cv_std'], 4),
            _fmt(r['test_accuracy'], 4),
            _fmt(r['test_loss'], 4),
            _fmt(r['batch_accuracy'], 4) if r['batch_accuracy'] is not None else '—',
            f"{r['batch_correct']}/{r['batch_total']}" if r['batch_total'] else '—',
        ])
    best_test = max(variant_results, key=lambda r: r['test_accuracy'])['name']
    best_cv   = max(variant_results, key=lambda r: r['cv_mean'] or 0)['name']
    summary_t = Table(summary_rows, hAlign='LEFT',
                      colWidths=(22*mm, 22*mm, 24*mm, 18*mm, 24*mm, 22*mm, 22*mm, 18*mm))
    style_cmds = [
        ('FONT',         (0, 0), (-1, -1), 'Helvetica',     7.5),
        ('FONT',         (0, 0), (-1,  0), 'Helvetica-Bold', 7.5),
        ('BACKGROUND',   (0, 0), (-1,  0), colors.HexColor('#eef2f7')),
        ('GRID',         (0, 0), (-1, -1), 0.25, colors.HexColor('#cccccc')),
        ('VALIGN',       (0, 0), (-1, -1), 'MIDDLE'),
        ('ALIGN',        (1, 1), (-1, -1), 'CENTER'),
        ('BOTTOMPADDING',(0, 0), (-1, -1), 1),
        ('TOPPADDING',   (0, 0), (-1, -1), 1),
    ]
    for i, r in enumerate(variant_results, start=1):
        if r['name'] == best_test:
            style_cmds.append(('BACKGROUND', (0, i), (-1, i), colors.HexColor('#fff7e0')))
    summary_t.setStyle(TableStyle(style_cmds))
    story.append(summary_t)
    story.append(Spacer(1, 3))
    story.append(Paragraph(f'Best on hold-out: <b>{best_test}</b> · Best on CV: <b>{best_cv}</b>', styles['Small']))

    # Comparison chart
    cmp_chart = MODEL_OUTPUT_DIR / 'variants_comparison.png'
    _build_comparison_chart(variant_results, cmp_chart, batch_subject)
    img_w = 175*mm
    if cmp_chart.exists():
        story.append(Spacer(1, 4))
        story.append(Image(str(cmp_chart), width=img_w, height=img_w*0.5))

    # Training curves (already saved by curves cell)
    curves_path = MODEL_OUTPUT_DIR / 'training_curves.png'
    story.append(_section('Training curves (final retrain on full training pool)', styles))
    if curves_path.exists():
        story.append(Image(str(curves_path), width=img_w, height=img_w*0.36))

    # Per-variant detail pages
    for r in variant_results:
        story.append(PageBreak())
        story.append(Paragraph(f'Variant: {r["name"]}', styles['Title']))
        story.append(Paragraph(r['description'], styles['Small']))
        story.append(Spacer(1, 4))

        story.append(_kv_table([
            ['Trainable params',         f'{r["n_params"]:,}'],
            ['CV mean ± std',           f'{_fmt(r["cv_mean"])} ± {_fmt(r["cv_std"])}'],
            ['Hold-out test acc / loss', f'{_fmt(r["test_accuracy"])} · {_fmt(r["test_loss"])}'],
            ['Batch-test acc',
             f'{_fmt(r["batch_accuracy"])}  ({r["batch_correct"]}/{r["batch_total"]})'
             if r['batch_total'] else '—'],
        ]))

        if r['cv_fold_results']:
            story.append(Paragraph('<b>Cross-validation folds</b>', styles['SubSection']))
            ftbl = [['Fold', 'Train (post-aug)', 'Val', 'Val acc', 'Best val', 'Final val']]
            for fr in r['cv_fold_results']:
                ftbl.append([fr['fold'], fr['train_after_aug'], fr['val_samples'],
                             _fmt(fr['val_accuracy']),
                             _fmt(fr['best_val_accuracy']),
                             _fmt(fr['final_val_accuracy'])])
            t = Table(ftbl, hAlign='LEFT',
                      colWidths=(12*mm, 30*mm, 16*mm, 22*mm, 22*mm, 22*mm))
            t.setStyle(TableStyle([
                ('FONT',         (0, 0), (-1, -1), 'Helvetica',     7.5),
                ('FONT',         (0, 0), (-1,  0), 'Helvetica-Bold', 7.5),
                ('BACKGROUND',   (0, 0), (-1,  0), colors.HexColor('#eef2f7')),
                ('GRID',         (0, 0), (-1, -1), 0.25, colors.HexColor('#cccccc')),
                ('VALIGN',       (0, 0), (-1, -1), 'MIDDLE'),
                ('ALIGN',        (1, 1), (-1, -1), 'CENTER'),
                ('BOTTOMPADDING',(0, 0), (-1, -1), 1),
                ('TOPPADDING',   (0, 0), (-1, -1), 1),
            ]))
            story.append(t)

        # Per-class hold-out metrics
        story.append(Paragraph('<b>Per-class hold-out metrics</b>', styles['SubSection']))
        rep = r['classification_report']
        _cell = ParagraphStyle('Cell', fontName='Helvetica', fontSize=7, leading=8.5)
        cls_rows = [['Class', 'Precision', 'Recall', 'F1', 'Support']]
        for cls in le.classes_:
            d = rep.get(cls, {})
            cls_rows.append([_wrap(cls, _cell),
                             _fmt(d.get('precision'), 3),
                             _fmt(d.get('recall'), 3),
                             _fmt(d.get('f1-score'), 3),
                             int(d.get('support', 0))])
        for tag in ('macro avg', 'weighted avg'):
            d = rep.get(tag, {})
            cls_rows.append([tag,
                             _fmt(d.get('precision'), 3),
                             _fmt(d.get('recall'), 3),
                             _fmt(d.get('f1-score'), 3),
                             int(d.get('support', 0))])
        ct = Table(cls_rows, hAlign='LEFT', colWidths=(82*mm, 20*mm, 20*mm, 20*mm, 18*mm))
        ct.setStyle(TableStyle([
            ('FONT',         (0, 0), (-1, -1), 'Helvetica',     7),
            ('FONT',         (0, 0), (-1,  0), 'Helvetica-Bold', 7),
            ('FONT',         (0, -2), (-1, -1), 'Helvetica-Oblique', 7),
            ('BACKGROUND',   (0, 0), (-1,  0), colors.HexColor('#eef2f7')),
            ('GRID',         (0, 0), (-1, -1), 0.25, colors.HexColor('#cccccc')),
            ('VALIGN',       (0, 0), (-1, -1), 'MIDDLE'),
            ('ALIGN',        (1, 1), (-1, -1), 'CENTER'),
            ('BOTTOMPADDING',(0, 0), (-1, -1), 1),
            ('TOPPADDING',   (0, 0), (-1, -1), 1),
        ]))
        story.append(ct)

        # Batch-test per class
        if r.get('batch_df') is not None and len(r['batch_df']) > 0:
            story.append(Paragraph(f'<b>Batch test per class ({batch_subject})</b>', styles['SubSection']))
            bt_rows = [['Class', 'Correct', 'Total', 'Accuracy']]
            for cls, g in r['batch_df'].groupby('true'):
                c = int(g['correct'].sum()); n = int(len(g))
                bt_rows.append([_wrap(cls, _cell), c, n, _fmt(c/n if n else 0.0, 3)])
            bt_rows.append(['Overall', r['batch_correct'], r['batch_total'],
                            _fmt(r['batch_accuracy'], 3) if r['batch_accuracy'] is not None else '—'])
            bt = Table(bt_rows, hAlign='LEFT', colWidths=(102*mm, 20*mm, 20*mm, 22*mm))
            bt.setStyle(TableStyle([
                ('FONT',         (0, 0), (-1, -1), 'Helvetica',     7),
                ('FONT',         (0, 0), (-1,  0), 'Helvetica-Bold', 7),
                ('FONT',         (0, -1), (-1, -1), 'Helvetica-Bold', 7),
                ('BACKGROUND',   (0, 0), (-1,  0), colors.HexColor('#eef2f7')),
                ('BACKGROUND',   (0, -1), (-1, -1), colors.HexColor('#fff7e0')),
                ('GRID',         (0, 0), (-1, -1), 0.25, colors.HexColor('#cccccc')),
                ('VALIGN',       (0, 0), (-1, -1), 'MIDDLE'),
                ('ALIGN',        (1, 1), (-1, -1), 'CENTER'),
                ('BOTTOMPADDING',(0, 0), (-1, -1), 1),
                ('TOPPADDING',   (0, 0), (-1, -1), 1),
            ]))
            story.append(bt)

    doc.build(story)
    print(f'PDF report written to {out_path}')
    return out_path


# Unique filename so re-running never overwrites a previous report
_report_timestamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
_report_filename  = f'variants_report_{_report_timestamp}.pdf'
report_pdf_path   = export_variants_report_pdf(MODEL_OUTPUT_DIR / _report_filename)
# Out:
# PDF report written to saved_models/variants_report_2026-05-11_16-57-13.pdf
