# %% [markdown]
# # Glove CSV Plotter - Full Manual Selection
#
# Edit the list below to comment out (using '#') the specific columns you do not wish to plot.

# %%
from pathlib import Path
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from pathlib import Path

# %%
# Set the CSV path here
CSV_PATH = Path('Synchronization/gloves_combined_20260411_214401_fist.csv')

df = pd.read_csv(CSV_PATH)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Set the CSV path here
#       2 CSV_PATH = Path('Synchronization/gloves_combined_20260411_214401_fist.csv')
#       3
# ----> 4 df = pd.read_csv(CSV_PATH)
#       5 df.head()
#
# File ~/ThesisRepo/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
X_COL = 'request_id'

# COMMENT OUT ANY LINE TO EXCLUDE IT FROM THE PLOT
PLOT_COLUMNS = [
    # --- LEFT GLOVE ---
    # 'left_palm_ax_prox', 'left_palm_ay_prox', 'left_palm_az_prox', 'left_palm_yaw_prox', 'left_palm_pitch_prox', 'left_palm_roll_prox', 
    # 'left_palm_flex_mcp', 'left_palm_flex_pip',
    # 'left_thumb_ax_prox', 'left_thumb_ay_prox', 'left_thumb_az_prox', 'left_thumb_yaw_prox', 'left_thumb_pitch_prox', 'left_thumb_roll_prox', 
    # 'left_thumb_flex_mcp', 'left_thumb_flex_pip',
    'left_index_ax_prox', 'left_index_ay_prox', 'left_index_az_prox', 'left_index_yaw_prox', 'left_index_pitch_prox', 'left_index_roll_prox', 
    'left_index_flex_mcp', 'left_index_flex_pip',
    'left_middle_ax_prox', 'left_middle_ay_prox', 'left_middle_az_prox', 'left_middle_yaw_prox', 'left_middle_pitch_prox', 'left_middle_roll_prox', 
    'left_middle_flex_mcp', 'left_middle_flex_pip',
    'left_ring_ax_prox', 'left_ring_ay_prox', 'left_ring_az_prox', 'left_ring_yaw_prox', 'left_ring_pitch_prox', 'left_ring_roll_prox', 
    'left_ring_flex_mcp', 'left_ring_flex_pip',
    'left_pinky_ax_prox', 'left_pinky_ay_prox', 'left_pinky_az_prox', 'left_pinky_yaw_prox', 'left_pinky_pitch_prox', 'left_pinky_roll_prox', 
    'left_pinky_flex_mcp', 'left_pinky_flex_pip',
    # 'left_wrist_ax_prox', 'left_wrist_ay_prox', 'left_wrist_az_prox', 'left_wrist_yaw_prox', 'left_wrist_pitch_prox', 'left_wrist_roll_prox', 
    # 'left_wrist_flex_mcp', 'left_wrist_flex_pip',

    # --- RIGHT GLOVE ---
    # Proximal sensors
    # 'right_palm_ax_prox', 'right_palm_ay_prox', 'right_palm_az_prox', 'right_palm_yaw_prox', 'right_palm_pitch_prox', 'right_palm_roll_prox', 'right_palm_flex_mcp', 'right_palm_flex_pip',
    # 'right_thumb_ax_prox', 'right_thumb_ay_prox', 'right_thumb_az_prox', 'right_thumb_yaw_prox', 'right_thumb_pitch_prox', 'right_thumb_roll_prox', 'right_thumb_flex_mcp', 'right_thumb_flex_pip',
    # 'right_index_ax_prox', 'right_index_ay_prox', 'right_index_az_prox', 'right_index_yaw_prox', 'right_index_pitch_prox', 'right_index_roll_prox', 'right_index_flex_mcp', 'right_index_flex_pip',
    # 'right_middle_ax_prox', 'right_middle_ay_prox', 'right_middle_az_prox', 'right_middle_yaw_prox', 'right_middle_pitch_prox', 'right_middle_roll_prox', 'right_middle_flex_mcp', 'right_middle_flex_pip',
    # 'right_ring_ax_prox', 'right_ring_ay_prox', 'right_ring_az_prox', 'right_ring_yaw_prox', 'right_ring_pitch_prox', 'right_ring_roll_prox', 'right_ring_flex_mcp', 'right_ring_flex_pip',
    # 'right_pinky_ax_prox', 'right_pinky_ay_prox', 'right_pinky_az_prox', 'right_pinky_yaw_prox', 'right_pinky_pitch_prox', 'right_pinky_roll_prox', 'right_pinky_flex_mcp', 'right_pinky_flex_pip',
    # 'right_wrist_ax_prox', 'right_wrist_ay_prox', 'right_wrist_az_prox', 'right_wrist_yaw_prox', 'right_wrist_pitch_prox', 'right_wrist_roll_prox', 'right_wrist_flex_mcp', 
    # 
    'right_wrist_flex_pip'


]

selected = [c for c in PLOT_COLUMNS if c in df.columns]
print(f"Selected {len(selected)} channels for plotting.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 36
#      32
#      33
#      34 ]
#      35
# ---> 36 selected = [c for c in PLOT_COLUMNS if c in df.columns]
#      37 print(f"Selected {len(selected)} channels for plotting.")
#
# NameError: name 'df' is not defined

# %%
def detect_family(col_name):
    c = col_name.lower()
    if 'flex' in c:
        return 'Flex'
    if any(tag in c for tag in ['ax', 'ay', 'az']):
        return 'Accel'
    if any(tag in c for tag in ['yaw', 'pitch', 'roll']):
        return 'Orientation'
    return 'Other'

families = ['Flex', 'Accel', 'Orientation']
family_titles = {
    'Flex': 'Flex Sensors',
    'Accel': 'Accelerometer',
    'Orientation': 'Orientation',
}

fig = make_subplots(
    rows=3, cols=1, shared_xaxes=True, vertical_spacing=0.06,
    subplot_titles=[family_titles[f] for f in families]
)

row_map = {'Flex': 1, 'Accel': 2, 'Orientation': 3}

for col in selected:
    family = detect_family(col)
    if family not in row_map: continue
    
    fig.add_trace(
        go.Scatter(
            x=df[X_COL], y=df[col], mode='lines', name=col,
            hovertemplate="<b>%{fullData.name}</b><br>" + X_COL + "=%{x}<br>Value=%{y}<extra></extra>"
        ),
        row=row_map[family], col=1
    )

fig.update_layout(height=1000, title_text="Hand Tracking Analytics", hovermode='x unified')
fig.show()
